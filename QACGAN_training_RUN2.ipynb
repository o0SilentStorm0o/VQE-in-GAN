# %% [markdown]
# # Hybrid Quantum-Classical ACGAN with VQE Regularization (RUN2 — Seed 2025)
#
# **Author:** David Strnadel
# **Date:** December, 2025
# **Affiliation:** Faculty of Applied Informatics, Tomas Bata University in Zlin

# %% [markdown]
# ## 1. Abstract
#
# This notebook presents the **second full training run (RUN2)** of the Quantum-enhanced Auxiliary Classifier GAN (QACGAN) with **seed 2025** for reproducibility. The experiment validates the hybrid architecture that integrates the Variational Quantum Eigensolver (VQE) as a physics-inspired regularization mechanism into the classical ACGAN framework.
#
# ### Key Results (10 Epochs)
# | Metric | Best Value | Epoch Achieved |
# |--------|------------|----------------|
# | **FID (Fréchet Inception Distance)** | **23.23** | 9 |
# | **IS (Inception Score)** | **2.32** | 4 |
# | **Classification Accuracy** | **100.0%** | 5 |
#
# ### Comparison with RUN1 (Seed 42)
# | Metric | RUN1 (seed 42) | RUN2 (seed 2025) | Difference |
# |--------|----------------|------------------|------------|
# | Best FID | 23.91 (epoch 10) | 23.23 (epoch 9) | −0.68 ↓ |
# | Best IS | 2.29 (epoch 2) | 2.32 (epoch 4) | +0.03 ↑ |
# | Best Accuracy | 99.4% (epoch 7,9) | 100.0% (epoch 5) | +0.6% ↑ |
#
# ### FID Progression
# The FID values across training epochs demonstrate consistent convergence:
# - Epoch 1: 117.75 → Epoch 5: 24.11 → Epoch 9: **23.23** (best) → Epoch 10: 35.48 (slight overfitting)
#
# This run achieved the **best overall FID** across all QACGAN experiments, confirming the effectiveness of the hybrid quantum-classical approach.

# %% [markdown]
# ## 2. Reproducible Environment
#
# This section installs and verifies all dependencies required for training the hybrid QACGAN model. The environment is designed for **Google Colab** with optional GPU acceleration.
#
# ### Required Dependencies
# | Package | Purpose |
# |---------|---------|
# | `qiskit` | Quantum circuit construction and simulation |
# | `qiskit-aer` | High-performance quantum simulator backend |
# | `qiskit-machine-learning` | Quantum neural network integration |
# | `torch` | Deep learning framework for classical components |
# | `torch-fidelity` | FID and Inception Score computation |
# | `scikit-image` | Image preprocessing utilities |
# | `pylatexenc` | LaTeX rendering for circuit visualization |
#
# > **Note:** If running in Google Colab, execute the installation cell first. For local execution, ensure CUDA is properly configured for GPU acceleration.

# %%
#@title Installation of Required Libraries

# !pip install --upgrade pip -q
# !pip install \
    qiskit \
    qiskit-aer \
    torch \
    torch-fidelity \
    scikit-image \
    ipywidgets \
    pylatexenc \
    -q

# !pip install \
  git+https://github.com/qiskit-community/qiskit-machine-learning.git@main#egg=qiskit-machine-learning \
  -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 72.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   DEPRECATION: Building 'pylatexenc' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pylatexenc'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pylatexenc (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for qiskit-machine-learning (pyproject.toml) ... done

# %% [markdown]
# ## 3. Theoretical Foundations
#
# This section summarizes the key theoretical concepts underlying the hybrid QACGAN architecture.
#
# ### 3.1 Generative Adversarial Networks (GANs)
# GANs implement a **minimax game** between two neural networks:
# - **Generator $G$**: Maps latent noise $\mathbf{z} \sim \mathcal{N}(0, I)$ to synthetic images
# - **Discriminator $D$**: Distinguishes real images from generated ones
#
# The training objective follows:
# $$\min_G \max_D \, \mathbb{E}_{x \sim p_{\text{data}}}[\log D(x)] + \mathbb{E}_{z \sim p_z}[\log(1 - D(G(z)))]$$
#
# ### 3.2 Auxiliary Classifier GAN (ACGAN)
# ACGAN extends the standard GAN by adding **class prediction** to the discriminator, enabling conditional generation. The discriminator outputs both:
# - **Validity score** $P(\text{real}|x)$
# - **Class distribution** $P(c|x)$
#
# ### 3.3 Variational Quantum Eigensolver (VQE)
# VQE is a hybrid quantum-classical algorithm that finds the ground-state energy of a quantum system:
# $$E(\boldsymbol{\theta}) = \langle \psi(\boldsymbol{\theta}) | H | \psi(\boldsymbol{\theta}) \rangle$$
#
# The parameterized quantum state $|\psi(\boldsymbol{\theta})\rangle$ is prepared using an **ansatz circuit**, and classical optimization minimizes $E(\boldsymbol{\theta})$.
#
# ### 3.4 Ising Hamiltonian for Class Encoding
# Each digit class $c \in \{0, \ldots, 9\}$ is encoded into a transverse-field Ising Hamiltonian:
# $$H_c = -J \sum_{\langle i,j \rangle} Z_i Z_j - \sum_i h_i^{(c)} Z_i$$
#
# where $J = 1.0$ (coupling strength) and $h_i^{(c)} = 0.1 + 0.01 \cdot c$ (class-dependent local field).
#
# > **Reference:** See Chapters 2, 4, and 5 of the bachelor thesis for comprehensive theoretical treatment.

# %%
#@title Verification of Required Libraries Installation

import torch, qiskit, qiskit_machine_learning, torch_fidelity

"""
<summary>
This script prints the versions of the main libraries (PyTorch, Qiskit, Qiskit Machine Learning, Torch-Fidelity)
and verifies the availability of key modules for quantum-classical machine learning.
</summary>
"""

print("PyTorch version:      ", torch.__version__)
print("Qiskit version:       ", qiskit.__version__)
print("Qiskit-ML version:    ", qiskit_machine_learning.__version__)
print("Torch-Fidelity ver.:  ", torch_fidelity.__version__)

from qiskit.primitives import StatevectorEstimator
from qiskit_aer import AerSimulator
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector

print("✅ All key modules imported successfully!")
# Out:
# PyTorch version:       2.8.0+cu126
# Qiskit version:        1.4.4
# Qiskit-ML version:     0.9.0
# Torch-Fidelity ver.:   0.3.0
# ✅ All key modules imported successfully!

# %%
#@title 1. Imports
"""
<summary>
Installation and import of required libraries for PyTorch, Qiskit, and other utilities used in the project.
</summary>
<remarks>
This script contains imports for working with neural networks in PyTorch, image processing with torchvision and skimage,
evaluation with torch-fidelity, and quantum libraries Qiskit including Qiskit Machine Learning.
It also includes multiprocessing setup and version printing of key libraries.
</remarks>
"""

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets, transforms
from torchvision.utils import save_image, make_grid
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import time
import shutil
import tempfile
from skimage.transform import resize

from torch_fidelity import calculate_metrics

from qiskit import QuantumCircuit
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives import StatevectorEstimator
from qiskit_aer import AerSimulator
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector

from IPython.display import clear_output
import datetime
from google.colab import files

try:
    torch.multiprocessing.set_start_method('spawn', force=True)
    print("Multiprocessing start method set to 'spawn'.")
except RuntimeError:
    print("Multiprocessing start method was already set.")

print(f"PyTorch version: {torch.__version__}")
import qiskit
print(f"Qiskit version: {qiskit.__version__}")
import qiskit_machine_learning
print(f"Qiskit Machine Learning version: {qiskit_machine_learning.__version__}")
# Out:
# Multiprocessing start method set to 'spawn'.
# PyTorch version: 2.8.0+cu126
# Qiskit version: 1.4.4
# Qiskit Machine Learning version: 0.9.0

# %%
#@title 2. Device, Paths and Configuration Setup
"""
<summary>
Device setup (CPU/GPU), path configuration and check of required files in Google Colab environment for training and evaluation of the model.
</summary>
<remarks>
The script automatically detects GPU availability, sets the appropriate memory format, defines working and output paths, creates required directories, and verifies the presence of the MNIST classifier.
</remarks>
"""

if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
    MEMORY_FORMAT = torch.channels_last
else:
    device = torch.device("cpu")
    print("GPU not available, using CPU.")
    MEMORY_FORMAT = torch.contiguous_format
print(f"Device in use: {device}, Preferred memory format for models: {MEMORY_FORMAT}")

WORK_DIR = "/content/"
MNIST_DOWNLOAD_PATH = os.path.join(WORK_DIR, "MNIST_data")
MNIST_TRAIN_IMAGES_PATH = os.path.join(MNIST_DOWNLOAD_PATH, "MNIST_train_images_png")
OUTPUT_DIR_IMAGES = os.path.join(WORK_DIR, "hybrid_acgan_images_output")
OUTPUT_DIR_MODELS = os.path.join(WORK_DIR, "hybrid_acgan_models_output")
LOG_FILE = os.path.join(WORK_DIR, "hybrid_acgan_training_logs.pkl")
CLASSIFIER_PATH = os.path.join(WORK_DIR, "mnist_classifier.pth")

os.makedirs(MNIST_DOWNLOAD_PATH, exist_ok=True)
os.makedirs(OUTPUT_DIR_IMAGES, exist_ok=True)
os.makedirs(OUTPUT_DIR_MODELS, exist_ok=True)
print(f"Working directory: {WORK_DIR}")
print(f"Path for MNIST PNG (FID): {MNIST_TRAIN_IMAGES_PATH}")

if not os.path.exists(CLASSIFIER_PATH):
    print(f"\n!!! WARNING: Classifier file '{CLASSIFIER_PATH}' not found! !!!")
    print("Please upload 'mnist_classifier.pth' into Colab (e.g., drag & drop into Files).")
    print("Without it, classification accuracy of generated images cannot be computed.")
else:
    print(f"\nClassifier file '{CLASSIFIER_PATH}' found.")
# Out:
# GPU is available: NVIDIA A100-SXM4-40GB
# Device in use: cuda, Preferred memory format for models: torch.channels_last
# Working directory: /content/
# Path for MNIST PNG (FID): /content/MNIST_data/MNIST_train_images_png
#
# Classifier file '/content/mnist_classifier.pth' found.

# %%
#@title 3. Hyperparameters and Training Configuration
"""
<summary>
Setup of hyperparameters and training configuration for the hybrid quantum-classical model, including model parameters, quantum settings, training hyperparameters, logging and evaluation configuration, and seed initialization for reproducibility.
</summary>
"""

SEED = 2025
Z_DIM = 100
NUM_CLASSES = 10
IMG_CHANNELS = 1
IMG_SIZE = 28

N_QUBITS = 4
ANSAETZ_REPS = 1
LAMBDA_VQER = 0.1
ISING_J = 1.0
ISING_H_GLOBAL = 0.1

NUM_EPOCHS = 10
EFFECTIVE_BATCH_SIZE = 64
MICRO_BATCH_SIZE = 32
ACCUMULATION_STEPS = EFFECTIVE_BATCH_SIZE // MICRO_BATCH_SIZE

LEARNING_RATE_G = 0.0002
LEARNING_RATE_D = 0.0002
BETA1 = 0.5
BETA2 = 0.999
LABEL_SMOOTHING = 0.9

LOG_INTERVAL = 50
EVAL_INTERVAL = 1
SAVE_SAMPLES_INTERVAL = 1

NUM_SAMPLES_FOR_METRICS = 1000
NUM_SAMPLES_FOR_ACCURACY = 500

FIDELITY_BATCH_SIZE = MICRO_BATCH_SIZE
FIDELITY_NUM_WORKERS = 2

USE_AMP = False

torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

print(f"Hyperparameters set. Effective batch size: {EFFECTIVE_BATCH_SIZE}")
print(f"Number of qubits for quantum part: {N_QUBITS}")
print(f"Lambda for VQE regularization: {LAMBDA_VQER}")
# Out:
# Hyperparameters set. Effective batch size: 64
# Number of qubits for quantum part: 4
# Lambda for VQE regularization: 0.1

# %% [markdown]
# ## 4. Quantum Components
#
# This section defines the core quantum modules that enable VQE-based regularization.
#
# ### 4.1 Ising Hamiltonian Construction
# The function `build_ising_hamiltonian_op` constructs a `SparsePauliOp` representation of the Ising Hamiltonian $H_c$:
#
# **Parameters:**
# - `n_qubits`: Number of qubits (4 in this experiment)
# - `J_coeff`: ZZ interaction strength ($J = 1.0$)
# - `h_coeffs_list`: Class-specific local field coefficients
#
# **Structure:**
# $$H = -J \sum_{i=0}^{n-2} Z_i Z_{i+1} - \sum_{i=0}^{n-1} h_i Z_i$$
#
# ### 4.2 Angle Producer Network
# The `AngleProducer` module transforms the latent vector $\mathbf{z}$ and class label into rotation angles $\boldsymbol{\theta}$ for the quantum ansatz:
#
# $$\boldsymbol{\theta} = \pi \cdot \tanh\left( \text{MLP}(\mathbf{z} \odot \text{Embed}(c)) \right)$$
#
# **Architecture:**
# - Label embedding: $\mathbb{Z}_{10} \to \mathbb{R}^{100}$
# - Hidden layers: $100 \to 128 \to 256 \to n_{\text{params}}$
# - Output range: $[-\pi, \pi]$ (via $\tanh$ activation)
#
# ### 4.3 EfficientSU2 Ansatz
# The variational circuit uses Qiskit's `EfficientSU2` with:
# - **4 qubits** with circular entanglement topology
# - **1 repetition layer** (8 trainable parameters)
# - **Insert barriers** for visualization clarity

# %%
#@title 4. Definition of Quantum Components
"""
<summary>
Definition of quantum components for the hybrid model:
- Creation of EfficientSU2 ansatz, calculation of the number of ansatz parameters
- Construction of Ising Hamiltonians for each class using SparsePauliOp
- Initialization of StatevectorEstimator for energy computations of quantum states
</summary>
"""

ansatz = EfficientSU2(num_qubits=N_QUBITS, reps=ANSAETZ_REPS, entanglement='circular', insert_barriers=True)
NUM_ANSATZ_PARAMS = ansatz.num_parameters
print(f"Quantum Ansatz: EfficientSU2 with {N_QUBITS} qubits and {ANSAETZ_REPS} reps.")
print(f"Number of ansatz parameters: {NUM_ANSATZ_PARAMS}")

def build_ising_hamiltonian_op(n_qubits, J_coeff=1.0, h_coeffs_list=None):
    """
    <summary>
    Creates an Ising Hamiltonian as SparsePauliOp.
    </summary>
    <param name="n_qubits">Number of qubits in the system.</param>
    <param name="J_coeff">Coefficient of ZZ interaction term.</param>
    <param name="h_coeffs_list">List of external field Z coefficients for each qubit.</param>
    <returns>SparsePauliOp representing the Ising Hamiltonian.</returns>
    """
    if h_coeffs_list is None:
        h_coeffs_list = [ISING_H_GLOBAL] * n_qubits
    if len(h_coeffs_list) != n_qubits:
        raise ValueError("Length of h_coeffs_list must equal n_qubits.")

    pauli_terms = []
    coeffs = []

    for i in range(n_qubits - 1):
        pauli_str = ['I'] * n_qubits
        pauli_str[i] = 'Z'
        pauli_str[i+1] = 'Z'
        pauli_terms.append("".join(pauli_str))
        coeffs.append(-J_coeff)

    for i in range(n_qubits):
        pauli_str = ['I'] * n_qubits
        pauli_str[i] = 'Z'
        pauli_terms.append("".join(pauli_str))
        coeffs.append(-h_coeffs_list[i])

    return SparsePauliOp(pauli_terms, coeffs=coeffs)

H_op_list = []
for i in range(NUM_CLASSES):
    h_coeffs_class = [ISING_H_GLOBAL + (i * 0.01) for _ in range(N_QUBITS)]
    H_op_list.append(build_ising_hamiltonian_op(N_QUBITS, J_coeff=ISING_J, h_coeffs_list=h_coeffs_class))

print(f"Created {len(H_op_list)} Hamiltonians (one per class).")
print(f"Example Hamiltonian for class 0: {H_op_list[0].paulis}")

aer_estimator = StatevectorEstimator()
print("StatevectorEstimator initialized.")
# Out:
# Quantum Ansatz: EfficientSU2 with 4 qubits and 1 reps.
# Number of ansatz parameters: 16
# Created 10 Hamiltonians (one per class).
# Example Hamiltonian for class 0: ['ZZII', 'IZZI', 'IIZZ', 'ZIII', 'IZII', 'IIZI', 'IIIZ']
# StatevectorEstimator initialized.

# %% [markdown]
# ## 5. Model Architecture
#
# ### 5.1 Hybrid Generator
#
# The `HybridGenerator` combines classical convolutional generation with quantum energy regularization:
#
# | Component | Description |
# |-----------|-------------|
# | **Label Embedding** | $\mathbb{Z}_{10} \to \mathbb{R}^{10}$ for class conditioning |
# | **Input Layer** | Linear: $110 \to 256 \times 7 \times 7$ |
# | **CNN Backbone** | BatchNorm → Upsample(×2) → Conv(256→128→64→1) |
# | **Output** | Tanh activation → 28×28 grayscale image |
# | **Quantum Branch** | AngleProducer → EfficientSU2 → EstimatorQNN → Energy $E_c$ |
#
# **Forward Pass:**
# 1. Generate classical image features via transposed convolutions
# 2. Compute ansatz angles from $(z, c)$
# 3. Evaluate class-specific VQE energy $E_c$
# 4. Return tuple: `(generated_image, energy)`
#
# ### 5.2 Discriminator (ACGAN-D)
#
# The discriminator uses a convolutional architecture with dual output heads:
#
# | Layer | Output Shape | Activation |
# |-------|--------------|------------|
# | Conv2d(1→64, k=4, s=2) | 64×14×14 | LeakyReLU(0.2) |
# | Conv2d(64→128, k=4, s=2) | 128×7×7 | BN + LeakyReLU |
# | Conv2d(128→256, k=3, s=2) | 256×4×4 | BN + LeakyReLU |
# | **Adversarial Head** | 1 (validity) | Sigmoid |
# | **Auxiliary Head** | 10 (class logits) | — |
#
# > **Design Note:** This architecture with 4×4 final feature maps proved more stable than the original ACGAN's 1×1 convolution design.

# %%
#@title 5. Definition of Models (Discriminator, Classifier, Hybrid Generator)
# --- 5.1 Classical MNIST Classifier (for evaluation) ---
class MnistClassifier(nn.Module):
    """
    <summary>
    Classical convolutional neural network classifier for the MNIST dataset.
    </summary>
    <param name="num_classes">Number of classes for classification (default 10).</param>
    <returns>Logits for each class.</returns>
    """
    def __init__(self, num_classes=10):
        super(MnistClassifier, self).__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.flatten_size = 64 * 7 * 7
        self.fc_block = nn.Sequential(
            nn.Linear(self.flatten_size, 1024),
            nn.ReLU(),
            nn.Linear(1024, num_classes))
    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = x.reshape(x.size(0), -1)
        logits = self.fc_block(x)
        return logits

# --- 5.2 Classical ACGAN Discriminator ---
class Discriminator(nn.Module):
    """
    <summary>
    Discriminator for the ACGAN architecture with recognition of both class and image authenticity.
    </summary>
    <param name="num_classes">Number of classes for the classification output.</param>
    <param name="img_channels">Number of channels of input images.</param>
    <returns>
        validity: Image authenticity score.
        class_logits: Logits for class prediction.
    </returns>
    """
    def __init__(self, num_classes=NUM_CLASSES, img_channels=IMG_CHANNELS):
        super(Discriminator, self).__init__()
        self.num_classes = num_classes
        self.img_channels = img_channels

        self.main_conv = nn.Sequential(
            nn.Conv2d(self.img_channels, 64, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
        )
        self.adv_layer = nn.Sequential(
            nn.Linear(256 * 4 * 4, 1),
            nn.Sigmoid()
        )
        self.aux_layer = nn.Sequential(
            nn.Linear(256 * 4 * 4, self.num_classes)
        )

    def forward(self, img):
        features = self.main_conv(img)
        flat_features = features.contiguous().view(features.size(0), -1)
        validity = self.adv_layer(flat_features)
        class_logits = self.aux_layer(flat_features)
        return validity, class_logits

# --- 5.3 Component for generating angles for the quantum ansatz ---
class AngleProducer(nn.Module):
    """
    <summary>
    Module producing angles for the parameterized quantum ansatz based on input noise and a conditional label.
    </summary>
    <param name="z_dim">Dimension of the latent vector.</param>
    <param name="num_classes">Number of classes for embedding.</param>
    <param name="num_ansatz_params">Number of parameters of the quantum ansatz.</param>
    <returns>Tensor of angles for the quantum ansatz in the range [-π, π].</returns>
    """
    def __init__(self, z_dim, num_classes, num_ansatz_params):
        super(AngleProducer, self).__init__()
        self.label_embedding = nn.Embedding(num_classes, z_dim)
        self.fc_net = nn.Sequential(
            nn.Linear(z_dim, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, num_ansatz_params),
            nn.Tanh()
        )
        self.num_ansatz_params = num_ansatz_params

    def forward(self, z, class_labels):
        embedded_labels = self.label_embedding(class_labels)
        conditioned_z = z * embedded_labels
        angles = self.fc_net(conditioned_z)
        return angles * torch.pi

# --- 5.4 Hybrid Generator (ACGAN + VQE regularization) ---
class HybridGenerator(nn.Module):
    """
    <summary>
    Hybrid generator combining the classical ACGAN architecture and quantum VQE regularization via an ansatz and Ising Hamiltonians.
    </summary>
    <param name="z_dim">Dimension of the input latent vector.</param>
    <param name="num_classes">Number of classes for conditional generation.</param>
    <param name="img_channels">Number of channels of the output image.</param>
    <param name="ansatz_instance">Instance of the parameterized quantum ansatz.</param>
    <param name="list_of_hamiltonians">List of SparsePauliOp Hamiltonians (one per class).</param>
    <param name="qiskit_estimator">Instance of Qiskit estimator for energy computations.</param>
    <param name="lambda_vqer_coeff">Weight of the VQE regularization term in the loss function.</param>
    <returns>
        img_classic: Generated image.
        E_c_batch: Energy for each sample in the batch.
    </returns>
    """
    def __init__(self, z_dim, num_classes, img_channels,
                 ansatz_instance,
                 list_of_hamiltonians,
                 qiskit_estimator,
                 lambda_vqer_coeff):
        super(HybridGenerator, self).__init__()

        self.z_dim = z_dim
        self.num_classes = num_classes
        self.img_channels = img_channels
        self.ansatz = ansatz_instance
        self.num_ansatz_params = ansatz_instance.num_parameters
        self.lambda_vqer = lambda_vqer_coeff

        self.classic_label_embedding = nn.Embedding(self.num_classes, self.num_classes)
        self.classic_input_layer = nn.Linear(self.z_dim + self.num_classes, 256 * 7 * 7)
        self.classic_main_generator_cnn = nn.Sequential(
            nn.BatchNorm2d(256),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(256, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128, momentum=0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64, momentum=0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, self.img_channels, kernel_size=3, stride=1, padding=1),
            nn.Tanh()
        )

        self.angle_producer = AngleProducer(self.z_dim, self.num_classes, self.num_ansatz_params)

        self.qnn_module_list = nn.ModuleList()
        for h_op in list_of_hamiltonians:
            qnn_c = EstimatorQNN(
                circuit=self.ansatz,
                observables=h_op,
                input_params=list(self.ansatz.parameters),
                input_gradients=True,
                estimator=qiskit_estimator
            )
            self.qnn_module_list.append(TorchConnector(qnn_c, initial_weights=None))

    def forward(self, z, class_labels):
        classic_embedded_lbls = self.classic_label_embedding(class_labels)
        classic_gen_in = torch.cat((z, classic_embedded_lbls), 1)
        classic_img_features_flat = self.classic_input_layer(classic_gen_in)
        classic_img_features_map = classic_img_features_flat.view(classic_img_features_flat.size(0), 256, 7, 7)
        img_classic = self.classic_main_generator_cnn(classic_img_features_map)

        angles_for_qnn = self.angle_producer(z, class_labels)

        batch_size = z.size(0)
        energies_for_batch = []
        for i in range(batch_size):
            label_index = class_labels[i].item()
            qnn_for_this_class = self.qnn_module_list[label_index]
            current_sample_angles = angles_for_qnn[i].unsqueeze(0)
            energy_tensor = qnn_for_this_class(current_sample_angles)
            energies_for_batch.append(energy_tensor.squeeze())

        E_c_batch = torch.stack(energies_for_batch)
        return img_classic, E_c_batch

# --- Weight initialization ---
def weights_init(m):
    """
    <summary>
    Initializes model weights depending on the layer type.
    </summary>
    <param name="m">Model layer.</param>
    """
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0)

print("Model definitions and weight initialization completed.")
# Out:
# Model definitions and weight initialization completed.

# %% [markdown]
# ## 6. Data Preparation
#
# This section handles MNIST dataset loading, normalization, and preparation for both training and FID evaluation.
#
# ### Dataset Configuration
# | Parameter | Value |
# |-----------|-------|
# | Dataset | MNIST (60,000 training images) |
# | Image Size | 28×28 pixels, grayscale |
# | Normalization | $[-1, 1]$ (mean=0.5, std=0.5) |
# | PNG Export | Required for `torch-fidelity` FID computation |
#
# ### Reproducibility
# - All random generators seeded with **SEED = 2025**
# - Worker initialization function ensures deterministic data loading
# - `torch.backends.cudnn.deterministic = True`

# %%
#@title 6. Dataset preparation and helper functions

def save_mnist_as_images(dataset_path_root, output_dir):
    """
    <summary>
    Save images from the MNIST training split as PNG files into the given folder.
    Checks whether the folder already contains a sufficient number of images; regenerates if needed.
    </summary>
    <param name="dataset_path_root">Path to the root folder for the MNIST dataset.</param>
    <param name="output_dir">Target directory to store the PNG images.</param>
    <returns>True if images were successfully written or already present; otherwise False.</returns>
    """
    num_mnist_train = 60000
    if os.path.exists(output_dir):
        try:
            num_files = len([f for f in os.listdir(output_dir) if f.endswith('.png')])
            if num_files >= num_mnist_train:
                print(f"Directory '{output_dir}' already exists and appears complete. Skipping PNG generation.")
                return True
            else:
                print(f"Directory '{output_dir}' exists but is incomplete. Removing and regenerating.")
                shutil.rmtree(output_dir)
        except OSError as e:
            print(f"Error while checking directory {output_dir}: {e}. Proceeding with generation...")

    os.makedirs(output_dir, exist_ok=True)
    print(f"Generating MNIST training images into '{output_dir}'...")
    transform_save = transforms.Compose([transforms.ToTensor()])
    try:
        mnist_dataset = datasets.MNIST(root=dataset_path_root, train=True, download=True, transform=transform_save)
    except Exception as e:
        print(f"FATAL: Failed to download/load the MNIST dataset from '{dataset_path_root}'. Error: {e}")
        return False

    for i, (image, label) in enumerate(mnist_dataset):
        save_image(image, os.path.join(output_dir, f"mnist_train_{i:05d}.png"), normalize=False)
        if (i + 1) % 5000 == 0:
            print(f"  Saved {i + 1}/{len(mnist_dataset)} images...")
    print(f"Successfully saved {len(mnist_dataset)} MNIST PNG images to '{output_dir}'.")
    return True

if not save_mnist_as_images(MNIST_DOWNLOAD_PATH, MNIST_TRAIN_IMAGES_PATH):
    print("Error while preparing MNIST PNG images. FID computation will not be possible.")

transform_train = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

g_loader = torch.Generator()
g_loader.manual_seed(SEED)

def _worker_init_fn(worker_id):
    import numpy as _np, random as _random, torch as _torch
    base = SEED + worker_id
    _np.random.seed(base)
    _random.seed(base)
    _torch.manual_seed(base)

try:
    train_dataset = datasets.MNIST(root=MNIST_DOWNLOAD_PATH, train=True, download=False, transform=transform_train)
    train_loader = DataLoader(
        train_dataset,
        batch_size=MICRO_BATCH_SIZE,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
        drop_last=True,
        generator=g_loader,
        persistent_workers=False
    )
    print(f"MNIST training dataset loaded: {len(train_dataset)} samples.")
except Exception as e:
    print(f"Failed to load MNIST dataset, error: {e}.")

def save_generated_samples(epoch, generator_model, fixed_z_noise, fixed_class_labels, output_path, num_samples_per_class=5):
    """
    <summary>
    Save generated sample images from the generator for a given epoch into a PNG file in the specified folder.
    </summary>
    <param name="epoch">Current epoch number.</param>
    <param name="generator_model">Generator instance.</param>
    <param name="fixed_z_noise">Fixed noise vector used for sample generation.</param>
    <param name="fixed_class_labels">Fixed labels used for sample generation.</param>
    <param name="output_path">Destination directory for the PNG file.</param>
    <param name="num_samples_per_class">Number of images per class in a single PNG row.</param>
    """
    generator_model.eval()
    with torch.no_grad():
        gen_imgs_classic, _ = generator_model(fixed_z_noise.to(device), fixed_class_labels.to(device))
        save_image(gen_imgs_classic.data,
                   os.path.join(output_path, f"hybrid_acgan_samples_epoch_{epoch:03d}.png"),
                   nrow=num_samples_per_class, normalize=True)
    generator_model.train()

def evaluate_hybrid_model(epoch, generator_model, ext_classifier,
                          num_metrics_samples, num_accuracy_samples,
                          ref_mnist_png_path, current_device):
    """
    <summary>
    Evaluate the hybrid generator using FID, IS, and classification accuracy.
    Generates samples, stores them temporarily for metric computation, and optionally computes accuracy using an external classifier.
    </summary>
    <param name="epoch">Epoch index (for logging).</param>
    <param name="generator_model">Generator instance.</param>
    <param name="ext_classifier">External classifier for accuracy evaluation (optional).</param>
    <param name="num_metrics_samples">Number of samples for FID/IS.</param>
    <param name="num_accuracy_samples">Number of samples for accuracy testing.</param>
    <param name="ref_mnist_png_path">Path to reference MNIST PNG images.</param>
    <param name="current_device">Device in use (CPU/GPU).</param>
    <returns>
        tuple(fid_score, is_score_mean, classification_accuracy)
        fid_score: Frechet Inception Distance value.
        is_score_mean: Mean Inception Score.
        classification_accuracy: Accuracy of the generated images.
    </returns>
    """
    generator_model.eval()
    if ext_classifier: ext_classifier.eval()

    fid_score, is_score_mean, classification_accuracy = float('nan'), float('nan'), float('nan')
    temp_gen_img_dir = tempfile.mkdtemp()

    try:
        print(f"  Generating {num_metrics_samples} samples for FID/IS into '{temp_gen_img_dir}'...")
        img_counter = 0
        with torch.no_grad():
            num_batches_needed = (num_metrics_samples + MICRO_BATCH_SIZE - 1) // MICRO_BATCH_SIZE
            for _ in range(num_batches_needed):
                if img_counter >= num_metrics_samples: break
                batch_z = torch.randn(MICRO_BATCH_SIZE, Z_DIM, device=current_device)
                batch_labels_fid = torch.randint(0, NUM_CLASSES, (MICRO_BATCH_SIZE,), device=current_device)
                gen_imgs_fid_classic, _ = generator_model(batch_z, batch_labels_fid)
                for img_tensor in gen_imgs_fid_classic.detach().cpu():
                    if img_counter >= num_metrics_samples: break
                    save_image(img_tensor,
                               os.path.join(temp_gen_img_dir, f"fid_img_{img_counter:05d}.png"),
                               normalize=True)
                    img_counter += 1

        if img_counter >= num_metrics_samples:
            print(f"  Saved {img_counter} images for metrics. Computing FID/IS via torch-fidelity...")
            metrics_dict = calculate_metrics(
                input1=temp_gen_img_dir,
                input2=ref_mnist_png_path,
                cuda=torch.cuda.is_available(),
                isc=True, fid=True,
                batch_size=FIDELITY_BATCH_SIZE,
                num_workers=FIDELITY_NUM_WORKERS,
                verbose=False
            )
            fid_score = metrics_dict.get('frechet_inception_distance', float('nan'))
            is_score_mean = metrics_dict.get('inception_score_mean', float('nan'))
            print(f"  FID: {fid_score:.4f}, IS (mean): {is_score_mean:.4f}")
        else:
            print(f"  Not enough generated samples ({img_counter}/{num_metrics_samples}) for FID/IS.")

    except Exception as e:
        print(f"  ERROR while computing FID/IS: {e}")
    finally:
        if os.path.exists(temp_gen_img_dir):
            shutil.rmtree(temp_gen_img_dir)

    if ext_classifier:
        try:
            print(f"  Generating {num_accuracy_samples} samples for classification test...")
            all_preds, all_targets = [], []
            num_samples_per_class_acc = num_accuracy_samples // NUM_CLASSES
            with torch.no_grad():
                for digit_class in range(NUM_CLASSES):
                    acc_z = torch.randn(num_samples_per_class_acc, Z_DIM, device=current_device)
                    acc_target_labels = torch.full((num_samples_per_class_acc,), digit_class, dtype=torch.long, device=current_device)
                    gen_imgs_acc_classic, _ = generator_model(acc_z, acc_target_labels)
                    outputs = ext_classifier(gen_imgs_acc_classic)
                    _, predicted = torch.max(outputs.data, 1)
                    all_preds.append(predicted.cpu())
                    all_targets.append(acc_target_labels.cpu())

            if all_preds:
                all_preds_tensor = torch.cat(all_preds)
                all_targets_tensor = torch.cat(all_targets)
                correct_predictions = (all_preds_tensor == all_targets_tensor).sum().item()
                total_for_accuracy = len(all_targets_tensor)
                if total_for_accuracy > 0:
                    classification_accuracy = 100. * correct_predictions / total_for_accuracy
                    print(f"  Classification accuracy on generated images: {classification_accuracy:.2f}%")
                else:
                    print("  No samples were generated for accuracy computation.")
            else:
                print("  No predictions were generated for accuracy computation.")

        except Exception as e:
            print(f"  ERROR while computing classification accuracy: {e}")
    else:
        print("  External classifier not available; accuracy will not be computed.")

    generator_model.train()
    return fid_score, is_score_mean, classification_accuracy
# Out:
# Directory '/content/MNIST_data/MNIST_train_images_png' already exists and appears complete. Skipping PNG generation.
# MNIST training dataset loaded: 60000 samples.

# %%
#@title 7. Initialize models, losses, and optimizers

"""
<summary>
Initialize models (discriminator, hybrid generator, external MNIST classifier),
loss functions, optimizers, and logging/visualization variables for training the hybrid quantum–classical ACGAN architecture.
</summary>
"""

discriminator = Discriminator(num_classes=NUM_CLASSES, img_channels=IMG_CHANNELS).to(device, memory_format=MEMORY_FORMAT)
discriminator.apply(weights_init)

hybrid_generator = HybridGenerator(
    z_dim=Z_DIM,
    num_classes=NUM_CLASSES,
    img_channels=IMG_CHANNELS,
    ansatz_instance=ansatz,
    list_of_hamiltonians=H_op_list,
    qiskit_estimator=aer_estimator,
    lambda_vqer_coeff=LAMBDA_VQER
).to(device)
hybrid_generator.apply(weights_init)

mnist_classifier_eval = MnistClassifier().to(device)
if os.path.exists(CLASSIFIER_PATH):
    try:
        mnist_classifier_eval.load_state_dict(torch.load(CLASSIFIER_PATH, map_location=device))
        mnist_classifier_eval.eval()
        print(f"External MNIST classifier '{CLASSIFIER_PATH}' loaded successfully.")
    except Exception as e:
        print(f"ERROR while loading external classifier: {e}. Accuracy will not be computed.")
        mnist_classifier_eval = None
else:
    print(f"External MNIST classifier '{CLASSIFIER_PATH}' not found. Accuracy will not be computed.")
    mnist_classifier_eval = None

adversarial_loss_fn = nn.BCELoss().to(device)
auxiliary_loss_fn = nn.CrossEntropyLoss().to(device)

optimizer_G = optim.Adam(hybrid_generator.parameters(), lr=LEARNING_RATE_G, betas=(BETA1, BETA2))
optimizer_D = optim.Adam(discriminator.parameters(), lr=LEARNING_RATE_D, betas=(BETA1, BETA2))

num_fixed_samples_display = NUM_CLASSES * 5
g_eval = torch.Generator(device=device).manual_seed(SEED + 999)
fixed_z = torch.randn(num_fixed_samples_display, Z_DIM, device=device, generator=g_eval)
fixed_labels_list = []
for i in range(NUM_CLASSES):
    fixed_labels_list.extend([i] * 5)
fixed_labels = torch.LongTensor(fixed_labels_list).to(device)

training_logs = {
    'iterations': [], 'epochs': [],
    'g_loss': [], 'g_adv_loss': [], 'g_aux_loss': [], 'g_vqe_loss': [], 'avg_energy': [],
    'd_loss': [], 'd_real_adv_loss': [], 'd_fake_adv_loss': [], 'd_real_aux_loss': [], 'd_fake_aux_loss': [],
    'eval_epochs': [], 'fid_scores': [], 'is_scores': [], 'classification_accuracy': []
}
best_fid = float('inf')
best_epoch = -1

print("Initialization of models, losses, and optimizers completed.")

def count_parameters(model):
    """
    <summary>
    Count and return the number of trainable parameters in a given model.
    </summary>
    <param name="model">A PyTorch model.</param>
    <returns>Total number of trainable parameters.</returns>
    """
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Trainable parameters in Hybrid Generator: {count_parameters(hybrid_generator):,}")
print(f"Trainable parameters in Discriminator: {count_parameters(discriminator):,}")
if mnist_classifier_eval:
    print(f"Trainable parameters in Eval Classifier: {count_parameters(mnist_classifier_eval):,}")
# Out:
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# External MNIST classifier '/content/mnist_classifier.pth' loaded successfully.
# Initialization of models, losses, and optimizers completed.
# Trainable parameters in Hybrid Generator: 1,813,853
# Trainable parameters in Discriminator: 472,843
# Trainable parameters in Eval Classifier: 3,274,634

# %% [markdown]
# ## 7. Training Loop
#
# The training alternates between discriminator and generator optimization with gradient accumulation.
#
# ### Training Parameters (RUN2)
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | `SEED` | **2025** | Random seed for reproducibility |
# | `NUM_EPOCHS` | 10 | Total training epochs |
# | `EFFECTIVE_BATCH_SIZE` | 64 | Batch size after accumulation |
# | `MICRO_BATCH_SIZE` | 32 | Per-step batch size |
# | `LEARNING_RATE_G/D` | $2 \times 10^{-4}$ | Adam learning rate |
# | `BETA1, BETA2` | 0.5, 0.999 | Adam momentum parameters |
# | `LABEL_SMOOTHING` | 0.9 | One-sided label smoothing for real images |
# | `EVAL_INTERVAL` | 1 | Evaluate metrics every epoch |
#
# ### Quantum Hyperparameters
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | `N_QUBITS` | 4 | Number of qubits in ansatz |
# | `ANSAETZ_REPS` | 1 | EfficientSU2 repetition layers |
# | `LAMBDA_VQER` | 0.1 | VQE regularization weight |
# | `ISING_J` | 1.0 | ZZ coupling strength |
# | `ISING_H_GLOBAL` | 0.1 | Base local field coefficient |
#
# ### Loss Functions
#
# **Generator Total Loss:**
# $$\mathcal{L}_G = \mathcal{L}_{G,\text{adv}} + \mathcal{L}_{G,\text{aux}} + \lambda_{\text{vqer}} \cdot E_c$$
#
# **Discriminator Total Loss:**
# $$\mathcal{L}_D = \frac{1}{2}(\mathcal{L}_{D,\text{real}}^{\text{adv}} + \mathcal{L}_{D,\text{fake}}^{\text{adv}}) + \frac{1}{2}(\mathcal{L}_{D,\text{real}}^{\text{aux}} + \mathcal{L}_{D,\text{fake}}^{\text{aux}})$$

# %%
#@title 8. Hybrid ACGAN Training Loop

"""
<summary>
Training loop for the hybrid ACGAN model with quantum VQE regularization.
Includes the main epoch/minibatch iterations, alternating training of discriminator and generator with gradient accumulation, logging of losses and metrics, saving samples and models, and periodic evaluation of FID/IS/classification accuracy.
</summary>
"""

print("Starting Hybrid ACGAN training...")
total_iterations = 0
start_time_total = time.time()

for epoch in range(NUM_EPOCHS):
    epoch_start_time = time.time()
    epoch_g_loss_sum, epoch_g_adv_sum, epoch_g_aux_sum, epoch_g_vqe_sum, epoch_e_c_sum = 0,0,0,0,0
    epoch_d_loss_sum, epoch_d_real_adv_sum, epoch_d_fake_adv_sum, epoch_d_real_aux_sum, epoch_d_fake_aux_sum = 0,0,0,0,0

    hybrid_generator.train()
    discriminator.train()

    optimizer_G.zero_grad()
    optimizer_D.zero_grad()

    for i, (real_imgs_batch, real_class_labels_batch) in enumerate(train_loader):
        current_batch_size = real_imgs_batch.size(0)
        real_imgs_batch = real_imgs_batch.to(device, memory_format=MEMORY_FORMAT if device.type == 'cuda' else torch.contiguous_format)
        real_class_labels_batch = real_class_labels_batch.to(device)

        real_targets_adv = torch.full((current_batch_size, 1), LABEL_SMOOTHING, device=device, dtype=torch.float32)
        fake_targets_adv = torch.full((current_batch_size, 1), 0.0, device=device, dtype=torch.float32)

        real_validity_D, real_class_logits_D = discriminator(real_imgs_batch)
        d_real_adv = adversarial_loss_fn(real_validity_D, real_targets_adv)
        d_real_aux = auxiliary_loss_fn(real_class_logits_D, real_class_labels_batch)

        z_noise_D = torch.randn(current_batch_size, Z_DIM, device=device)
        gen_class_labels_D = torch.randint(0, NUM_CLASSES, (current_batch_size,), device=device, dtype=torch.long)
        fake_imgs_classic_D, _ = hybrid_generator(z_noise_D, gen_class_labels_D)
        fake_validity_D, fake_class_logits_D = discriminator(fake_imgs_classic_D.detach())
        d_fake_adv = adversarial_loss_fn(fake_validity_D, fake_targets_adv)
        d_fake_aux = auxiliary_loss_fn(fake_class_logits_D, gen_class_labels_D)

        d_adv_combined = (d_real_adv + d_fake_adv) / 2
        d_aux_combined = (d_real_aux + d_fake_aux) / 2
        d_loss = (d_adv_combined + d_aux_combined) / ACCUMULATION_STEPS

        d_loss.backward()

        epoch_d_loss_sum += d_loss.item() * ACCUMULATION_STEPS
        epoch_d_real_adv_sum += d_real_adv.item()
        epoch_d_fake_adv_sum += d_fake_adv.item()
        epoch_d_real_aux_sum += d_real_aux.item()
        epoch_d_fake_aux_sum += d_fake_aux.item()

        z_noise_G = torch.randn(current_batch_size, Z_DIM, device=device)
        gen_class_labels_G = torch.randint(0, NUM_CLASSES, (current_batch_size,), device=device, dtype=torch.long)
        fake_imgs_classic_G, E_c_G = hybrid_generator(z_noise_G, gen_class_labels_G)
        fake_validity_G, fake_class_logits_G = discriminator(fake_imgs_classic_G)
        g_real_targets = torch.ones((current_batch_size, 1), device=device, dtype=torch.float32)
        g_adv = adversarial_loss_fn(fake_validity_G, g_real_targets)
        g_aux = auxiliary_loss_fn(fake_class_logits_G, gen_class_labels_G)
        g_vqe_regularizer = hybrid_generator.lambda_vqer * E_c_G.mean()
        g_loss_gan_part = g_adv + g_aux
        g_loss = (g_loss_gan_part + g_vqe_regularizer) / ACCUMULATION_STEPS

        g_loss.backward()

        epoch_g_loss_sum += g_loss.item() * ACCUMULATION_STEPS
        epoch_g_adv_sum += g_adv.item()
        epoch_g_aux_sum += g_aux.item()
        epoch_g_vqe_sum += g_vqe_regularizer.item()
        epoch_e_c_sum += E_c_G.mean().item()

        if (i + 1) % ACCUMULATION_STEPS == 0 or (i + 1) == len(train_loader):
            optimizer_D.step()
            optimizer_D.zero_grad()
            optimizer_G.step()
            optimizer_G.zero_grad()

        total_iterations += 1
        if total_iterations % LOG_INTERVAL == 0:
            print(f"[Epoch {epoch+1}/{NUM_EPOCHS}] [Batch {i+1}/{len(train_loader)}] [Iter {total_iterations}]")
            print(f"  G loss: {g_loss.item()*ACCUMULATION_STEPS:.4f} (Adv: {g_adv.item():.4f}, Aux: {g_aux.item():.4f}, VQE_reg: {g_vqe_regularizer.item():.4f}, E_c: {E_c_G.mean().item():.4f})")
            print(f"  D loss: {d_loss.item()*ACCUMULATION_STEPS:.4f} (RealAdv: {d_real_adv.item():.4f}, FakeAdv: {d_fake_adv.item():.4f}, RealAux: {d_real_aux.item():.4f}, FakeAux: {d_fake_aux.item():.4f})")
            training_logs['iterations'].append(total_iterations)
            training_logs['g_loss'].append(g_loss.item()*ACCUMULATION_STEPS)
            training_logs['g_adv_loss'].append(g_adv.item())
            training_logs['g_aux_loss'].append(g_aux.item())
            training_logs['g_vqe_loss'].append(g_vqe_regularizer.item())
            training_logs['avg_energy'].append(E_c_G.mean().item())
            training_logs['d_loss'].append(d_loss.item()*ACCUMULATION_STEPS)
            training_logs['d_real_adv_loss'].append(d_real_adv.item())
            training_logs['d_fake_adv_loss'].append(d_fake_adv.item())
            training_logs['d_real_aux_loss'].append(d_real_aux.item())
            training_logs['d_fake_aux_loss'].append(d_fake_aux.item())

    epoch_duration = time.time() - epoch_start_time
    num_batches_in_epoch = len(train_loader)
    avg_g_loss = epoch_g_loss_sum / num_batches_in_epoch
    avg_g_adv = epoch_g_adv_sum / num_batches_in_epoch
    avg_g_aux = epoch_g_aux_sum / num_batches_in_epoch
    avg_g_vqe = epoch_g_vqe_sum / num_batches_in_epoch
    avg_E_c = epoch_e_c_sum / num_batches_in_epoch

    avg_d_loss = epoch_d_loss_sum / num_batches_in_epoch
    avg_d_real_adv = epoch_d_real_adv_sum / num_batches_in_epoch
    avg_d_fake_adv = epoch_d_fake_adv_sum / num_batches_in_epoch
    avg_d_real_aux = epoch_d_real_aux_sum / num_batches_in_epoch
    avg_d_fake_aux = epoch_d_fake_aux_sum / num_batches_in_epoch

    print(f"\n--- End of Epoch {epoch+1}/{NUM_EPOCHS} (Duration: {epoch_duration:.2f}s) ---")
    print(f"  Avg G Loss: {avg_g_loss:.4f} (Adv: {avg_g_adv:.4f}, Aux: {avg_g_aux:.4f}, VQE_reg: {avg_g_vqe:.4f}, Avg E_c: {avg_E_c:.4f})")
    print(f"  Avg D Loss: {avg_d_loss:.4f} (R_Adv: {avg_d_real_adv:.4f}, F_Adv: {avg_d_fake_adv:.4f}, R_Aux: {avg_d_real_aux:.4f}, F_Aux: {avg_d_fake_aux:.4f})")

    training_logs['epochs'].append(epoch + 1)

    if (epoch + 1) % SAVE_SAMPLES_INTERVAL == 0 or (epoch + 1) == NUM_EPOCHS:
        save_generated_samples(epoch + 1, hybrid_generator, fixed_z, fixed_labels, OUTPUT_DIR_IMAGES)
        print(f"  Samples for epoch {epoch+1} saved.")

    if (epoch + 1) % EVAL_INTERVAL == 0 or (epoch + 1) == NUM_EPOCHS:
        print(f"  Running evaluation for epoch {epoch+1}...")
        fid, is_mean, acc = evaluate_hybrid_model(
            epoch + 1, hybrid_generator, mnist_classifier_eval,
            NUM_SAMPLES_FOR_METRICS, NUM_SAMPLES_FOR_ACCURACY,
            MNIST_TRAIN_IMAGES_PATH, device
        )
        training_logs['eval_epochs'].append(epoch + 1)
        training_logs['fid_scores'].append(fid)
        training_logs['is_scores'].append(is_mean)
        training_logs['classification_accuracy'].append(acc)

        if fid is not None and not np.isnan(fid) and fid < best_fid:
            best_fid = fid
            best_epoch = epoch + 1
            torch.save(hybrid_generator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_best.pth'))
            torch.save(discriminator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'discriminator_best.pth'))
            print(f"  *** New best FID: {best_fid:.4f} at epoch {best_epoch}. Models saved. ***")

    with open(LOG_FILE, 'wb') as f:
        pickle.dump(training_logs, f)
    print("-" * 60)

total_training_time = time.time() - start_time_total
print(f"\nTraining finished in {total_training_time // 3600:.0f}h {(total_training_time % 3600) // 60:.0f}m {total_training_time % 60:.0f}s")
print(f"Best FID achieved: {best_fid:.4f} at epoch {best_epoch}.")

torch.save(hybrid_generator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_final.pth'))
torch.save(discriminator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'discriminator_final.pth'))
print(f"Final models saved to '{OUTPUT_DIR_MODELS}'.")
# Out:
# Starting Hybrid ACGAN training...
# [Epoch 1/10] [Batch 50/1875] [Iter 50]
#   G loss: 0.1053 (Adv: 0.3522, Aux: 0.1126, VQE_reg: -0.3595, E_c: -3.5952)
#   D loss: 1.4723 (RealAdv: 0.3641, FakeAdv: 1.3108, RealAux: 1.0431, FakeAux: 0.2266)
# [Epoch 1/10] [Batch 100/1875] [Iter 100]
#   G loss: 0.1641 (Adv: 0.4860, Aux: 0.0370, VQE_reg: -0.3589, E_c: -3.5887)
#   D loss: 0.9991 (RealAdv: 0.4609, FakeAdv: 1.0873, RealAux: 0.4227, FakeAux: 0.0271)
# [Epoch 1/10] [Batch 150/1875] [Iter 150]
#   G loss: 0.1198 (Adv: 0.4574, Aux: 0.0183, VQE_reg: -0.3559, E_c: -3.5587)
#   D loss: 0.9511 (RealAdv: 0.3909, FakeAdv: 1.0681, RealAux: 0.4199, FakeAux: 0.0234)
# [Epoch 1/10] [Batch 200/1875] [Iter 200]
#   G loss: -0.0472 (Adv: 0.2979, Aux: 0.0130, VQE_reg: -0.3581, E_c: -3.5807)
#   D loss: 1.1693 (RealAdv: 0.3527, FakeAdv: 1.5181, RealAux: 0.4495, FakeAux: 0.0183)
# [Epoch 1/10] [Batch 250/1875] [Iter 250]
#   G loss: 0.0260 (Adv: 0.3554, Aux: 0.0252, VQE_reg: -0.3547, E_c: -3.5470)
#   D loss: 1.1158 (RealAdv: 0.3524, FakeAdv: 1.3419, RealAux: 0.5228, FakeAux: 0.0145)
# [Epoch 1/10] [Batch 300/1875] [Iter 300]
#   G loss: 0.0638 (Adv: 0.4070, Aux: 0.0150, VQE_reg: -0.3582, E_c: -3.5817)
#   D loss: 0.9515 (RealAdv: 0.4059, FakeAdv: 1.1682, RealAux: 0.3177, FakeAux: 0.0113)
# [Epoch 1/10] [Batch 350/1875] [Iter 350]
#   G loss: -0.1038 (Adv: 0.2385, Aux: 0.0132, VQE_reg: -0.3554, E_c: -3.5538)
#   D loss: 1.0802 (RealAdv: 0.3362, FakeAdv: 1.5563, RealAux: 0.2576, FakeAux: 0.0104)
# [Epoch 1/10] [Batch 400/1875] [Iter 400]
#   G loss: 0.0446 (Adv: 0.3620, Aux: 0.0389, VQE_reg: -0.3563, E_c: -3.5627)
#   D loss: 0.9774 (RealAdv: 0.3860, FakeAdv: 1.2354, RealAux: 0.3238, FakeAux: 0.0096)
# [Epoch 1/10] [Batch 450/1875] [Iter 450]
#   G loss: 0.1095 (Adv: 0.4446, Aux: 0.0205, VQE_reg: -0.3557, E_c: -3.5567)
#   D loss: 0.8223 (RealAdv: 0.4260, FakeAdv: 1.0493, RealAux: 0.1487, FakeAux: 0.0206)
# [Epoch 1/10] [Batch 500/1875] [Iter 500]
#   G loss: 0.0072 (Adv: 0.3331, Aux: 0.0298, VQE_reg: -0.3557, E_c: -3.5574)
#   D loss: 1.0481 (RealAdv: 0.3954, FakeAdv: 1.2910, RealAux: 0.3835, FakeAux: 0.0264)
# [Epoch 1/10] [Batch 550/1875] [Iter 550]
#   G loss: -0.1518 (Adv: 0.1955, Aux: 0.0091, VQE_reg: -0.3563, E_c: -3.5634)
#   D loss: 1.1290 (RealAdv: 0.3375, FakeAdv: 1.7203, RealAux: 0.1886, FakeAux: 0.0117)
# [Epoch 1/10] [Batch 600/1875] [Iter 600]
#   G loss: 0.0332 (Adv: 0.3853, Aux: 0.0089, VQE_reg: -0.3609, E_c: -3.6092)
#   D loss: 0.9073 (RealAdv: 0.3729, FakeAdv: 1.1602, RealAux: 0.2762, FakeAux: 0.0052)
# [Epoch 1/10] [Batch 650/1875] [Iter 650]
#   G loss: -0.0086 (Adv: 0.3403, Aux: 0.0051, VQE_reg: -0.3539, E_c: -3.5394)
#   D loss: 1.0489 (RealAdv: 0.3506, FakeAdv: 1.4357, RealAux: 0.3020, FakeAux: 0.0094)
# [Epoch 1/10] [Batch 700/1875] [Iter 700]
#   G loss: 0.0268 (Adv: 0.3752, Aux: 0.0077, VQE_reg: -0.3561, E_c: -3.5609)
#   D loss: 0.8523 (RealAdv: 0.4019, FakeAdv: 1.1580, RealAux: 0.1341, FakeAux: 0.0105)
# [Epoch 1/10] [Batch 750/1875] [Iter 750]
#   G loss: 0.0126 (Adv: 0.3655, Aux: 0.0028, VQE_reg: -0.3556, E_c: -3.5557)
#   D loss: 0.8419 (RealAdv: 0.3775, FakeAdv: 1.1645, RealAux: 0.1341, FakeAux: 0.0076)
# [Epoch 1/10] [Batch 800/1875] [Iter 800]
#   G loss: -0.0119 (Adv: 0.3206, Aux: 0.0258, VQE_reg: -0.3583, E_c: -3.5830)
#   D loss: 0.9742 (RealAdv: 0.3554, FakeAdv: 1.5600, RealAux: 0.0283, FakeAux: 0.0047)
# [Epoch 1/10] [Batch 850/1875] [Iter 850]
#   G loss: -0.1212 (Adv: 0.2342, Aux: 0.0063, VQE_reg: -0.3617, E_c: -3.6168)
#   D loss: 1.0131 (RealAdv: 0.3447, FakeAdv: 1.6150, RealAux: 0.0622, FakeAux: 0.0043)
# [Epoch 1/10] [Batch 900/1875] [Iter 900]
#   G loss: -0.0025 (Adv: 0.3500, Aux: 0.0078, VQE_reg: -0.3603, E_c: -3.6029)
#   D loss: 0.9901 (RealAdv: 0.3743, FakeAdv: 1.3046, RealAux: 0.2964, FakeAux: 0.0049)
# [Epoch 1/10] [Batch 950/1875] [Iter 950]
#   G loss: 0.0031 (Adv: 0.3487, Aux: 0.0111, VQE_reg: -0.3567, E_c: -3.5668)
#   D loss: 0.9684 (RealAdv: 0.3876, FakeAdv: 1.2080, RealAux: 0.3361, FakeAux: 0.0050)
# [Epoch 1/10] [Batch 1000/1875] [Iter 1000]
#   G loss: 0.0383 (Adv: 0.3903, Aux: 0.0062, VQE_reg: -0.3582, E_c: -3.5821)
#   D loss: 1.0032 (RealAdv: 0.3967, FakeAdv: 1.2212, RealAux: 0.3545, FakeAux: 0.0339)
# [Epoch 1/10] [Batch 1050/1875] [Iter 1050]
#   G loss: -0.0479 (Adv: 0.3043, Aux: 0.0062, VQE_reg: -0.3584, E_c: -3.5837)
#   D loss: 0.9586 (RealAdv: 0.3604, FakeAdv: 1.3939, RealAux: 0.1538, FakeAux: 0.0091)
# [Epoch 1/10] [Batch 1100/1875] [Iter 1100]
#   G loss: -0.0557 (Adv: 0.2902, Aux: 0.0103, VQE_reg: -0.3562, E_c: -3.5621)
#   D loss: 0.9459 (RealAdv: 0.3654, FakeAdv: 1.1933, RealAux: 0.3251, FakeAux: 0.0080)
# [Epoch 1/10] [Batch 1150/1875] [Iter 1150]
#   G loss: 0.0808 (Adv: 0.4374, Aux: 0.0050, VQE_reg: -0.3616, E_c: -3.6156)
#   D loss: 0.8124 (RealAdv: 0.4089, FakeAdv: 1.0835, RealAux: 0.1053, FakeAux: 0.0271)
# [Epoch 1/10] [Batch 1200/1875] [Iter 1200]
#   G loss: 0.0058 (Adv: 0.3587, Aux: 0.0065, VQE_reg: -0.3593, E_c: -3.5935)
#   D loss: 1.0249 (RealAdv: 0.3643, FakeAdv: 1.3961, RealAux: 0.2854, FakeAux: 0.0041)
# [Epoch 1/10] [Batch 1250/1875] [Iter 1250]
#   G loss: -0.0411 (Adv: 0.3040, Aux: 0.0129, VQE_reg: -0.3579, E_c: -3.5793)
#   D loss: 0.8872 (RealAdv: 0.3774, FakeAdv: 1.3569, RealAux: 0.0318, FakeAux: 0.0082)
# [Epoch 1/10] [Batch 1300/1875] [Iter 1300]
#   G loss: -0.0391 (Adv: 0.3132, Aux: 0.0068, VQE_reg: -0.3591, E_c: -3.5911)
#   D loss: 0.8501 (RealAdv: 0.3719, FakeAdv: 1.2840, RealAux: 0.0381, FakeAux: 0.0062)
# [Epoch 1/10] [Batch 1350/1875] [Iter 1350]
#   G loss: -0.0542 (Adv: 0.2987, Aux: 0.0029, VQE_reg: -0.3558, E_c: -3.5578)
#   D loss: 0.8912 (RealAdv: 0.4047, FakeAdv: 1.2359, RealAux: 0.1362, FakeAux: 0.0055)
# [Epoch 1/10] [Batch 1400/1875] [Iter 1400]
#   G loss: 0.1197 (Adv: 0.4713, Aux: 0.0066, VQE_reg: -0.3583, E_c: -3.5825)
#   D loss: 0.9410 (RealAdv: 0.3874, FakeAdv: 1.3504, RealAux: 0.1278, FakeAux: 0.0164)
# [Epoch 1/10] [Batch 1450/1875] [Iter 1450]
#   G loss: 0.0198 (Adv: 0.3695, Aux: 0.0064, VQE_reg: -0.3561, E_c: -3.5608)
#   D loss: 0.8363 (RealAdv: 0.3790, FakeAdv: 1.2071, RealAux: 0.0792, FakeAux: 0.0074)
# [Epoch 1/10] [Batch 1500/1875] [Iter 1500]
#   G loss: 0.0799 (Adv: 0.4357, Aux: 0.0035, VQE_reg: -0.3593, E_c: -3.5933)
#   D loss: 0.9461 (RealAdv: 0.3930, FakeAdv: 1.0637, RealAux: 0.4227, FakeAux: 0.0127)
# [Epoch 1/10] [Batch 1550/1875] [Iter 1550]
#   G loss: 0.0675 (Adv: 0.3784, Aux: 0.0483, VQE_reg: -0.3592, E_c: -3.5916)
#   D loss: 0.8108 (RealAdv: 0.3739, FakeAdv: 1.0527, RealAux: 0.1903, FakeAux: 0.0046)
# [Epoch 1/10] [Batch 1600/1875] [Iter 1600]
#   G loss: 0.0548 (Adv: 0.4068, Aux: 0.0072, VQE_reg: -0.3592, E_c: -3.5922)
#   D loss: 0.9473 (RealAdv: 0.3936, FakeAdv: 1.1465, RealAux: 0.3534, FakeAux: 0.0012)
# [Epoch 1/10] [Batch 1650/1875] [Iter 1650]
#   G loss: 0.0244 (Adv: 0.3780, Aux: 0.0036, VQE_reg: -0.3572, E_c: -3.5724)
#   D loss: 0.8237 (RealAdv: 0.3947, FakeAdv: 1.0673, RealAux: 0.1682, FakeAux: 0.0172)
# [Epoch 1/10] [Batch 1700/1875] [Iter 1700]
#   G loss: -0.0099 (Adv: 0.3361, Aux: 0.0145, VQE_reg: -0.3605, E_c: -3.6054)
#   D loss: 0.9105 (RealAdv: 0.3713, FakeAdv: 1.3235, RealAux: 0.1049, FakeAux: 0.0213)
# [Epoch 1/10] [Batch 1750/1875] [Iter 1750]
#   G loss: 0.0003 (Adv: 0.3538, Aux: 0.0051, VQE_reg: -0.3586, E_c: -3.5860)
#   D loss: 0.8994 (RealAdv: 0.3828, FakeAdv: 1.2828, RealAux: 0.1297, FakeAux: 0.0036)
# [Epoch 1/10] [Batch 1800/1875] [Iter 1800]
#   G loss: -0.0035 (Adv: 0.3354, Aux: 0.0163, VQE_reg: -0.3552, E_c: -3.5521)
#   D loss: 0.8328 (RealAdv: 0.3776, FakeAdv: 1.2637, RealAux: 0.0159, FakeAux: 0.0083)
# [Epoch 1/10] [Batch 1850/1875] [Iter 1850]
#   G loss: -0.0015 (Adv: 0.3540, Aux: 0.0030, VQE_reg: -0.3585, E_c: -3.5852)
#   D loss: 0.8575 (RealAdv: 0.3615, FakeAdv: 1.2314, RealAux: 0.1183, FakeAux: 0.0039)
#
# --- End of Epoch 1/10 (Duration: 5009.21s) ---
#   Avg G Loss: 0.0369 (Adv: 0.3619, Aux: 0.0329, VQE_reg: -0.3579, Avg E_c: -3.5792)
#   Avg D Loss: 0.9691 (R_Adv: 0.3815, F_Adv: 1.2743, R_Aux: 0.2487, F_Aux: 0.0338)
#   Samples for epoch 1 saved.
#   Running evaluation for epoch 1...
#   Generating 1000 samples for FID/IS into '/tmp/tmp88bpzyws'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:00<00:00, 122MB/s]
# /usr/local/lib/python3.12/dist-packages/torch_fidelity/datasets.py:16: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(img.tobytes())).view(height, width, 3)
#   FID: 117.7520, IS (mean): 2.0622
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 87.00%
#   *** New best FID: 117.7520 at epoch 1. Models saved. ***
# ------------------------------------------------------------
# [Epoch 2/10] [Batch 25/1875] [Iter 1900]
#   G loss: -0.0409 (Adv: 0.3115, Aux: 0.0053, VQE_reg: -0.3577, E_c: -3.5770)
#   D loss: 0.8635 (RealAdv: 0.3736, FakeAdv: 1.2986, RealAux: 0.0508, FakeAux: 0.0042)
# [Epoch 2/10] [Batch 75/1875] [Iter 1950]
#   G loss: 0.0546 (Adv: 0.4084, Aux: 0.0018, VQE_reg: -0.3556, E_c: -3.5556)
#   D loss: 0.8305 (RealAdv: 0.4048, FakeAdv: 1.1922, RealAux: 0.0361, FakeAux: 0.0279)
# [Epoch 2/10] [Batch 125/1875] [Iter 2000]
#   G loss: 0.0205 (Adv: 0.3673, Aux: 0.0076, VQE_reg: -0.3543, E_c: -3.5433)
#   D loss: 0.9541 (RealAdv: 0.3672, FakeAdv: 1.1880, RealAux: 0.3492, FakeAux: 0.0037)
# [Epoch 2/10] [Batch 175/1875] [Iter 2050]
#   G loss: 0.0727 (Adv: 0.3541, Aux: 0.0748, VQE_reg: -0.3562, E_c: -3.5619)
#   D loss: 0.8739 (RealAdv: 0.3561, FakeAdv: 1.3056, RealAux: 0.0702, FakeAux: 0.0160)
# [Epoch 2/10] [Batch 225/1875] [Iter 2100]
#   G loss: -0.0499 (Adv: 0.3096, Aux: 0.0017, VQE_reg: -0.3611, E_c: -3.6114)
#   D loss: 0.9129 (RealAdv: 0.3714, FakeAdv: 1.3030, RealAux: 0.1488, FakeAux: 0.0024)
# [Epoch 2/10] [Batch 275/1875] [Iter 2150]
#   G loss: 0.0144 (Adv: 0.3651, Aux: 0.0070, VQE_reg: -0.3577, E_c: -3.5770)
#   D loss: 0.8320 (RealAdv: 0.3938, FakeAdv: 1.2064, RealAux: 0.0574, FakeAux: 0.0064)
# [Epoch 2/10] [Batch 325/1875] [Iter 2200]
#   G loss: 0.0384 (Adv: 0.3426, Aux: 0.0561, VQE_reg: -0.3603, E_c: -3.6026)
#   D loss: 0.8647 (RealAdv: 0.3730, FakeAdv: 1.3200, RealAux: 0.0315, FakeAux: 0.0050)
# [Epoch 2/10] [Batch 375/1875] [Iter 2250]
#   G loss: -0.0283 (Adv: 0.3269, Aux: 0.0027, VQE_reg: -0.3579, E_c: -3.5791)
#   D loss: 0.8496 (RealAdv: 0.3762, FakeAdv: 1.2954, RealAux: 0.0220, FakeAux: 0.0057)
# [Epoch 2/10] [Batch 425/1875] [Iter 2300]
#   G loss: 0.1438 (Adv: 0.4976, Aux: 0.0047, VQE_reg: -0.3584, E_c: -3.5839)
#   D loss: 0.8618 (RealAdv: 0.4157, FakeAdv: 1.1467, RealAux: 0.1450, FakeAux: 0.0161)
# [Epoch 2/10] [Batch 475/1875] [Iter 2350]
#   G loss: -0.0253 (Adv: 0.3128, Aux: 0.0190, VQE_reg: -0.3571, E_c: -3.5710)
#   D loss: 0.9282 (RealAdv: 0.3918, FakeAdv: 1.3171, RealAux: 0.1401, FakeAux: 0.0073)
# [Epoch 2/10] [Batch 525/1875] [Iter 2400]
#   G loss: 0.0076 (Adv: 0.3593, Aux: 0.0107, VQE_reg: -0.3624, E_c: -3.6240)
#   D loss: 0.8890 (RealAdv: 0.3710, FakeAdv: 1.3241, RealAux: 0.0788, FakeAux: 0.0040)
# [Epoch 2/10] [Batch 575/1875] [Iter 2450]
#   G loss: -0.0157 (Adv: 0.3362, Aux: 0.0041, VQE_reg: -0.3559, E_c: -3.5590)
#   D loss: 0.8754 (RealAdv: 0.3562, FakeAdv: 1.3194, RealAux: 0.0728, FakeAux: 0.0023)
# [Epoch 2/10] [Batch 625/1875] [Iter 2500]
#   G loss: -0.0047 (Adv: 0.3219, Aux: 0.0298, VQE_reg: -0.3564, E_c: -3.5637)
#   D loss: 0.8831 (RealAdv: 0.3763, FakeAdv: 1.3478, RealAux: 0.0380, FakeAux: 0.0041)
# [Epoch 2/10] [Batch 675/1875] [Iter 2550]
#   G loss: -0.0093 (Adv: 0.3501, Aux: 0.0012, VQE_reg: -0.3607, E_c: -3.6065)
#   D loss: 0.7707 (RealAdv: 0.3768, FakeAdv: 1.1350, RealAux: 0.0281, FakeAux: 0.0014)
# [Epoch 2/10] [Batch 725/1875] [Iter 2600]
#   G loss: 0.0110 (Adv: 0.3651, Aux: 0.0038, VQE_reg: -0.3579, E_c: -3.5792)
#   D loss: 0.9117 (RealAdv: 0.3675, FakeAdv: 1.3652, RealAux: 0.0878, FakeAux: 0.0029)
# [Epoch 2/10] [Batch 775/1875] [Iter 2650]
#   G loss: -0.0241 (Adv: 0.3342, Aux: 0.0033, VQE_reg: -0.3616, E_c: -3.6165)
#   D loss: 0.9565 (RealAdv: 0.3690, FakeAdv: 1.4744, RealAux: 0.0574, FakeAux: 0.0122)
# [Epoch 2/10] [Batch 825/1875] [Iter 2700]
#   G loss: 0.0836 (Adv: 0.4307, Aux: 0.0095, VQE_reg: -0.3565, E_c: -3.5650)
#   D loss: 0.7888 (RealAdv: 0.4053, FakeAdv: 1.0943, RealAux: 0.0773, FakeAux: 0.0007)
# [Epoch 2/10] [Batch 875/1875] [Iter 2750]
#   G loss: 0.0022 (Adv: 0.3560, Aux: 0.0024, VQE_reg: -0.3563, E_c: -3.5627)
#   D loss: 0.8519 (RealAdv: 0.4019, FakeAdv: 1.1767, RealAux: 0.1177, FakeAux: 0.0075)
# [Epoch 2/10] [Batch 925/1875] [Iter 2800]
#   G loss: 0.0640 (Adv: 0.3901, Aux: 0.0320, VQE_reg: -0.3581, E_c: -3.5812)
#   D loss: 0.8825 (RealAdv: 0.4121, FakeAdv: 1.2553, RealAux: 0.0943, FakeAux: 0.0033)
# [Epoch 2/10] [Batch 975/1875] [Iter 2850]
#   G loss: 0.0485 (Adv: 0.4069, Aux: 0.0019, VQE_reg: -0.3602, E_c: -3.6022)
#   D loss: 0.7835 (RealAdv: 0.3836, FakeAdv: 1.1651, RealAux: 0.0128, FakeAux: 0.0055)
# [Epoch 2/10] [Batch 1025/1875] [Iter 2900]
#   G loss: -0.0125 (Adv: 0.3417, Aux: 0.0031, VQE_reg: -0.3573, E_c: -3.5726)
#   D loss: 0.8353 (RealAdv: 0.3787, FakeAdv: 1.2057, RealAux: 0.0736, FakeAux: 0.0128)
# [Epoch 2/10] [Batch 1075/1875] [Iter 2950]
#   G loss: 0.0276 (Adv: 0.3846, Aux: 0.0008, VQE_reg: -0.3578, E_c: -3.5779)
#   D loss: 0.8079 (RealAdv: 0.4001, FakeAdv: 1.2106, RealAux: 0.0040, FakeAux: 0.0010)
# [Epoch 2/10] [Batch 1125/1875] [Iter 3000]
#   G loss: -0.0025 (Adv: 0.3547, Aux: 0.0009, VQE_reg: -0.3581, E_c: -3.5814)
#   D loss: 0.7885 (RealAdv: 0.3789, FakeAdv: 1.1880, RealAux: 0.0085, FakeAux: 0.0016)
# [Epoch 2/10] [Batch 1175/1875] [Iter 3050]
#   G loss: -0.0518 (Adv: 0.3046, Aux: 0.0023, VQE_reg: -0.3587, E_c: -3.5866)
#   D loss: 0.8909 (RealAdv: 0.3646, FakeAdv: 1.3122, RealAux: 0.1041, FakeAux: 0.0008)
# [Epoch 2/10] [Batch 1225/1875] [Iter 3100]
#   G loss: 0.0919 (Adv: 0.4478, Aux: 0.0028, VQE_reg: -0.3587, E_c: -3.5874)
#   D loss: 0.8019 (RealAdv: 0.4332, FakeAdv: 1.0550, RealAux: 0.1072, FakeAux: 0.0084)
# [Epoch 2/10] [Batch 1275/1875] [Iter 3150]
#   G loss: -0.0549 (Adv: 0.2864, Aux: 0.0146, VQE_reg: -0.3558, E_c: -3.5580)
#   D loss: 0.8971 (RealAdv: 0.3701, FakeAdv: 1.1450, RealAux: 0.2771, FakeAux: 0.0020)
# [Epoch 2/10] [Batch 1325/1875] [Iter 3200]
#   G loss: 0.0121 (Adv: 0.3639, Aux: 0.0072, VQE_reg: -0.3590, E_c: -3.5898)
#   D loss: 0.8609 (RealAdv: 0.3816, FakeAdv: 1.2728, RealAux: 0.0643, FakeAux: 0.0031)
# [Epoch 2/10] [Batch 1375/1875] [Iter 3250]
#   G loss: 0.0133 (Adv: 0.3686, Aux: 0.0024, VQE_reg: -0.3577, E_c: -3.5770)
#   D loss: 0.8268 (RealAdv: 0.3704, FakeAdv: 1.2356, RealAux: 0.0325, FakeAux: 0.0150)
# [Epoch 2/10] [Batch 1425/1875] [Iter 3300]
#   G loss: -0.0062 (Adv: 0.3471, Aux: 0.0051, VQE_reg: -0.3584, E_c: -3.5836)
#   D loss: 0.8155 (RealAdv: 0.3898, FakeAdv: 1.2185, RealAux: 0.0210, FakeAux: 0.0016)
# [Epoch 2/10] [Batch 1475/1875] [Iter 3350]
#   G loss: -0.0456 (Adv: 0.3084, Aux: 0.0014, VQE_reg: -0.3553, E_c: -3.5533)
#   D loss: 0.8642 (RealAdv: 0.4036, FakeAdv: 1.3142, RealAux: 0.0076, FakeAux: 0.0030)
# [Epoch 2/10] [Batch 1525/1875] [Iter 3400]
#   G loss: -0.0199 (Adv: 0.3319, Aux: 0.0023, VQE_reg: -0.3542, E_c: -3.5417)
#   D loss: 0.7858 (RealAdv: 0.4154, FakeAdv: 1.1307, RealAux: 0.0232, FakeAux: 0.0023)
# [Epoch 2/10] [Batch 1575/1875] [Iter 3450]
#   G loss: -0.0929 (Adv: 0.2575, Aux: 0.0110, VQE_reg: -0.3615, E_c: -3.6150)
#   D loss: 0.9798 (RealAdv: 0.3759, FakeAdv: 1.5143, RealAux: 0.0675, FakeAux: 0.0019)
# [Epoch 2/10] [Batch 1625/1875] [Iter 3500]
#   G loss: -0.0214 (Adv: 0.3348, Aux: 0.0031, VQE_reg: -0.3593, E_c: -3.5930)
#   D loss: 0.9762 (RealAdv: 0.3655, FakeAdv: 1.3481, RealAux: 0.2255, FakeAux: 0.0133)
# [Epoch 2/10] [Batch 1675/1875] [Iter 3550]
#   G loss: 0.0052 (Adv: 0.3667, Aux: 0.0008, VQE_reg: -0.3624, E_c: -3.6237)
#   D loss: 0.8303 (RealAdv: 0.3805, FakeAdv: 1.2630, RealAux: 0.0160, FakeAux: 0.0011)
# [Epoch 2/10] [Batch 1725/1875] [Iter 3600]
#   G loss: 0.0135 (Adv: 0.3660, Aux: 0.0046, VQE_reg: -0.3570, E_c: -3.5701)
#   D loss: 0.9116 (RealAdv: 0.3975, FakeAdv: 1.3281, RealAux: 0.0914, FakeAux: 0.0064)
# [Epoch 2/10] [Batch 1775/1875] [Iter 3650]
#   G loss: -0.0327 (Adv: 0.3238, Aux: 0.0015, VQE_reg: -0.3579, E_c: -3.5794)
#   D loss: 0.9495 (RealAdv: 0.3774, FakeAdv: 1.3777, RealAux: 0.1385, FakeAux: 0.0055)
# [Epoch 2/10] [Batch 1825/1875] [Iter 3700]
#   G loss: 0.0224 (Adv: 0.3759, Aux: 0.0074, VQE_reg: -0.3610, E_c: -3.6096)
#   D loss: 0.8775 (RealAdv: 0.3816, FakeAdv: 1.1248, RealAux: 0.2458, FakeAux: 0.0028)
# [Epoch 2/10] [Batch 1875/1875] [Iter 3750]
#   G loss: 0.0215 (Adv: 0.3673, Aux: 0.0128, VQE_reg: -0.3586, E_c: -3.5858)
#   D loss: 0.8424 (RealAdv: 0.3898, FakeAdv: 1.2063, RealAux: 0.0858, FakeAux: 0.0030)
#
# --- End of Epoch 2/10 (Duration: 5010.46s) ---
#   Avg G Loss: 0.0047 (Adv: 0.3552, Aux: 0.0074, VQE_reg: -0.3580, Avg E_c: -3.5798)
#   Avg D Loss: 0.8702 (R_Adv: 0.3814, F_Adv: 1.2549, R_Aux: 0.0975, F_Aux: 0.0067)
#   Samples for epoch 2 saved.
#   Running evaluation for epoch 2...
#   Generating 1000 samples for FID/IS into '/tmp/tmp3vby2f00'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 57.6929, IS (mean): 2.0943
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 91.00%
#   *** New best FID: 57.6929 at epoch 2. Models saved. ***
# ------------------------------------------------------------
# [Epoch 3/10] [Batch 50/1875] [Iter 3800]
#   G loss: -0.0347 (Adv: 0.3196, Aux: 0.0030, VQE_reg: -0.3573, E_c: -3.5733)
#   D loss: 0.8977 (RealAdv: 0.3714, FakeAdv: 1.2936, RealAux: 0.1208, FakeAux: 0.0097)
# [Epoch 3/10] [Batch 100/1875] [Iter 3850]
#   G loss: 0.0152 (Adv: 0.3688, Aux: 0.0019, VQE_reg: -0.3555, E_c: -3.5550)
#   D loss: 0.9330 (RealAdv: 0.3852, FakeAdv: 1.2248, RealAux: 0.2537, FakeAux: 0.0024)
# [Epoch 3/10] [Batch 150/1875] [Iter 3900]
#   G loss: 0.0318 (Adv: 0.3876, Aux: 0.0015, VQE_reg: -0.3573, E_c: -3.5731)
#   D loss: 0.9465 (RealAdv: 0.3926, FakeAdv: 1.2816, RealAux: 0.2174, FakeAux: 0.0015)
# [Epoch 3/10] [Batch 200/1875] [Iter 3950]
#   G loss: -0.0324 (Adv: 0.3167, Aux: 0.0124, VQE_reg: -0.3615, E_c: -3.6145)
#   D loss: 0.8663 (RealAdv: 0.3580, FakeAdv: 1.3291, RealAux: 0.0440, FakeAux: 0.0014)
# [Epoch 3/10] [Batch 250/1875] [Iter 4000]
#   G loss: -0.0240 (Adv: 0.3269, Aux: 0.0044, VQE_reg: -0.3553, E_c: -3.5530)
#   D loss: 0.8372 (RealAdv: 0.3859, FakeAdv: 1.0964, RealAux: 0.1279, FakeAux: 0.0641)
# [Epoch 3/10] [Batch 300/1875] [Iter 4050]
#   G loss: 0.0905 (Adv: 0.4448, Aux: 0.0015, VQE_reg: -0.3558, E_c: -3.5577)
#   D loss: 0.7808 (RealAdv: 0.4313, FakeAdv: 1.0066, RealAux: 0.1234, FakeAux: 0.0004)
# [Epoch 3/10] [Batch 350/1875] [Iter 4100]
#   G loss: 0.0321 (Adv: 0.3869, Aux: 0.0012, VQE_reg: -0.3560, E_c: -3.5603)
#   D loss: 0.8638 (RealAdv: 0.4042, FakeAdv: 1.2679, RealAux: 0.0546, FakeAux: 0.0008)
# [Epoch 3/10] [Batch 400/1875] [Iter 4150]
#   G loss: 0.0291 (Adv: 0.3862, Aux: 0.0040, VQE_reg: -0.3611, E_c: -3.6109)
#   D loss: 0.8660 (RealAdv: 0.3643, FakeAdv: 1.2311, RealAux: 0.1328, FakeAux: 0.0038)
# [Epoch 3/10] [Batch 450/1875] [Iter 4200]
#   G loss: -0.0507 (Adv: 0.3019, Aux: 0.0032, VQE_reg: -0.3558, E_c: -3.5582)
#   D loss: 0.9965 (RealAdv: 0.3541, FakeAdv: 1.5122, RealAux: 0.1248, FakeAux: 0.0018)
# [Epoch 3/10] [Batch 500/1875] [Iter 4250]
#   G loss: 0.0475 (Adv: 0.3533, Aux: 0.0525, VQE_reg: -0.3583, E_c: -3.5834)
#   D loss: 0.8250 (RealAdv: 0.4020, FakeAdv: 1.1670, RealAux: 0.0373, FakeAux: 0.0438)
# [Epoch 3/10] [Batch 550/1875] [Iter 4300]
#   G loss: 0.0087 (Adv: 0.3417, Aux: 0.0251, VQE_reg: -0.3580, E_c: -3.5804)
#   D loss: 0.9189 (RealAdv: 0.3865, FakeAdv: 1.2366, RealAux: 0.2047, FakeAux: 0.0101)
# [Epoch 3/10] [Batch 600/1875] [Iter 4350]
#   G loss: 0.0573 (Adv: 0.3484, Aux: 0.0664, VQE_reg: -0.3575, E_c: -3.5751)
#   D loss: 0.8625 (RealAdv: 0.3948, FakeAdv: 1.2728, RealAux: 0.0538, FakeAux: 0.0036)
# [Epoch 3/10] [Batch 650/1875] [Iter 4400]
#   G loss: -0.0107 (Adv: 0.3476, Aux: 0.0002, VQE_reg: -0.3586, E_c: -3.5855)
#   D loss: 0.8390 (RealAdv: 0.3690, FakeAdv: 1.2567, RealAux: 0.0513, FakeAux: 0.0010)
# [Epoch 3/10] [Batch 700/1875] [Iter 4450]
#   G loss: 0.0143 (Adv: 0.3635, Aux: 0.0123, VQE_reg: -0.3615, E_c: -3.6148)
#   D loss: 0.8311 (RealAdv: 0.4044, FakeAdv: 1.1244, RealAux: 0.1053, FakeAux: 0.0281)
# [Epoch 3/10] [Batch 750/1875] [Iter 4500]
#   G loss: 0.0086 (Adv: 0.3693, Aux: 0.0015, VQE_reg: -0.3621, E_c: -3.6214)
#   D loss: 0.8699 (RealAdv: 0.4022, FakeAdv: 1.2449, RealAux: 0.0804, FakeAux: 0.0124)
# [Epoch 3/10] [Batch 800/1875] [Iter 4550]
#   G loss: -0.0618 (Adv: 0.2878, Aux: 0.0046, VQE_reg: -0.3541, E_c: -3.5413)
#   D loss: 0.8348 (RealAdv: 0.3672, FakeAdv: 1.2516, RealAux: 0.0505, FakeAux: 0.0003)
# [Epoch 3/10] [Batch 850/1875] [Iter 4600]
#   G loss: 0.0680 (Adv: 0.4213, Aux: 0.0037, VQE_reg: -0.3570, E_c: -3.5696)
#   D loss: 0.8175 (RealAdv: 0.3946, FakeAdv: 1.2064, RealAux: 0.0304, FakeAux: 0.0035)
# [Epoch 3/10] [Batch 900/1875] [Iter 4650]
#   G loss: -0.0208 (Adv: 0.3326, Aux: 0.0034, VQE_reg: -0.3568, E_c: -3.5677)
#   D loss: 0.9032 (RealAdv: 0.3861, FakeAdv: 1.3902, RealAux: 0.0266, FakeAux: 0.0034)
# [Epoch 3/10] [Batch 950/1875] [Iter 4700]
#   G loss: -0.0073 (Adv: 0.3507, Aux: 0.0007, VQE_reg: -0.3587, E_c: -3.5873)
#   D loss: 0.8878 (RealAdv: 0.3798, FakeAdv: 1.3512, RealAux: 0.0428, FakeAux: 0.0018)
# [Epoch 3/10] [Batch 1000/1875] [Iter 4750]
#   G loss: -0.0113 (Adv: 0.3422, Aux: 0.0056, VQE_reg: -0.3592, E_c: -3.5915)
#   D loss: 0.8570 (RealAdv: 0.3912, FakeAdv: 1.3201, RealAux: 0.0024, FakeAux: 0.0004)
# [Epoch 3/10] [Batch 1050/1875] [Iter 4800]
#   G loss: -0.0377 (Adv: 0.3159, Aux: 0.0020, VQE_reg: -0.3557, E_c: -3.5571)
#   D loss: 0.8937 (RealAdv: 0.3760, FakeAdv: 1.3700, RealAux: 0.0363, FakeAux: 0.0050)
# [Epoch 3/10] [Batch 1100/1875] [Iter 4850]
#   G loss: -0.0338 (Adv: 0.3183, Aux: 0.0010, VQE_reg: -0.3530, E_c: -3.5300)
#   D loss: 0.9629 (RealAdv: 0.3647, FakeAdv: 1.4401, RealAux: 0.1202, FakeAux: 0.0008)
# [Epoch 3/10] [Batch 1150/1875] [Iter 4900]
#   G loss: 0.0937 (Adv: 0.3989, Aux: 0.0528, VQE_reg: -0.3580, E_c: -3.5799)
#   D loss: 0.7932 (RealAdv: 0.4407, FakeAdv: 1.1050, RealAux: 0.0328, FakeAux: 0.0078)
# [Epoch 3/10] [Batch 1200/1875] [Iter 4950]
#   G loss: -0.0237 (Adv: 0.3320, Aux: 0.0011, VQE_reg: -0.3569, E_c: -3.5686)
#   D loss: 0.9705 (RealAdv: 0.3867, FakeAdv: 1.3451, RealAux: 0.2083, FakeAux: 0.0008)
# [Epoch 3/10] [Batch 1250/1875] [Iter 5000]
#   G loss: 0.0056 (Adv: 0.3653, Aux: 0.0024, VQE_reg: -0.3621, E_c: -3.6210)
#   D loss: 0.8484 (RealAdv: 0.3918, FakeAdv: 1.2692, RealAux: 0.0344, FakeAux: 0.0013)
# [Epoch 3/10] [Batch 1300/1875] [Iter 5050]
#   G loss: 0.0250 (Adv: 0.3845, Aux: 0.0003, VQE_reg: -0.3598, E_c: -3.5979)
#   D loss: 0.8285 (RealAdv: 0.4251, FakeAdv: 1.2118, RealAux: 0.0199, FakeAux: 0.0003)
# [Epoch 3/10] [Batch 1350/1875] [Iter 5100]
#   G loss: -0.0029 (Adv: 0.3518, Aux: 0.0013, VQE_reg: -0.3561, E_c: -3.5607)
#   D loss: 0.7681 (RealAdv: 0.3717, FakeAdv: 1.1322, RealAux: 0.0307, FakeAux: 0.0016)
# [Epoch 3/10] [Batch 1400/1875] [Iter 5150]
#   G loss: -0.0295 (Adv: 0.3251, Aux: 0.0010, VQE_reg: -0.3556, E_c: -3.5563)
#   D loss: 0.8298 (RealAdv: 0.3847, FakeAdv: 1.2710, RealAux: 0.0036, FakeAux: 0.0004)
# [Epoch 3/10] [Batch 1450/1875] [Iter 5200]
#   G loss: 0.0224 (Adv: 0.3764, Aux: 0.0055, VQE_reg: -0.3596, E_c: -3.5955)
#   D loss: 0.8263 (RealAdv: 0.3995, FakeAdv: 1.1376, RealAux: 0.1143, FakeAux: 0.0012)
# [Epoch 3/10] [Batch 1500/1875] [Iter 5250]
#   G loss: -0.0111 (Adv: 0.3403, Aux: 0.0077, VQE_reg: -0.3591, E_c: -3.5907)
#   D loss: 0.9557 (RealAdv: 0.3874, FakeAdv: 1.2475, RealAux: 0.1875, FakeAux: 0.0890)
# [Epoch 3/10] [Batch 1550/1875] [Iter 5300]
#   G loss: -0.0480 (Adv: 0.3114, Aux: 0.0003, VQE_reg: -0.3596, E_c: -3.5961)
#   D loss: 0.8614 (RealAdv: 0.4011, FakeAdv: 1.2882, RealAux: 0.0307, FakeAux: 0.0030)
# [Epoch 3/10] [Batch 1600/1875] [Iter 5350]
#   G loss: -0.0179 (Adv: 0.3404, Aux: 0.0006, VQE_reg: -0.3589, E_c: -3.5893)
#   D loss: 0.8148 (RealAdv: 0.3812, FakeAdv: 1.1932, RealAux: 0.0551, FakeAux: 0.0002)
# [Epoch 3/10] [Batch 1650/1875] [Iter 5400]
#   G loss: -0.0364 (Adv: 0.3194, Aux: 0.0012, VQE_reg: -0.3570, E_c: -3.5703)
#   D loss: 0.8817 (RealAdv: 0.4007, FakeAdv: 1.3360, RealAux: 0.0245, FakeAux: 0.0022)
# [Epoch 3/10] [Batch 1700/1875] [Iter 5450]
#   G loss: 0.0021 (Adv: 0.3599, Aux: 0.0014, VQE_reg: -0.3593, E_c: -3.5928)
#   D loss: 0.8222 (RealAdv: 0.4044, FakeAdv: 1.1984, RealAux: 0.0395, FakeAux: 0.0020)
# [Epoch 3/10] [Batch 1750/1875] [Iter 5500]
#   G loss: -0.0143 (Adv: 0.3494, Aux: 0.0001, VQE_reg: -0.3638, E_c: -3.6384)
#   D loss: 0.8090 (RealAdv: 0.3918, FakeAdv: 1.2129, RealAux: 0.0131, FakeAux: 0.0001)
# [Epoch 3/10] [Batch 1800/1875] [Iter 5550]
#   G loss: 0.0189 (Adv: 0.3764, Aux: 0.0036, VQE_reg: -0.3611, E_c: -3.6115)
#   D loss: 0.8182 (RealAdv: 0.3905, FakeAdv: 1.2222, RealAux: 0.0131, FakeAux: 0.0106)
# [Epoch 3/10] [Batch 1850/1875] [Iter 5600]
#   G loss: 0.0044 (Adv: 0.3406, Aux: 0.0216, VQE_reg: -0.3578, E_c: -3.5784)
#   D loss: 0.8672 (RealAdv: 0.3943, FakeAdv: 1.3185, RealAux: 0.0184, FakeAux: 0.0031)
#
# --- End of Epoch 3/10 (Duration: 5020.66s) ---
#   Avg G Loss: -0.0041 (Adv: 0.3483, Aux: 0.0055, VQE_reg: -0.3579, Avg E_c: -3.5794)
#   Avg D Loss: 0.8635 (R_Adv: 0.3879, F_Adv: 1.2629, R_Aux: 0.0708, F_Aux: 0.0055)
#   Samples for epoch 3 saved.
#   Running evaluation for epoch 3...
#   Generating 1000 samples for FID/IS into '/tmp/tmp22z4jf19'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 46.8561, IS (mean): 1.9281
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 91.20%
#   *** New best FID: 46.8561 at epoch 3. Models saved. ***
# ------------------------------------------------------------
# [Epoch 4/10] [Batch 25/1875] [Iter 5650]
#   G loss: -0.0080 (Adv: 0.3471, Aux: 0.0024, VQE_reg: -0.3574, E_c: -3.5742)
#   D loss: 1.0508 (RealAdv: 0.3952, FakeAdv: 1.2912, RealAux: 0.3809, FakeAux: 0.0342)
# [Epoch 4/10] [Batch 75/1875] [Iter 5700]
#   G loss: -0.0116 (Adv: 0.3433, Aux: 0.0018, VQE_reg: -0.3568, E_c: -3.5677)
#   D loss: 0.9001 (RealAdv: 0.3803, FakeAdv: 1.3323, RealAux: 0.0871, FakeAux: 0.0005)
# [Epoch 4/10] [Batch 125/1875] [Iter 5750]
#   G loss: 0.0430 (Adv: 0.4013, Aux: 0.0005, VQE_reg: -0.3589, E_c: -3.5892)
#   D loss: 0.8375 (RealAdv: 0.4200, FakeAdv: 1.1194, RealAux: 0.1350, FakeAux: 0.0007)
# [Epoch 4/10] [Batch 175/1875] [Iter 5800]
#   G loss: -0.0122 (Adv: 0.3451, Aux: 0.0005, VQE_reg: -0.3578, E_c: -3.5783)
#   D loss: 0.9069 (RealAdv: 0.3947, FakeAdv: 1.3031, RealAux: 0.1151, FakeAux: 0.0009)
# [Epoch 4/10] [Batch 225/1875] [Iter 5850]
#   G loss: -0.0237 (Adv: 0.3336, Aux: 0.0028, VQE_reg: -0.3602, E_c: -3.6016)
#   D loss: 0.8276 (RealAdv: 0.3794, FakeAdv: 1.2673, RealAux: 0.0075, FakeAux: 0.0009)
# [Epoch 4/10] [Batch 275/1875] [Iter 5900]
#   G loss: -0.0237 (Adv: 0.3198, Aux: 0.0158, VQE_reg: -0.3593, E_c: -3.5929)
#   D loss: 0.8272 (RealAdv: 0.3901, FakeAdv: 1.2083, RealAux: 0.0453, FakeAux: 0.0107)
# [Epoch 4/10] [Batch 325/1875] [Iter 5950]
#   G loss: 0.0072 (Adv: 0.3585, Aux: 0.0056, VQE_reg: -0.3568, E_c: -3.5683)
#   D loss: 0.7898 (RealAdv: 0.3892, FakeAdv: 1.1701, RealAux: 0.0195, FakeAux: 0.0008)
# [Epoch 4/10] [Batch 375/1875] [Iter 6000]
#   G loss: 0.0169 (Adv: 0.3727, Aux: 0.0014, VQE_reg: -0.3572, E_c: -3.5720)
#   D loss: 0.8362 (RealAdv: 0.3975, FakeAdv: 1.2601, RealAux: 0.0120, FakeAux: 0.0028)
# [Epoch 4/10] [Batch 425/1875] [Iter 6050]
#   G loss: -0.0141 (Adv: 0.3455, Aux: 0.0011, VQE_reg: -0.3606, E_c: -3.6064)
#   D loss: 0.9176 (RealAdv: 0.3585, FakeAdv: 1.3450, RealAux: 0.1311, FakeAux: 0.0005)
# [Epoch 4/10] [Batch 475/1875] [Iter 6100]
#   G loss: -0.0092 (Adv: 0.3419, Aux: 0.0021, VQE_reg: -0.3532, E_c: -3.5323)
#   D loss: 0.8432 (RealAdv: 0.4116, FakeAdv: 1.2332, RealAux: 0.0356, FakeAux: 0.0061)
# [Epoch 4/10] [Batch 525/1875] [Iter 6150]
#   G loss: 0.0270 (Adv: 0.3824, Aux: 0.0005, VQE_reg: -0.3559, E_c: -3.5590)
#   D loss: 0.8573 (RealAdv: 0.3947, FakeAdv: 1.2150, RealAux: 0.1030, FakeAux: 0.0019)
# [Epoch 4/10] [Batch 575/1875] [Iter 6200]
#   G loss: -0.0844 (Adv: 0.2725, Aux: 0.0009, VQE_reg: -0.3578, E_c: -3.5780)
#   D loss: 0.9326 (RealAdv: 0.3692, FakeAdv: 1.4530, RealAux: 0.0401, FakeAux: 0.0029)
# [Epoch 4/10] [Batch 625/1875] [Iter 6250]
#   G loss: 0.0399 (Adv: 0.3906, Aux: 0.0047, VQE_reg: -0.3554, E_c: -3.5539)
#   D loss: 0.8200 (RealAdv: 0.3893, FakeAdv: 1.2421, RealAux: 0.0081, FakeAux: 0.0005)
# [Epoch 4/10] [Batch 675/1875] [Iter 6300]
#   G loss: -0.0350 (Adv: 0.3213, Aux: 0.0036, VQE_reg: -0.3598, E_c: -3.5982)
#   D loss: 0.8219 (RealAdv: 0.3659, FakeAdv: 1.2741, RealAux: 0.0020, FakeAux: 0.0017)
# [Epoch 4/10] [Batch 725/1875] [Iter 6350]
#   G loss: -0.0258 (Adv: 0.3330, Aux: 0.0005, VQE_reg: -0.3593, E_c: -3.5928)
#   D loss: 0.9452 (RealAdv: 0.3939, FakeAdv: 1.3624, RealAux: 0.1332, FakeAux: 0.0010)
# [Epoch 4/10] [Batch 775/1875] [Iter 6400]
#   G loss: 0.0006 (Adv: 0.3295, Aux: 0.0292, VQE_reg: -0.3582, E_c: -3.5816)
#   D loss: 0.9517 (RealAdv: 0.3793, FakeAdv: 1.3253, RealAux: 0.1957, FakeAux: 0.0031)
# [Epoch 4/10] [Batch 825/1875] [Iter 6450]
#   G loss: -0.0135 (Adv: 0.3427, Aux: 0.0009, VQE_reg: -0.3571, E_c: -3.5713)
#   D loss: 0.8635 (RealAdv: 0.3943, FakeAdv: 1.2942, RealAux: 0.0351, FakeAux: 0.0033)
# [Epoch 4/10] [Batch 875/1875] [Iter 6500]
#   G loss: -0.0668 (Adv: 0.2900, Aux: 0.0002, VQE_reg: -0.3570, E_c: -3.5704)
#   D loss: 0.8762 (RealAdv: 0.3941, FakeAdv: 1.2832, RealAux: 0.0742, FakeAux: 0.0010)
# [Epoch 4/10] [Batch 925/1875] [Iter 6550]
#   G loss: -0.0270 (Adv: 0.3306, Aux: 0.0009, VQE_reg: -0.3585, E_c: -3.5845)
#   D loss: 0.8809 (RealAdv: 0.4007, FakeAdv: 1.3229, RealAux: 0.0371, FakeAux: 0.0012)
# [Epoch 4/10] [Batch 975/1875] [Iter 6600]
#   G loss: -0.0160 (Adv: 0.3379, Aux: 0.0036, VQE_reg: -0.3575, E_c: -3.5752)
#   D loss: 0.8735 (RealAdv: 0.3774, FakeAdv: 1.2380, RealAux: 0.1303, FakeAux: 0.0014)
# [Epoch 4/10] [Batch 1025/1875] [Iter 6650]
#   G loss: -0.0461 (Adv: 0.3081, Aux: 0.0039, VQE_reg: -0.3582, E_c: -3.5821)
#   D loss: 0.9186 (RealAdv: 0.3687, FakeAdv: 1.4390, RealAux: 0.0221, FakeAux: 0.0074)
# [Epoch 4/10] [Batch 1075/1875] [Iter 6700]
#   G loss: -0.0135 (Adv: 0.3432, Aux: 0.0017, VQE_reg: -0.3584, E_c: -3.5839)
#   D loss: 0.8505 (RealAdv: 0.3972, FakeAdv: 1.2858, RealAux: 0.0180, FakeAux: 0.0001)
# [Epoch 4/10] [Batch 1125/1875] [Iter 6750]
#   G loss: 0.0119 (Adv: 0.3665, Aux: 0.0035, VQE_reg: -0.3581, E_c: -3.5808)
#   D loss: 0.7982 (RealAdv: 0.4042, FakeAdv: 1.0456, RealAux: 0.1459, FakeAux: 0.0006)
# [Epoch 4/10] [Batch 1175/1875] [Iter 6800]
#   G loss: -0.0379 (Adv: 0.3239, Aux: 0.0002, VQE_reg: -0.3620, E_c: -3.6201)
#   D loss: 0.8209 (RealAdv: 0.3939, FakeAdv: 1.2339, RealAux: 0.0125, FakeAux: 0.0015)
# [Epoch 4/10] [Batch 1225/1875] [Iter 6850]
#   G loss: 0.0059 (Adv: 0.3652, Aux: 0.0004, VQE_reg: -0.3597, E_c: -3.5974)
#   D loss: 0.8864 (RealAdv: 0.3970, FakeAdv: 1.2707, RealAux: 0.1050, FakeAux: 0.0002)
# [Epoch 4/10] [Batch 1275/1875] [Iter 6900]
#   G loss: -0.1021 (Adv: 0.2506, Aux: 0.0061, VQE_reg: -0.3588, E_c: -3.5877)
#   D loss: 0.9865 (RealAdv: 0.3846, FakeAdv: 1.4817, RealAux: 0.1044, FakeAux: 0.0022)
# [Epoch 4/10] [Batch 1325/1875] [Iter 6950]
#   G loss: -0.0339 (Adv: 0.3189, Aux: 0.0032, VQE_reg: -0.3560, E_c: -3.5597)
#   D loss: 0.8655 (RealAdv: 0.3928, FakeAdv: 1.2478, RealAux: 0.0891, FakeAux: 0.0013)
# [Epoch 4/10] [Batch 1375/1875] [Iter 7000]
#   G loss: -0.0119 (Adv: 0.3315, Aux: 0.0170, VQE_reg: -0.3604, E_c: -3.6036)
#   D loss: 0.8123 (RealAdv: 0.3859, FakeAdv: 1.2149, RealAux: 0.0232, FakeAux: 0.0005)
# [Epoch 4/10] [Batch 1425/1875] [Iter 7050]
#   G loss: 0.0457 (Adv: 0.3368, Aux: 0.0692, VQE_reg: -0.3602, E_c: -3.6022)
#   D loss: 0.8651 (RealAdv: 0.3851, FakeAdv: 1.3364, RealAux: 0.0052, FakeAux: 0.0036)
# [Epoch 4/10] [Batch 1475/1875] [Iter 7100]
#   G loss: -0.0417 (Adv: 0.3178, Aux: 0.0009, VQE_reg: -0.3605, E_c: -3.6045)
#   D loss: 0.8946 (RealAdv: 0.3901, FakeAdv: 1.3104, RealAux: 0.0886, FakeAux: 0.0001)
# [Epoch 4/10] [Batch 1525/1875] [Iter 7150]
#   G loss: -0.0463 (Adv: 0.3106, Aux: 0.0006, VQE_reg: -0.3576, E_c: -3.5756)
#   D loss: 0.8393 (RealAdv: 0.4025, FakeAdv: 1.2692, RealAux: 0.0050, FakeAux: 0.0020)
# [Epoch 4/10] [Batch 1575/1875] [Iter 7200]
#   G loss: -0.0027 (Adv: 0.3533, Aux: 0.0008, VQE_reg: -0.3569, E_c: -3.5687)
#   D loss: 0.8324 (RealAdv: 0.4061, FakeAdv: 1.2578, RealAux: 0.0007, FakeAux: 0.0003)
# [Epoch 4/10] [Batch 1625/1875] [Iter 7250]
#   G loss: -0.0279 (Adv: 0.3308, Aux: 0.0023, VQE_reg: -0.3611, E_c: -3.6106)
#   D loss: 0.8571 (RealAdv: 0.3779, FakeAdv: 1.3168, RealAux: 0.0189, FakeAux: 0.0005)
# [Epoch 4/10] [Batch 1675/1875] [Iter 7300]
#   G loss: -0.0439 (Adv: 0.3145, Aux: 0.0006, VQE_reg: -0.3591, E_c: -3.5910)
#   D loss: 0.8452 (RealAdv: 0.3936, FakeAdv: 1.2917, RealAux: 0.0033, FakeAux: 0.0017)
# [Epoch 4/10] [Batch 1725/1875] [Iter 7350]
#   G loss: 0.0002 (Adv: 0.3550, Aux: 0.0003, VQE_reg: -0.3551, E_c: -3.5509)
#   D loss: 0.8544 (RealAdv: 0.3868, FakeAdv: 1.2649, RealAux: 0.0569, FakeAux: 0.0001)
# [Epoch 4/10] [Batch 1775/1875] [Iter 7400]
#   G loss: -0.0399 (Adv: 0.3132, Aux: 0.0011, VQE_reg: -0.3542, E_c: -3.5416)
#   D loss: 0.8422 (RealAdv: 0.4079, FakeAdv: 1.2431, RealAux: 0.0326, FakeAux: 0.0010)
# [Epoch 4/10] [Batch 1825/1875] [Iter 7450]
#   G loss: -0.0208 (Adv: 0.3342, Aux: 0.0053, VQE_reg: -0.3604, E_c: -3.6035)
#   D loss: 0.8299 (RealAdv: 0.4073, FakeAdv: 1.2318, RealAux: 0.0191, FakeAux: 0.0016)
# [Epoch 4/10] [Batch 1875/1875] [Iter 7500]
#   G loss: -0.0138 (Adv: 0.3431, Aux: 0.0003, VQE_reg: -0.3572, E_c: -3.5715)
#   D loss: 0.7191 (RealAdv: 0.3847, FakeAdv: 1.0518, RealAux: 0.0017, FakeAux: 0.0001)
#
# --- End of Epoch 4/10 (Duration: 5038.31s) ---
#   Avg G Loss: -0.0122 (Adv: 0.3418, Aux: 0.0041, VQE_reg: -0.3581, Avg E_c: -3.5811)
#   Avg D Loss: 0.8629 (R_Adv: 0.3959, F_Adv: 1.2723, R_Aux: 0.0536, F_Aux: 0.0040)
#   Samples for epoch 4 saved.
#   Running evaluation for epoch 4...
#   Generating 1000 samples for FID/IS into '/tmp/tmporwtp6p8'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 32.2773, IS (mean): 2.3157
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 98.20%
#   *** New best FID: 32.2773 at epoch 4. Models saved. ***
# ------------------------------------------------------------
# [Epoch 5/10] [Batch 50/1875] [Iter 7550]
#   G loss: 0.0175 (Adv: 0.3685, Aux: 0.0023, VQE_reg: -0.3533, E_c: -3.5333)
#   D loss: 0.8514 (RealAdv: 0.4383, FakeAdv: 1.2105, RealAux: 0.0536, FakeAux: 0.0006)
# [Epoch 5/10] [Batch 100/1875] [Iter 7600]
#   G loss: -0.0258 (Adv: 0.3291, Aux: 0.0050, VQE_reg: -0.3599, E_c: -3.5985)
#   D loss: 0.8404 (RealAdv: 0.4060, FakeAdv: 1.2515, RealAux: 0.0182, FakeAux: 0.0051)
# [Epoch 5/10] [Batch 150/1875] [Iter 7650]
#   G loss: -0.0364 (Adv: 0.3149, Aux: 0.0013, VQE_reg: -0.3526, E_c: -3.5264)
#   D loss: 0.8191 (RealAdv: 0.3757, FakeAdv: 1.2242, RealAux: 0.0376, FakeAux: 0.0008)
# [Epoch 5/10] [Batch 200/1875] [Iter 7700]
#   G loss: -0.0535 (Adv: 0.3053, Aux: 0.0012, VQE_reg: -0.3600, E_c: -3.6003)
#   D loss: 0.9280 (RealAdv: 0.3926, FakeAdv: 1.3864, RealAux: 0.0764, FakeAux: 0.0008)
# [Epoch 5/10] [Batch 250/1875] [Iter 7750]
#   G loss: 0.0158 (Adv: 0.3703, Aux: 0.0020, VQE_reg: -0.3566, E_c: -3.5656)
#   D loss: 0.8887 (RealAdv: 0.3781, FakeAdv: 1.2963, RealAux: 0.1006, FakeAux: 0.0023)
# [Epoch 5/10] [Batch 300/1875] [Iter 7800]
#   G loss: -0.0119 (Adv: 0.3430, Aux: 0.0005, VQE_reg: -0.3554, E_c: -3.5545)
#   D loss: 0.8046 (RealAdv: 0.3983, FakeAdv: 1.1992, RealAux: 0.0110, FakeAux: 0.0007)
# [Epoch 5/10] [Batch 350/1875] [Iter 7850]
#   G loss: -0.0050 (Adv: 0.3530, Aux: 0.0004, VQE_reg: -0.3584, E_c: -3.5842)
#   D loss: 0.8838 (RealAdv: 0.4243, FakeAdv: 1.3099, RealAux: 0.0325, FakeAux: 0.0008)
# [Epoch 5/10] [Batch 400/1875] [Iter 7900]
#   G loss: -0.0065 (Adv: 0.3529, Aux: 0.0014, VQE_reg: -0.3607, E_c: -3.6075)
#   D loss: 0.8362 (RealAdv: 0.4019, FakeAdv: 1.1993, RealAux: 0.0705, FakeAux: 0.0008)
# [Epoch 5/10] [Batch 450/1875] [Iter 7950]
#   G loss: -0.0293 (Adv: 0.3259, Aux: 0.0048, VQE_reg: -0.3601, E_c: -3.6007)
#   D loss: 0.8418 (RealAdv: 0.3936, FakeAdv: 1.2738, RealAux: 0.0158, FakeAux: 0.0003)
# [Epoch 5/10] [Batch 500/1875] [Iter 8000]
#   G loss: -0.0704 (Adv: 0.2812, Aux: 0.0061, VQE_reg: -0.3577, E_c: -3.5771)
#   D loss: 0.8817 (RealAdv: 0.4129, FakeAdv: 1.2612, RealAux: 0.0893, FakeAux: 0.0002)
# [Epoch 5/10] [Batch 550/1875] [Iter 8050]
#   G loss: -0.0302 (Adv: 0.3223, Aux: 0.0039, VQE_reg: -0.3564, E_c: -3.5635)
#   D loss: 0.8782 (RealAdv: 0.3844, FakeAdv: 1.2098, RealAux: 0.1608, FakeAux: 0.0013)
# [Epoch 5/10] [Batch 600/1875] [Iter 8100]
#   G loss: -0.0291 (Adv: 0.3271, Aux: 0.0007, VQE_reg: -0.3570, E_c: -3.5699)
#   D loss: 0.9020 (RealAdv: 0.4066, FakeAdv: 1.3487, RealAux: 0.0381, FakeAux: 0.0106)
# [Epoch 5/10] [Batch 650/1875] [Iter 8150]
#   G loss: -0.0441 (Adv: 0.3132, Aux: 0.0011, VQE_reg: -0.3584, E_c: -3.5842)
#   D loss: 0.9140 (RealAdv: 0.4142, FakeAdv: 1.3552, RealAux: 0.0584, FakeAux: 0.0002)
# [Epoch 5/10] [Batch 700/1875] [Iter 8200]
#   G loss: -0.0434 (Adv: 0.3126, Aux: 0.0008, VQE_reg: -0.3568, E_c: -3.5677)
#   D loss: 0.9233 (RealAdv: 0.3895, FakeAdv: 1.3492, RealAux: 0.0956, FakeAux: 0.0123)
# [Epoch 5/10] [Batch 750/1875] [Iter 8250]
#   G loss: -0.0736 (Adv: 0.2794, Aux: 0.0013, VQE_reg: -0.3543, E_c: -3.5431)
#   D loss: 0.9105 (RealAdv: 0.3626, FakeAdv: 1.4467, RealAux: 0.0050, FakeAux: 0.0068)
# [Epoch 5/10] [Batch 800/1875] [Iter 8300]
#   G loss: -0.0419 (Adv: 0.3137, Aux: 0.0011, VQE_reg: -0.3568, E_c: -3.5675)
#   D loss: 0.8617 (RealAdv: 0.4222, FakeAdv: 1.2987, RealAux: 0.0021, FakeAux: 0.0004)
# [Epoch 5/10] [Batch 850/1875] [Iter 8350]
#   G loss: 0.0082 (Adv: 0.3638, Aux: 0.0028, VQE_reg: -0.3583, E_c: -3.5835)
#   D loss: 0.8798 (RealAdv: 0.4001, FakeAdv: 1.2729, RealAux: 0.0859, FakeAux: 0.0006)
# [Epoch 5/10] [Batch 900/1875] [Iter 8400]
#   G loss: 0.0150 (Adv: 0.3707, Aux: 0.0031, VQE_reg: -0.3588, E_c: -3.5882)
#   D loss: 0.7633 (RealAdv: 0.4003, FakeAdv: 1.0991, RealAux: 0.0262, FakeAux: 0.0011)
# [Epoch 5/10] [Batch 950/1875] [Iter 8450]
#   G loss: -0.0668 (Adv: 0.2858, Aux: 0.0031, VQE_reg: -0.3557, E_c: -3.5569)
#   D loss: 0.8976 (RealAdv: 0.3726, FakeAdv: 1.3779, RealAux: 0.0441, FakeAux: 0.0005)
# [Epoch 5/10] [Batch 1000/1875] [Iter 8500]
#   G loss: 0.0099 (Adv: 0.3659, Aux: 0.0026, VQE_reg: -0.3587, E_c: -3.5866)
#   D loss: 0.8485 (RealAdv: 0.4336, FakeAdv: 1.2136, RealAux: 0.0464, FakeAux: 0.0033)
# [Epoch 5/10] [Batch 1050/1875] [Iter 8550]
#   G loss: 0.0205 (Adv: 0.3801, Aux: 0.0004, VQE_reg: -0.3600, E_c: -3.5997)
#   D loss: 0.8170 (RealAdv: 0.4416, FakeAdv: 1.1805, RealAux: 0.0116, FakeAux: 0.0003)
# [Epoch 5/10] [Batch 1100/1875] [Iter 8600]
#   G loss: -0.0337 (Adv: 0.3228, Aux: 0.0009, VQE_reg: -0.3574, E_c: -3.5738)
#   D loss: 0.8573 (RealAdv: 0.4030, FakeAdv: 1.2412, RealAux: 0.0624, FakeAux: 0.0080)
# [Epoch 5/10] [Batch 1150/1875] [Iter 8650]
#   G loss: -0.0011 (Adv: 0.3567, Aux: 0.0012, VQE_reg: -0.3589, E_c: -3.5894)
#   D loss: 0.8638 (RealAdv: 0.4139, FakeAdv: 1.2409, RealAux: 0.0720, FakeAux: 0.0007)
# [Epoch 5/10] [Batch 1200/1875] [Iter 8700]
#   G loss: -0.0571 (Adv: 0.2994, Aux: 0.0006, VQE_reg: -0.3571, E_c: -3.5707)
#   D loss: 0.8813 (RealAdv: 0.3962, FakeAdv: 1.3576, RealAux: 0.0052, FakeAux: 0.0036)
# [Epoch 5/10] [Batch 1250/1875] [Iter 8750]
#   G loss: -0.0659 (Adv: 0.2956, Aux: 0.0003, VQE_reg: -0.3618, E_c: -3.6180)
#   D loss: 0.8500 (RealAdv: 0.3857, FakeAdv: 1.3016, RealAux: 0.0124, FakeAux: 0.0003)
# [Epoch 5/10] [Batch 1300/1875] [Iter 8800]
#   G loss: 0.0078 (Adv: 0.3619, Aux: 0.0027, VQE_reg: -0.3568, E_c: -3.5682)
#   D loss: 0.8401 (RealAdv: 0.3902, FakeAdv: 1.2787, RealAux: 0.0078, FakeAux: 0.0035)
# [Epoch 5/10] [Batch 1350/1875] [Iter 8850]
#   G loss: -0.0223 (Adv: 0.3129, Aux: 0.0204, VQE_reg: -0.3556, E_c: -3.5562)
#   D loss: 0.8504 (RealAdv: 0.4106, FakeAdv: 1.2801, RealAux: 0.0094, FakeAux: 0.0008)
# [Epoch 5/10] [Batch 1400/1875] [Iter 8900]
#   G loss: -0.0108 (Adv: 0.3451, Aux: 0.0003, VQE_reg: -0.3562, E_c: -3.5624)
#   D loss: 0.8983 (RealAdv: 0.3949, FakeAdv: 1.1954, RealAux: 0.2057, FakeAux: 0.0007)
# [Epoch 5/10] [Batch 1450/1875] [Iter 8950]
#   G loss: -0.0473 (Adv: 0.3067, Aux: 0.0041, VQE_reg: -0.3581, E_c: -3.5812)
#   D loss: 0.9007 (RealAdv: 0.3888, FakeAdv: 1.3185, RealAux: 0.0937, FakeAux: 0.0005)
# [Epoch 5/10] [Batch 1500/1875] [Iter 9000]
#   G loss: -0.0102 (Adv: 0.3413, Aux: 0.0014, VQE_reg: -0.3529, E_c: -3.5289)
#   D loss: 0.8579 (RealAdv: 0.4260, FakeAdv: 1.1659, RealAux: 0.1203, FakeAux: 0.0036)
# [Epoch 5/10] [Batch 1550/1875] [Iter 9050]
#   G loss: -0.0067 (Adv: 0.3517, Aux: 0.0010, VQE_reg: -0.3595, E_c: -3.5949)
#   D loss: 0.8243 (RealAdv: 0.4112, FakeAdv: 1.2241, RealAux: 0.0125, FakeAux: 0.0007)
# [Epoch 5/10] [Batch 1600/1875] [Iter 9100]
#   G loss: -0.0147 (Adv: 0.3409, Aux: 0.0004, VQE_reg: -0.3560, E_c: -3.5596)
#   D loss: 0.9463 (RealAdv: 0.3879, FakeAdv: 1.3243, RealAux: 0.1774, FakeAux: 0.0030)
# [Epoch 5/10] [Batch 1650/1875] [Iter 9150]
#   G loss: -0.0059 (Adv: 0.3499, Aux: 0.0003, VQE_reg: -0.3561, E_c: -3.5607)
#   D loss: 0.8671 (RealAdv: 0.4005, FakeAdv: 1.2823, RealAux: 0.0513, FakeAux: 0.0002)
# [Epoch 5/10] [Batch 1700/1875] [Iter 9200]
#   G loss: -0.0672 (Adv: 0.2857, Aux: 0.0040, VQE_reg: -0.3569, E_c: -3.5690)
#   D loss: 0.9656 (RealAdv: 0.3901, FakeAdv: 1.3744, RealAux: 0.1655, FakeAux: 0.0010)
# [Epoch 5/10] [Batch 1750/1875] [Iter 9250]
#   G loss: -0.0573 (Adv: 0.3007, Aux: 0.0007, VQE_reg: -0.3586, E_c: -3.5859)
#   D loss: 0.8879 (RealAdv: 0.3970, FakeAdv: 1.3755, RealAux: 0.0030, FakeAux: 0.0004)
# [Epoch 5/10] [Batch 1800/1875] [Iter 9300]
#   G loss: -0.0142 (Adv: 0.3427, Aux: 0.0017, VQE_reg: -0.3586, E_c: -3.5864)
#   D loss: 0.8466 (RealAdv: 0.4057, FakeAdv: 1.2627, RealAux: 0.0219, FakeAux: 0.0030)
# [Epoch 5/10] [Batch 1850/1875] [Iter 9350]
#   G loss: -0.0619 (Adv: 0.2955, Aux: 0.0015, VQE_reg: -0.3589, E_c: -3.5887)
#   D loss: 0.8573 (RealAdv: 0.3897, FakeAdv: 1.2862, RealAux: 0.0378, FakeAux: 0.0009)
#
# --- End of Epoch 5/10 (Duration: 5035.82s) ---
#   Avg G Loss: -0.0179 (Adv: 0.3371, Aux: 0.0030, VQE_reg: -0.3581, Avg E_c: -3.5805)
#   Avg D Loss: 0.8639 (R_Adv: 0.4013, F_Adv: 1.2795, R_Aux: 0.0440, F_Aux: 0.0030)
#   Samples for epoch 5 saved.
#   Running evaluation for epoch 5...
#   Generating 1000 samples for FID/IS into '/tmp/tmpl1wotq2y'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 24.1109, IS (mean): 2.0289
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 100.00%
#   *** New best FID: 24.1109 at epoch 5. Models saved. ***
# ------------------------------------------------------------
# [Epoch 6/10] [Batch 25/1875] [Iter 9400]
#   G loss: -0.0522 (Adv: 0.3048, Aux: 0.0001, VQE_reg: -0.3570, E_c: -3.5703)
#   D loss: 0.8866 (RealAdv: 0.4029, FakeAdv: 1.3646, RealAux: 0.0048, FakeAux: 0.0009)
# [Epoch 6/10] [Batch 75/1875] [Iter 9450]
#   G loss: 0.0024 (Adv: 0.3596, Aux: 0.0020, VQE_reg: -0.3592, E_c: -3.5921)
#   D loss: 0.8906 (RealAdv: 0.4129, FakeAdv: 1.3082, RealAux: 0.0421, FakeAux: 0.0179)
# [Epoch 6/10] [Batch 125/1875] [Iter 9500]
#   G loss: -0.0728 (Adv: 0.2890, Aux: 0.0005, VQE_reg: -0.3623, E_c: -3.6232)
#   D loss: 0.8704 (RealAdv: 0.3893, FakeAdv: 1.3371, RealAux: 0.0120, FakeAux: 0.0024)
# [Epoch 6/10] [Batch 175/1875] [Iter 9550]
#   G loss: 0.0183 (Adv: 0.3715, Aux: 0.0005, VQE_reg: -0.3538, E_c: -3.5380)
#   D loss: 0.8101 (RealAdv: 0.4032, FakeAdv: 1.2033, RealAux: 0.0129, FakeAux: 0.0008)
# [Epoch 6/10] [Batch 225/1875] [Iter 9600]
#   G loss: -0.0199 (Adv: 0.3361, Aux: 0.0029, VQE_reg: -0.3589, E_c: -3.5885)
#   D loss: 0.8935 (RealAdv: 0.4252, FakeAdv: 1.3554, RealAux: 0.0023, FakeAux: 0.0041)
# [Epoch 6/10] [Batch 275/1875] [Iter 9650]
#   G loss: -0.0522 (Adv: 0.3006, Aux: 0.0014, VQE_reg: -0.3543, E_c: -3.5425)
#   D loss: 0.9397 (RealAdv: 0.3910, FakeAdv: 1.3708, RealAux: 0.1173, FakeAux: 0.0004)
# [Epoch 6/10] [Batch 325/1875] [Iter 9700]
#   G loss: 0.0023 (Adv: 0.3638, Aux: 0.0001, VQE_reg: -0.3617, E_c: -3.6166)
#   D loss: 0.8990 (RealAdv: 0.4333, FakeAdv: 1.1920, RealAux: 0.1723, FakeAux: 0.0003)
# [Epoch 6/10] [Batch 375/1875] [Iter 9750]
#   G loss: -0.0627 (Adv: 0.2939, Aux: 0.0009, VQE_reg: -0.3574, E_c: -3.5743)
#   D loss: 0.9395 (RealAdv: 0.3788, FakeAdv: 1.4836, RealAux: 0.0135, FakeAux: 0.0031)
# [Epoch 6/10] [Batch 425/1875] [Iter 9800]
#   G loss: -0.0119 (Adv: 0.3450, Aux: 0.0002, VQE_reg: -0.3571, E_c: -3.5713)
#   D loss: 0.8460 (RealAdv: 0.3972, FakeAdv: 1.2835, RealAux: 0.0099, FakeAux: 0.0014)
# [Epoch 6/10] [Batch 475/1875] [Iter 9850]
#   G loss: -0.0365 (Adv: 0.3191, Aux: 0.0004, VQE_reg: -0.3561, E_c: -3.5605)
#   D loss: 0.8721 (RealAdv: 0.4131, FakeAdv: 1.2320, RealAux: 0.0985, FakeAux: 0.0006)
# [Epoch 6/10] [Batch 525/1875] [Iter 9900]
#   G loss: 0.0629 (Adv: 0.3715, Aux: 0.0491, VQE_reg: -0.3577, E_c: -3.5774)
#   D loss: 0.8224 (RealAdv: 0.3922, FakeAdv: 1.2486, RealAux: 0.0030, FakeAux: 0.0010)
# [Epoch 6/10] [Batch 575/1875] [Iter 9950]
#   G loss: -0.0528 (Adv: 0.3059, Aux: 0.0002, VQE_reg: -0.3589, E_c: -3.5891)
#   D loss: 0.9016 (RealAdv: 0.3731, FakeAdv: 1.3154, RealAux: 0.0998, FakeAux: 0.0150)
# [Epoch 6/10] [Batch 625/1875] [Iter 10000]
#   G loss: 0.0027 (Adv: 0.3599, Aux: 0.0009, VQE_reg: -0.3581, E_c: -3.5806)
#   D loss: 0.8115 (RealAdv: 0.4191, FakeAdv: 1.2005, RealAux: 0.0009, FakeAux: 0.0025)
# [Epoch 6/10] [Batch 675/1875] [Iter 10050]
#   G loss: -0.0022 (Adv: 0.3578, Aux: 0.0008, VQE_reg: -0.3608, E_c: -3.6080)
#   D loss: 0.8896 (RealAdv: 0.4061, FakeAdv: 1.3404, RealAux: 0.0314, FakeAux: 0.0013)
# [Epoch 6/10] [Batch 725/1875] [Iter 10100]
#   G loss: 0.0524 (Adv: 0.4069, Aux: 0.0023, VQE_reg: -0.3569, E_c: -3.5686)
#   D loss: 0.8320 (RealAdv: 0.4218, FakeAdv: 1.2234, RealAux: 0.0008, FakeAux: 0.0180)
# [Epoch 6/10] [Batch 775/1875] [Iter 10150]
#   G loss: -0.0408 (Adv: 0.3148, Aux: 0.0001, VQE_reg: -0.3557, E_c: -3.5570)
#   D loss: 0.8403 (RealAdv: 0.3803, FakeAdv: 1.2999, RealAux: 0.0004, FakeAux: 0.0000)
# [Epoch 6/10] [Batch 825/1875] [Iter 10200]
#   G loss: -0.0091 (Adv: 0.3472, Aux: 0.0004, VQE_reg: -0.3567, E_c: -3.5669)
#   D loss: 0.8606 (RealAdv: 0.4130, FakeAdv: 1.2762, RealAux: 0.0309, FakeAux: 0.0011)
# [Epoch 6/10] [Batch 875/1875] [Iter 10250]
#   G loss: 0.0293 (Adv: 0.3868, Aux: 0.0010, VQE_reg: -0.3586, E_c: -3.5855)
#   D loss: 0.8260 (RealAdv: 0.4182, FakeAdv: 1.2108, RealAux: 0.0209, FakeAux: 0.0023)
# [Epoch 6/10] [Batch 925/1875] [Iter 10300]
#   G loss: -0.0210 (Adv: 0.3383, Aux: 0.0005, VQE_reg: -0.3598, E_c: -3.5977)
#   D loss: 0.9405 (RealAdv: 0.4195, FakeAdv: 1.1911, RealAux: 0.2697, FakeAux: 0.0006)
# [Epoch 6/10] [Batch 975/1875] [Iter 10350]
#   G loss: -0.0136 (Adv: 0.3457, Aux: 0.0004, VQE_reg: -0.3598, E_c: -3.5977)
#   D loss: 0.8360 (RealAdv: 0.4008, FakeAdv: 1.2677, RealAux: 0.0028, FakeAux: 0.0007)
# [Epoch 6/10] [Batch 1025/1875] [Iter 10400]
#   G loss: 0.0148 (Adv: 0.3688, Aux: 0.0065, VQE_reg: -0.3605, E_c: -3.6055)
#   D loss: 0.8148 (RealAdv: 0.4067, FakeAdv: 1.2144, RealAux: 0.0082, FakeAux: 0.0004)
# [Epoch 6/10] [Batch 1075/1875] [Iter 10450]
#   G loss: -0.0372 (Adv: 0.3177, Aux: 0.0013, VQE_reg: -0.3562, E_c: -3.5622)
#   D loss: 0.8796 (RealAdv: 0.3878, FakeAdv: 1.3119, RealAux: 0.0543, FakeAux: 0.0052)
# [Epoch 6/10] [Batch 1125/1875] [Iter 10500]
#   G loss: -0.0117 (Adv: 0.3459, Aux: 0.0004, VQE_reg: -0.3579, E_c: -3.5793)
#   D loss: 0.8418 (RealAdv: 0.4081, FakeAdv: 1.2696, RealAux: 0.0054, FakeAux: 0.0007)
# [Epoch 6/10] [Batch 1175/1875] [Iter 10550]
#   G loss: 0.0443 (Adv: 0.4046, Aux: 0.0012, VQE_reg: -0.3615, E_c: -3.6146)
#   D loss: 0.8191 (RealAdv: 0.4169, FakeAdv: 1.1765, RealAux: 0.0442, FakeAux: 0.0006)
# [Epoch 6/10] [Batch 1225/1875] [Iter 10600]
#   G loss: -0.0366 (Adv: 0.3224, Aux: 0.0001, VQE_reg: -0.3591, E_c: -3.5912)
#   D loss: 0.8207 (RealAdv: 0.4073, FakeAdv: 1.2187, RealAux: 0.0130, FakeAux: 0.0024)
# [Epoch 6/10] [Batch 1275/1875] [Iter 10650]
#   G loss: 0.0335 (Adv: 0.3865, Aux: 0.0005, VQE_reg: -0.3535, E_c: -3.5351)
#   D loss: 0.8353 (RealAdv: 0.3873, FakeAdv: 1.2799, RealAux: 0.0031, FakeAux: 0.0003)
# [Epoch 6/10] [Batch 1325/1875] [Iter 10700]
#   G loss: -0.0363 (Adv: 0.3274, Aux: 0.0002, VQE_reg: -0.3640, E_c: -3.6398)
#   D loss: 0.8490 (RealAdv: 0.3824, FakeAdv: 1.2848, RealAux: 0.0304, FakeAux: 0.0004)
# ...
#   D loss: 0.9747 (RealAdv: 0.3771, FakeAdv: 1.4711, RealAux: 0.1010, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 300/1875] [Iter 15300]
#   G loss: 0.0227 (Adv: 0.3318, Aux: 0.0487, VQE_reg: -0.3578, E_c: -3.5775)
#   D loss: 0.9149 (RealAdv: 0.3874, FakeAdv: 1.4257, RealAux: 0.0163, FakeAux: 0.0003)
# [Epoch 9/10] [Batch 350/1875] [Iter 15350]
#   G loss: -0.0459 (Adv: 0.3163, Aux: 0.0000, VQE_reg: -0.3622, E_c: -3.6215)
#   D loss: 0.9010 (RealAdv: 0.3963, FakeAdv: 1.3774, RealAux: 0.0282, FakeAux: 0.0003)
# [Epoch 9/10] [Batch 400/1875] [Iter 15400]
#   G loss: -0.0730 (Adv: 0.2842, Aux: 0.0003, VQE_reg: -0.3575, E_c: -3.5751)
#   D loss: 0.9660 (RealAdv: 0.3613, FakeAdv: 1.5620, RealAux: 0.0087, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 450/1875] [Iter 15450]
#   G loss: -0.0005 (Adv: 0.3626, Aux: 0.0001, VQE_reg: -0.3631, E_c: -3.6313)
#   D loss: 0.8311 (RealAdv: 0.4459, FakeAdv: 1.2083, RealAux: 0.0080, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 500/1875] [Iter 15500]
#   G loss: 0.0052 (Adv: 0.3656, Aux: 0.0003, VQE_reg: -0.3607, E_c: -3.6074)
#   D loss: 0.7826 (RealAdv: 0.4098, FakeAdv: 1.1547, RealAux: 0.0002, FakeAux: 0.0005)
# [Epoch 9/10] [Batch 550/1875] [Iter 15550]
#   G loss: -0.0447 (Adv: 0.3123, Aux: 0.0007, VQE_reg: -0.3577, E_c: -3.5769)
#   D loss: 0.7988 (RealAdv: 0.3984, FakeAdv: 1.1963, RealAux: 0.0008, FakeAux: 0.0020)
# [Epoch 9/10] [Batch 600/1875] [Iter 15600]
#   G loss: -0.0002 (Adv: 0.3564, Aux: 0.0004, VQE_reg: -0.3570, E_c: -3.5699)
#   D loss: 0.7954 (RealAdv: 0.3897, FakeAdv: 1.1502, RealAux: 0.0508, FakeAux: 0.0002)
# [Epoch 9/10] [Batch 650/1875] [Iter 15650]
#   G loss: 0.0017 (Adv: 0.3620, Aux: 0.0000, VQE_reg: -0.3604, E_c: -3.6038)
#   D loss: 0.8071 (RealAdv: 0.3837, FakeAdv: 1.2253, RealAux: 0.0050, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 700/1875] [Iter 15700]
#   G loss: -0.0184 (Adv: 0.3377, Aux: 0.0024, VQE_reg: -0.3585, E_c: -3.5849)
#   D loss: 0.8570 (RealAdv: 0.4285, FakeAdv: 1.2585, RealAux: 0.0269, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 750/1875] [Iter 15750]
#   G loss: -0.0200 (Adv: 0.3363, Aux: 0.0002, VQE_reg: -0.3565, E_c: -3.5650)
#   D loss: 0.8496 (RealAdv: 0.3944, FakeAdv: 1.3023, RealAux: 0.0024, FakeAux: 0.0002)
# [Epoch 9/10] [Batch 800/1875] [Iter 15800]
#   G loss: 0.0159 (Adv: 0.3755, Aux: 0.0011, VQE_reg: -0.3607, E_c: -3.6074)
#   D loss: 0.8663 (RealAdv: 0.4415, FakeAdv: 1.2736, RealAux: 0.0160, FakeAux: 0.0016)
# [Epoch 9/10] [Batch 850/1875] [Iter 15850]
#   G loss: -0.0267 (Adv: 0.3315, Aux: 0.0007, VQE_reg: -0.3589, E_c: -3.5891)
#   D loss: 0.8180 (RealAdv: 0.3955, FakeAdv: 1.2384, RealAux: 0.0012, FakeAux: 0.0009)
# [Epoch 9/10] [Batch 900/1875] [Iter 15900]
#   G loss: -0.0599 (Adv: 0.2957, Aux: 0.0010, VQE_reg: -0.3565, E_c: -3.5655)
#   D loss: 0.8640 (RealAdv: 0.3907, FakeAdv: 1.2991, RealAux: 0.0381, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 950/1875] [Iter 15950]
#   G loss: -0.0360 (Adv: 0.3242, Aux: 0.0006, VQE_reg: -0.3609, E_c: -3.6090)
#   D loss: 0.8096 (RealAdv: 0.3915, FakeAdv: 1.2253, RealAux: 0.0024, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1000/1875] [Iter 16000]
#   G loss: -0.0349 (Adv: 0.3223, Aux: 0.0065, VQE_reg: -0.3637, E_c: -3.6373)
#   D loss: 0.8587 (RealAdv: 0.4127, FakeAdv: 1.2988, RealAux: 0.0049, FakeAux: 0.0010)
# [Epoch 9/10] [Batch 1050/1875] [Iter 16050]
#   G loss: -0.0179 (Adv: 0.3324, Aux: 0.0077, VQE_reg: -0.3579, E_c: -3.5791)
#   D loss: 0.8669 (RealAdv: 0.4042, FakeAdv: 1.2437, RealAux: 0.0859, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1100/1875] [Iter 16100]
#   G loss: -0.0418 (Adv: 0.3130, Aux: 0.0005, VQE_reg: -0.3552, E_c: -3.5524)
#   D loss: 0.8480 (RealAdv: 0.4051, FakeAdv: 1.2894, RealAux: 0.0008, FakeAux: 0.0007)
# [Epoch 9/10] [Batch 1150/1875] [Iter 16150]
#   G loss: -0.0038 (Adv: 0.3528, Aux: 0.0006, VQE_reg: -0.3571, E_c: -3.5712)
#   D loss: 0.8176 (RealAdv: 0.4125, FakeAdv: 1.1922, RealAux: 0.0305, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1200/1875] [Iter 16200]
#   G loss: 0.0194 (Adv: 0.3806, Aux: 0.0003, VQE_reg: -0.3615, E_c: -3.6154)
#   D loss: 0.8341 (RealAdv: 0.4394, FakeAdv: 1.2067, RealAux: 0.0220, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1250/1875] [Iter 16250]
#   G loss: 0.0166 (Adv: 0.3708, Aux: 0.0030, VQE_reg: -0.3573, E_c: -3.5727)
#   D loss: 0.8333 (RealAdv: 0.4138, FakeAdv: 1.2525, RealAux: 0.0001, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1300/1875] [Iter 16300]
#   G loss: 0.0035 (Adv: 0.3625, Aux: 0.0015, VQE_reg: -0.3604, E_c: -3.6043)
#   D loss: 0.8529 (RealAdv: 0.4063, FakeAdv: 1.2923, RealAux: 0.0070, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1350/1875] [Iter 16350]
#   G loss: 0.0075 (Adv: 0.3677, Aux: 0.0002, VQE_reg: -0.3604, E_c: -3.6044)
#   D loss: 0.8491 (RealAdv: 0.4016, FakeAdv: 1.2172, RealAux: 0.0793, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 1400/1875] [Iter 16400]
#   G loss: -0.0056 (Adv: 0.3528, Aux: 0.0008, VQE_reg: -0.3592, E_c: -3.5921)
#   D loss: 0.8655 (RealAdv: 0.4247, FakeAdv: 1.3047, RealAux: 0.0005, FakeAux: 0.0010)
# [Epoch 9/10] [Batch 1450/1875] [Iter 16450]
#   G loss: -0.0359 (Adv: 0.3235, Aux: 0.0002, VQE_reg: -0.3596, E_c: -3.5962)
#   D loss: 0.8196 (RealAdv: 0.3905, FakeAdv: 1.2484, RealAux: 0.0001, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1500/1875] [Iter 16500]
#   G loss: -0.0124 (Adv: 0.3439, Aux: 0.0008, VQE_reg: -0.3571, E_c: -3.5711)
#   D loss: 0.8308 (RealAdv: 0.4175, FakeAdv: 1.2417, RealAux: 0.0023, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1550/1875] [Iter 16550]
#   G loss: -0.0048 (Adv: 0.3526, Aux: 0.0003, VQE_reg: -0.3577, E_c: -3.5768)
#   D loss: 0.8465 (RealAdv: 0.3792, FakeAdv: 1.3046, RealAux: 0.0072, FakeAux: 0.0020)
# [Epoch 9/10] [Batch 1600/1875] [Iter 16600]
#   G loss: -0.0658 (Adv: 0.2871, Aux: 0.0001, VQE_reg: -0.3530, E_c: -3.5304)
#   D loss: 0.8269 (RealAdv: 0.3952, FakeAdv: 1.2580, RealAux: 0.0005, FakeAux: 0.0002)
# [Epoch 9/10] [Batch 1650/1875] [Iter 16650]
#   G loss: -0.0381 (Adv: 0.3102, Aux: 0.0103, VQE_reg: -0.3585, E_c: -3.5854)
#   D loss: 0.8536 (RealAdv: 0.3966, FakeAdv: 1.2584, RealAux: 0.0517, FakeAux: 0.0005)
# [Epoch 9/10] [Batch 1700/1875] [Iter 16700]
#   G loss: 0.0383 (Adv: 0.3876, Aux: 0.0074, VQE_reg: -0.3567, E_c: -3.5674)
#   D loss: 0.8586 (RealAdv: 0.4005, FakeAdv: 1.2865, RealAux: 0.0302, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 1750/1875] [Iter 16750]
#   G loss: 0.0046 (Adv: 0.3565, Aux: 0.0040, VQE_reg: -0.3559, E_c: -3.5590)
#   D loss: 0.8200 (RealAdv: 0.4173, FakeAdv: 1.2092, RealAux: 0.0128, FakeAux: 0.0007)
# [Epoch 9/10] [Batch 1800/1875] [Iter 16800]
#   G loss: -0.0484 (Adv: 0.3094, Aux: 0.0002, VQE_reg: -0.3579, E_c: -3.5792)
#   D loss: 0.8370 (RealAdv: 0.4168, FakeAdv: 1.2532, RealAux: 0.0036, FakeAux: 0.0004)
# [Epoch 9/10] [Batch 1850/1875] [Iter 16850]
#   G loss: -0.0278 (Adv: 0.3262, Aux: 0.0005, VQE_reg: -0.3545, E_c: -3.5445)
#   D loss: 0.9005 (RealAdv: 0.4024, FakeAdv: 1.3484, RealAux: 0.0378, FakeAux: 0.0124)
#
# --- End of Epoch 9/10 (Duration: 4999.91s) ---
#   Avg G Loss: -0.0231 (Adv: 0.3331, Aux: 0.0019, VQE_reg: -0.3580, Avg E_c: -3.5801)
#   Avg D Loss: 0.8576 (R_Adv: 0.4060, F_Adv: 1.2823, R_Aux: 0.0248, F_Aux: 0.0021)
#   Samples for epoch 9 saved.
#   Running evaluation for epoch 9...
#   Generating 1000 samples for FID/IS into '/tmp/tmpiuzd91gh'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 23.2347, IS (mean): 1.9689
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 99.40%
#   *** New best FID: 23.2347 at epoch 9. Models saved. ***
# ------------------------------------------------------------
# [Epoch 10/10] [Batch 25/1875] [Iter 16900]
#   G loss: -0.0507 (Adv: 0.3091, Aux: 0.0009, VQE_reg: -0.3607, E_c: -3.6071)
#   D loss: 0.8873 (RealAdv: 0.4004, FakeAdv: 1.3727, RealAux: 0.0005, FakeAux: 0.0010)
# [Epoch 10/10] [Batch 75/1875] [Iter 16950]
#   G loss: -0.0224 (Adv: 0.3382, Aux: 0.0001, VQE_reg: -0.3607, E_c: -3.6069)
#   D loss: 0.8406 (RealAdv: 0.3949, FakeAdv: 1.2801, RealAux: 0.0060, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 125/1875] [Iter 17000]
#   G loss: -0.1002 (Adv: 0.2557, Aux: 0.0002, VQE_reg: -0.3561, E_c: -3.5608)
#   D loss: 0.9726 (RealAdv: 0.3633, FakeAdv: 1.5795, RealAux: 0.0013, FakeAux: 0.0011)
# [Epoch 10/10] [Batch 175/1875] [Iter 17050]
#   G loss: -0.0540 (Adv: 0.3025, Aux: 0.0003, VQE_reg: -0.3569, E_c: -3.5685)
#   D loss: 0.8793 (RealAdv: 0.3809, FakeAdv: 1.3709, RealAux: 0.0062, FakeAux: 0.0007)
# [Epoch 10/10] [Batch 225/1875] [Iter 17100]
#   G loss: -0.0173 (Adv: 0.3384, Aux: 0.0003, VQE_reg: -0.3560, E_c: -3.5597)
#   D loss: 0.8158 (RealAdv: 0.4130, FakeAdv: 1.2075, RealAux: 0.0110, FakeAux: 0.0002)
# [Epoch 10/10] [Batch 275/1875] [Iter 17150]
#   G loss: -0.0079 (Adv: 0.3498, Aux: 0.0049, VQE_reg: -0.3625, E_c: -3.6254)
#   D loss: 0.8530 (RealAdv: 0.4114, FakeAdv: 1.2673, RealAux: 0.0269, FakeAux: 0.0004)
# [Epoch 10/10] [Batch 325/1875] [Iter 17200]
#   G loss: -0.0476 (Adv: 0.3096, Aux: 0.0006, VQE_reg: -0.3578, E_c: -3.5780)
#   D loss: 0.9155 (RealAdv: 0.3921, FakeAdv: 1.2797, RealAux: 0.1589, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 375/1875] [Iter 17250]
#   G loss: 0.0152 (Adv: 0.3721, Aux: 0.0007, VQE_reg: -0.3576, E_c: -3.5757)
#   D loss: 0.8192 (RealAdv: 0.3894, FakeAdv: 1.2456, RealAux: 0.0029, FakeAux: 0.0006)
# [Epoch 10/10] [Batch 425/1875] [Iter 17300]
#   G loss: -0.0405 (Adv: 0.3153, Aux: 0.0014, VQE_reg: -0.3572, E_c: -3.5724)
#   D loss: 0.8336 (RealAdv: 0.4058, FakeAdv: 1.2519, RealAux: 0.0085, FakeAux: 0.0009)
# [Epoch 10/10] [Batch 475/1875] [Iter 17350]
#   G loss: -0.0231 (Adv: 0.3332, Aux: 0.0001, VQE_reg: -0.3564, E_c: -3.5639)
#   D loss: 0.8927 (RealAdv: 0.4095, FakeAdv: 1.3706, RealAux: 0.0050, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 525/1875] [Iter 17400]
#   G loss: -0.0703 (Adv: 0.2870, Aux: 0.0000, VQE_reg: -0.3573, E_c: -3.5732)
#   D loss: 0.9521 (RealAdv: 0.3700, FakeAdv: 1.5335, RealAux: 0.0006, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 575/1875] [Iter 17450]
#   G loss: -0.0157 (Adv: 0.3445, Aux: 0.0001, VQE_reg: -0.3603, E_c: -3.6029)
#   D loss: 0.8356 (RealAdv: 0.4288, FakeAdv: 1.2358, RealAux: 0.0051, FakeAux: 0.0015)
# [Epoch 10/10] [Batch 625/1875] [Iter 17500]
#   G loss: -0.0061 (Adv: 0.3508, Aux: 0.0000, VQE_reg: -0.3569, E_c: -3.5690)
#   D loss: 0.8347 (RealAdv: 0.4226, FakeAdv: 1.2244, RealAux: 0.0223, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 675/1875] [Iter 17550]
#   G loss: 0.0056 (Adv: 0.3654, Aux: 0.0000, VQE_reg: -0.3599, E_c: -3.5985)
#   D loss: 0.9026 (RealAdv: 0.4012, FakeAdv: 1.2779, RealAux: 0.1259, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 725/1875] [Iter 17600]
#   G loss: -0.0420 (Adv: 0.3150, Aux: 0.0007, VQE_reg: -0.3577, E_c: -3.5773)
#   D loss: 0.9058 (RealAdv: 0.3814, FakeAdv: 1.2779, RealAux: 0.1522, FakeAux: 0.0002)
# [Epoch 10/10] [Batch 775/1875] [Iter 17650]
#   G loss: 0.0236 (Adv: 0.3799, Aux: 0.0015, VQE_reg: -0.3578, E_c: -3.5783)
#   D loss: 0.8077 (RealAdv: 0.4154, FakeAdv: 1.1937, RealAux: 0.0062, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 825/1875] [Iter 17700]
#   G loss: -0.0332 (Adv: 0.3241, Aux: 0.0001, VQE_reg: -0.3573, E_c: -3.5735)
#   D loss: 0.8447 (RealAdv: 0.4401, FakeAdv: 1.2421, RealAux: 0.0072, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 875/1875] [Iter 17750]
#   G loss: -0.0185 (Adv: 0.3360, Aux: 0.0019, VQE_reg: -0.3564, E_c: -3.5642)
#   D loss: 0.8212 (RealAdv: 0.4036, FakeAdv: 1.2333, RealAux: 0.0052, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 925/1875] [Iter 17800]
#   G loss: -0.0048 (Adv: 0.3487, Aux: 0.0002, VQE_reg: -0.3537, E_c: -3.5369)
#   D loss: 0.8746 (RealAdv: 0.4024, FakeAdv: 1.2126, RealAux: 0.1279, FakeAux: 0.0063)
# [Epoch 10/10] [Batch 975/1875] [Iter 17850]
#   G loss: -0.0358 (Adv: 0.3220, Aux: 0.0002, VQE_reg: -0.3579, E_c: -3.5790)
#   D loss: 0.8638 (RealAdv: 0.3914, FakeAdv: 1.2777, RealAux: 0.0102, FakeAux: 0.0483)
# [Epoch 10/10] [Batch 1025/1875] [Iter 17900]
#   G loss: -0.0342 (Adv: 0.3234, Aux: 0.0000, VQE_reg: -0.3576, E_c: -3.5758)
#   D loss: 0.7978 (RealAdv: 0.3991, FakeAdv: 1.1951, RealAux: 0.0014, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 1075/1875] [Iter 17950]
#   G loss: 0.0153 (Adv: 0.3740, Aux: 0.0001, VQE_reg: -0.3587, E_c: -3.5874)
#   D loss: 0.8023 (RealAdv: 0.4620, FakeAdv: 1.1282, RealAux: 0.0144, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1125/1875] [Iter 18000]
#   G loss: -0.0213 (Adv: 0.3377, Aux: 0.0001, VQE_reg: -0.3591, E_c: -3.5909)
#   D loss: 0.8734 (RealAdv: 0.3993, FakeAdv: 1.3318, RealAux: 0.0155, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 1175/1875] [Iter 18050]
#   G loss: -0.1122 (Adv: 0.2477, Aux: 0.0003, VQE_reg: -0.3602, E_c: -3.6024)
#   D loss: 0.9345 (RealAdv: 0.3624, FakeAdv: 1.5052, RealAux: 0.0013, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1225/1875] [Iter 18100]
#   G loss: -0.0198 (Adv: 0.3335, Aux: 0.0040, VQE_reg: -0.3573, E_c: -3.5734)
#   D loss: 0.8433 (RealAdv: 0.4110, FakeAdv: 1.2048, RealAux: 0.0695, FakeAux: 0.0013)
# [Epoch 10/10] [Batch 1275/1875] [Iter 18150]
#   G loss: -0.0344 (Adv: 0.3224, Aux: 0.0005, VQE_reg: -0.3573, E_c: -3.5730)
#   D loss: 0.7843 (RealAdv: 0.4231, FakeAdv: 1.1430, RealAux: 0.0024, FakeAux: 0.0002)
# [Epoch 10/10] [Batch 1325/1875] [Iter 18200]
#   G loss: -0.0416 (Adv: 0.3133, Aux: 0.0002, VQE_reg: -0.3552, E_c: -3.5519)
#   D loss: 0.8832 (RealAdv: 0.4142, FakeAdv: 1.3515, RealAux: 0.0004, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 1375/1875] [Iter 18250]
#   G loss: 0.0161 (Adv: 0.3737, Aux: 0.0004, VQE_reg: -0.3580, E_c: -3.5801)
#   D loss: 0.8636 (RealAdv: 0.4136, FakeAdv: 1.2676, RealAux: 0.0457, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 1425/1875] [Iter 18300]
#   G loss: -0.0158 (Adv: 0.3438, Aux: 0.0000, VQE_reg: -0.3597, E_c: -3.5966)
#   D loss: 0.8410 (RealAdv: 0.4167, FakeAdv: 1.2596, RealAux: 0.0047, FakeAux: 0.0009)
# [Epoch 10/10] [Batch 1475/1875] [Iter 18350]
#   G loss: -0.0291 (Adv: 0.3292, Aux: 0.0001, VQE_reg: -0.3584, E_c: -3.5841)
#   D loss: 0.8660 (RealAdv: 0.4022, FakeAdv: 1.3291, RealAux: 0.0005, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1525/1875] [Iter 18400]
#   G loss: -0.0246 (Adv: 0.3321, Aux: 0.0000, VQE_reg: -0.3568, E_c: -3.5676)
#   D loss: 0.8464 (RealAdv: 0.4110, FakeAdv: 1.2811, RealAux: 0.0006, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1575/1875] [Iter 18450]
#   G loss: -0.0198 (Adv: 0.3365, Aux: 0.0000, VQE_reg: -0.3564, E_c: -3.5636)
#   D loss: 0.8672 (RealAdv: 0.4093, FakeAdv: 1.2565, RealAux: 0.0684, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 1625/1875] [Iter 18500]
#   G loss: -0.0314 (Adv: 0.3248, Aux: 0.0001, VQE_reg: -0.3563, E_c: -3.5625)
#   D loss: 0.8709 (RealAdv: 0.4026, FakeAdv: 1.3299, RealAux: 0.0090, FakeAux: 0.0002)
# [Epoch 10/10] [Batch 1675/1875] [Iter 18550]
#   G loss: 0.0317 (Adv: 0.3933, Aux: 0.0001, VQE_reg: -0.3617, E_c: -3.6168)
#   D loss: 0.8327 (RealAdv: 0.4081, FakeAdv: 1.2398, RealAux: 0.0013, FakeAux: 0.0161)
# [Epoch 10/10] [Batch 1725/1875] [Iter 18600]
#   G loss: -0.0213 (Adv: 0.3338, Aux: 0.0006, VQE_reg: -0.3557, E_c: -3.5565)
#   D loss: 0.8407 (RealAdv: 0.4302, FakeAdv: 1.2494, RealAux: 0.0017, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1775/1875] [Iter 18650]
#   G loss: -0.0214 (Adv: 0.3384, Aux: 0.0001, VQE_reg: -0.3599, E_c: -3.5994)
#   D loss: 0.8436 (RealAdv: 0.4386, FakeAdv: 1.2407, RealAux: 0.0078, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 1825/1875] [Iter 18700]
#   G loss: -0.0217 (Adv: 0.3321, Aux: 0.0012, VQE_reg: -0.3549, E_c: -3.5494)
#   D loss: 0.8305 (RealAdv: 0.4174, FakeAdv: 1.2414, RealAux: 0.0021, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1875/1875] [Iter 18750]
#   G loss: -0.0418 (Adv: 0.3134, Aux: 0.0012, VQE_reg: -0.3564, E_c: -3.5641)
#   D loss: 0.8627 (RealAdv: 0.3873, FakeAdv: 1.3317, RealAux: 0.0064, FakeAux: 0.0001)
#
# --- End of Epoch 10/10 (Duration: 5005.96s) ---
#   Avg G Loss: -0.0237 (Adv: 0.3320, Aux: 0.0023, VQE_reg: -0.3580, Avg E_c: -3.5797)
#   Avg D Loss: 0.8581 (R_Adv: 0.4071, F_Adv: 1.2821, R_Aux: 0.0247, F_Aux: 0.0024)
#   Samples for epoch 10 saved.
#   Running evaluation for epoch 10...
#   Generating 1000 samples for FID/IS into '/tmp/tmponlf2pnk'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 35.4766, IS (mean): 2.1210
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 96.60%
# ------------------------------------------------------------
#
# Training finished in 14h 9m 1s
# Best FID achieved: 23.2347 at epoch 9.
# Final models saved to '/content/hybrid_acgan_models_output'.

# %% [markdown]
# ## 8. Evaluation and Visualization
#
# This section presents the quantitative evaluation metrics recorded during training.
#
# ### Final Metrics Summary (RUN2 — Seed 2025)
# | Metric | Best Value | Epoch | Final (Epoch 10) |
# |--------|------------|-------|------------------|
# | **FID** | **23.23** | 9 | 35.48 |
# | **Inception Score** | **2.32** | 4 | 2.12 |
# | **Classification Accuracy** | **100.0%** | 5 | 96.6% |
#
# ### Complete FID Progression
# | Epoch | FID Score | Improvement |
# |-------|-----------|-------------|
# | 1 | 117.75 | — |
# | 2 | 57.69 | −60.06 |
# | 3 | 46.86 | −10.83 |
# | 4 | 32.28 | −14.58 |
# | 5 | 24.11 | −8.17 |
# | 6 | 30.19 | +6.08 |
# | 7 | 29.15 | −1.04 |
# | 8 | 24.41 | −4.74 |
# | 9 | **23.23** | −1.18 |
# | 10 | 35.48 | +12.25 |
#
# ### Classification Accuracy Progression
# | Epoch | Accuracy | Epoch | Accuracy |
# |-------|----------|-------|----------|
# | 1 | 87.0% | 6 | 98.2% |
# | 2 | 91.0% | 7 | 98.4% |
# | 3 | 91.2% | 8 | 99.6% |
# | 4 | 98.2% | 9 | 99.4% |
# | 5 | **100.0%** | 10 | 96.6% |
#
# ### Observations
# - **Peak performance at epoch 9**: FID 23.23 represents the best result across all QACGAN experiments
# - **100% accuracy at epoch 5**: Demonstrates strong class conditioning capability
# - **Late-stage overfitting**: FID increase at epoch 10 suggests potential benefit from early stopping

# %%
#@title 9. Visualization of Training Logs

"""
<summary>
Loads the training logs from file and visualizes the training progress of the hybrid ACGAN model.
Plots losses, loss components, energy, FID/IS metrics, and classification accuracy over iterations/epochs.
</summary>
"""

if os.path.exists(LOG_FILE):
    with open(LOG_FILE, 'rb') as f:
        logs = pickle.load(f)

    plt.style.use('seaborn-v0_8-whitegrid')

    fig, axs = plt.subplots(4, 2, figsize=(18, 22))
    fig.suptitle('Hybrid ACGAN-VQER Training Analysis', fontsize=16)

    iters = logs.get('iterations', [])
    epochs_eval = logs.get('eval_epochs', [])

    if iters:
        axs[0, 0].plot(iters, logs.get('g_loss', []), label='G Loss (Total)', color='green', alpha=0.7)
        axs[0, 0].plot(iters, logs.get('d_loss', []), label='D Loss (Total)', color='red', alpha=0.7)
        axs[0, 0].set_xlabel('Iterations')
        axs[0, 0].set_ylabel('Loss')
        axs[0, 0].set_title('Total G and D Losses')
        axs[0, 0].legend()
        axs[0, 0].grid(True, linestyle='--', alpha=0.7)

    if iters:
        axs[0, 1].plot(iters, logs.get('g_adv_loss', []), label='G Adv Loss', color='lightgreen', linestyle='--')
        axs[0, 1].plot(iters, logs.get('g_aux_loss', []), label='G Aux Loss', color='darkgreen', linestyle='-.')
        axs[0, 1].plot(iters, logs.get('g_vqe_loss', []), label='G VQE Reg Loss', color='cyan', linestyle=':')
        axs[0, 1].set_xlabel('Iterations')
        axs[0, 1].set_ylabel('Loss')
        axs[0, 1].set_title('Generator Loss Components')
        axs[0, 1].legend()
        axs[0, 1].grid(True, linestyle='--', alpha=0.7)

    if iters:
        axs[1, 0].plot(iters, logs.get('avg_energy', []), label='Avg E_c (per batch)', color='magenta')
        axs[1, 0].set_xlabel('Iterations')
        axs[1, 0].set_ylabel('Average Energy E_c')
        axs[1, 0].set_title('E_c Energy from VQE Regularization')
        axs[1, 0].legend()
        axs[1, 0].grid(True, linestyle='--', alpha=0.7)

    if iters:
        axs[1, 1].plot(iters, logs.get('d_real_adv_loss', []), label='D Real Adv', color='salmon', linestyle='--')
        axs[1, 1].plot(iters, logs.get('d_fake_adv_loss', []), label='D Fake Adv', color='firebrick', linestyle='--')
        axs[1, 1].plot(iters, logs.get('d_real_aux_loss', []), label='D Real Aux', color='lightcoral', linestyle='-.')
        axs[1, 1].plot(iters, logs.get('d_fake_aux_loss', []), label='D Fake Aux', color='maroon', linestyle='-.')
        axs[1, 1].set_xlabel('Iterations')
        axs[1, 1].set_ylabel('Loss')
        axs[1, 1].set_title('Discriminator Loss Components')
        axs[1, 1].legend()
        axs[1, 1].grid(True, linestyle='--', alpha=0.7)

    if epochs_eval:
        axs[2, 0].plot(epochs_eval, logs.get('fid_scores', []), label='FID Score', marker='o', color='blue')
        axs[2, 0].set_xlabel('Epochs')
        axs[2, 0].set_ylabel('FID (lower is better)')
        axs[2, 0].set_title('Fréchet Inception Distance (FID)')
        axs[2, 0].legend()
        axs[2, 0].grid(True, linestyle='--', alpha=0.7)

    if epochs_eval:
        axs[2, 1].plot(epochs_eval, logs.get('is_scores', []), label='Inception Score (mean)', marker='s', color='purple')
        axs[2, 1].set_xlabel('Epochs')
        axs[2, 1].set_ylabel('IS (higher is better)')
        axs[2, 1].set_title('Inception Score (IS)')
        axs[2, 1].legend()
        axs[2, 1].grid(True, linestyle='--', alpha=0.7)

    if epochs_eval:
        axs[3, 0].plot(epochs_eval, logs.get('classification_accuracy', []), label='Classification Accuracy', marker='^', color='teal')
        axs[3, 0].set_xlabel('Epochs')
        axs[3, 0].set_ylabel('Accuracy (%)')
        axs[3, 0].set_title('External Classifier Accuracy')
        axs[3, 0].legend()
        axs[3, 0].grid(True, linestyle='--', alpha=0.7)

    axs[3, 1].axis('off')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()
else:
    print(f"Log file '{LOG_FILE}' not found. Cannot render plots.")

# %%
#@title 10. Final Sample Generation and Packaging of Results

if os.path.exists(os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_final.pth')):
    print("\nLoading final generator model for sample generation...")
    final_generator = HybridGenerator(
        z_dim=Z_DIM, num_classes=NUM_CLASSES, img_channels=IMG_CHANNELS,
        ansatz_instance=ansatz, list_of_hamiltonians=H_op_list,
        qiskit_estimator=aer_estimator, lambda_vqer_coeff=LAMBDA_VQER
    ).to(device)
    try:
        final_generator.load_state_dict(torch.load(os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_final.pth'), map_location=device))
        final_generator.eval()

        # Display parameters
        samples_per_class_final = 10
        num_final_display_samples = NUM_CLASSES * samples_per_class_final

        # Deterministic final grid
        g_eval = torch.Generator(device=device).manual_seed(SEED + 1001)
        final_z = torch.randn(num_final_display_samples, Z_DIM, device=device, generator=g_eval)
        final_labels_list = []
        for i in range(NUM_CLASSES):
            final_labels_list.extend([i] * samples_per_class_final)
        final_labels = torch.LongTensor(final_labels_list).to(device)

        with torch.no_grad():
            gen_imgs_final_classic, _ = final_generator(final_z, final_labels)

        save_image(gen_imgs_final_classic.data,
                   os.path.join(OUTPUT_DIR_IMAGES, "hybrid_acgan_final_grid_all_classes.png"),
                   nrow=samples_per_class_final, normalize=True)
        print(f"Final sample grid saved to '{OUTPUT_DIR_IMAGES}'.")

        # Per-class sample sheets (deterministic)
        for digit_class in range(NUM_CLASSES):
            g_eval_cls = torch.Generator(device=device).manual_seed(SEED + 2000 + digit_class)
            class_z = torch.randn(samples_per_class_final, Z_DIM, device=device, generator=g_eval_cls)
            class_labels = torch.full((samples_per_class_final,), digit_class, dtype=torch.long, device=device)
            with torch.no_grad():
                gen_imgs_class_specific, _ = final_generator(class_z, class_labels)
            save_image(gen_imgs_class_specific.data,
                       os.path.join(OUTPUT_DIR_IMAGES, f"hybrid_acgan_final_samples_class_{digit_class}.png"),
                       nrow=samples_per_class_final, normalize=True)
        print(f"Final samples for individual classes saved to '{OUTPUT_DIR_IMAGES}'.")

    except Exception as e:
        print(f"Error during final sample generation: {e}")
else:
    print("Final generator model not found, samples will not be generated.")

def zip_and_download_results_colab(folders_to_zip, files_to_zip, zip_filename_base="hybrid_acgan_results", work_dir="/content/"):
    """
    <summary>
    Packages selected folders and files into a ZIP archive, downloads it to the user, and deletes the temporary directory in the Google Colab environment.
    </summary>
    <param name="folders_to_zip">List of folder paths to include in the ZIP archive.</param>
    <param name="files_to_zip">List of file paths to include in the ZIP archive.</param>
    <param name="zip_filename_base">Base name of the resulting ZIP file.</param>
    <param name="work_dir">Working directory where the archive will be created.</param>
    """
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    zip_filename = f"{zip_filename_base}_{timestamp}.zip"
    zip_filepath = os.path.join(work_dir, zip_filename)

    temp_archive_dir_name = f"temp_archive_{timestamp}"
    temp_archive_dir_path = os.path.join(work_dir, temp_archive_dir_name)
    os.makedirs(temp_archive_dir_path, exist_ok=True)

    print(f"\nCopying files and folders to temporary directory '{temp_archive_dir_path}' for archiving...")
    for folder_path in folders_to_zip:
        if os.path.isdir(folder_path):
            dest_folder_name = os.path.basename(os.path.normpath(folder_path))
            shutil.copytree(folder_path, os.path.join(temp_archive_dir_path, dest_folder_name))
            print(f"  - Folder '{dest_folder_name}' copied.")
        else:
            print(f"  - Warning: Folder '{folder_path}' not found.")

    for file_item_path in files_to_zip:
        if os.path.isfile(file_item_path):
            shutil.copy(file_item_path, temp_archive_dir_path)
            print(f"  - File '{os.path.basename(file_item_path)}' copied.")
        else:
            print(f"  - Warning: File '{file_item_path}' not found.")

    print("Creating ZIP archive...")
    try:
        shutil.make_archive(os.path.join(work_dir, zip_filename_base + "_" + timestamp),
                            'zip',
                            root_dir=temp_archive_dir_path)
        print(f"ZIP archive '{zip_filepath}' successfully created.")

        shutil.rmtree(temp_archive_dir_path)
        print(f"Temporary directory '{temp_archive_dir_path}' deleted.")

        print(f"Starting download of file '{zip_filename}'...")
        files.download(zip_filepath)
        print("Download started. The file should appear in your browser.")

    except Exception as e:
        print(f"ERROR during creation or download of ZIP archive: {e}")
        if os.path.exists(temp_archive_dir_path):
            shutil.rmtree(temp_archive_dir_path)

folders_to_include = [OUTPUT_DIR_IMAGES, OUTPUT_DIR_MODELS]
files_to_include = [LOG_FILE]
if os.path.exists(CLASSIFIER_PATH):
    files_to_include.append(CLASSIFIER_PATH)

zip_and_download_results_colab(folders_to_include, files_to_include)
# Out:
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# Loading final generator model for sample generation...
# Final sample grid saved to '/content/hybrid_acgan_images_output'.
# Final samples for individual classes saved to '/content/hybrid_acgan_images_output'.
#
# Copying files and folders to temporary directory '/content/temp_archive_20250928_015001' for archiving...
#   - Folder 'hybrid_acgan_images_output' copied.
#   - Folder 'hybrid_acgan_models_output' copied.
#   - File 'hybrid_acgan_training_logs.pkl' copied.
#   - File 'mnist_classifier.pth' copied.
# Creating ZIP archive...
# ZIP archive '/content/hybrid_acgan_results_20250928_015001.zip' successfully created.
# Temporary directory '/content/temp_archive_20250928_015001' deleted.
# Starting download of file 'hybrid_acgan_results_20250928_015001.zip'...
# Download started. The file should appear in your browser.

# %% [markdown]
# ## 9. Discussion and Conclusion
#
# ### Key Findings from RUN2
#
# This experiment (seed 2025) achieved the **best FID score (23.23)** among all QACGAN runs, demonstrating:
#
# 1. **Consistent convergence**: FID improved from 117.75 → 23.23 over 9 epochs
# 2. **Strong class conditioning**: 100% classification accuracy at epoch 5
# 3. **Reproducibility**: Results align with RUN1 (seed 42), confirming model stability
#
# ### Cross-Run Comparison (QACGAN)
# | Metric | RUN1 (seed 42) | RUN2 (seed 2025) | 5-Epoch Demo |
# |--------|----------------|------------------|--------------|
# | Best FID | 23.91 | **23.23** | 19.92 |
# | Best IS | 2.29 | **2.32** | 2.07 |
# | Best Accuracy | 99.4% | **100.0%** | 99.0% |
# | Training Epochs | 10 | 10 | 5 |
#
# ### ACGAN vs QACGAN Summary
# | Aspect | Classical ACGAN | Hybrid QACGAN |
# |--------|-----------------|---------------|
# | Best FID | 24.02 (epoch 20) | **23.23** (epoch 9) |
# | Epochs to FID < 25 | 20 | 9 |
# | Physics-inspired regularization | ❌ | ✅ (VQE + Ising) |
# | Computational cost | ~2 min/epoch | ~1.45 h/epoch |
#
# ### Limitations
# - **Simulation overhead**: Quantum circuit simulation adds significant computational cost
# - **Scalability**: Current 4-qubit ansatz limits expressivity
# - **Hardware gap**: Results from statevector simulation; real hardware may differ
#
# ### Future Directions
# 1. **Hardware validation**: Deploy on IBM Quantum or IonQ devices
# 2. **Deeper ansatzes**: Explore more repetition layers and entanglement patterns
# 3. **Noise-aware training**: Integrate quantum error mitigation techniques
# 4. **Larger datasets**: Extend to CIFAR-10 or Fashion-MNIST
#
# > **Conclusion:** RUN2 confirms that VQE-inspired regularization provides a physics-motivated inductive bias that accelerates GAN convergence while maintaining competitive image quality. The best FID of 23.23 validates the hybrid quantum-classical approach for generative modeling.

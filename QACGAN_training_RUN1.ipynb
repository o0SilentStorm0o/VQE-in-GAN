# %% [markdown]
# # Hybrid QACGAN with VQE Regularization (Extended Run 1 — 10 Epochs)
#
# **Author:** David Strnadel
# **Date:** December 2025
# **Affiliation:** Faculty of Applied Informatics, Tomas Bata University in Zlin

# %% [markdown]
# ## Abstract
#
# This notebook implements an extended **10-epoch training run** of the hybrid **Quantum-enhanced Auxiliary Classifier GAN (QACGAN)** with VQE-based energy regularization. This run uses **seed 42** (same as the 5-epoch exploratory run) to assess whether longer training improves stability and final metrics.
#
# **Key Results (10 Epochs, Seed 42):**
# - **Best FID**: **23.91** at epoch 10 (vs. 19.92 at epoch 5 in exploratory run)
# - **FID at epoch 5**: 35.96 (demonstrating high early-epoch variance)
# - **Best IS**: **2.29** at epoch 2
# - **Best Accuracy**: **99.4%** at epochs 7 and 9
# - **Training Time**: ~14h 2min (noiseless statevector simulation)
#
# ### Key Observations
# This run reveals significant **variance in early-epoch FID**: the same seed that achieved FID 19.92 at epoch 5 in the exploratory run now shows FID 35.96 at the same point. However, FID stabilizes to 23.91 by epoch 10, competitive with the ACGAN baseline (24.02).
#
# > **Note:** Results are obtained on a noiseless simulator. The variance across runs highlights the sensitivity of GAN training to initialization details.

# %% [markdown]
# ## 1. Reproducible Environment
#
# This notebook is designed to run on **Google Colab** with GPU acceleration. Execute the cells below to install all required dependencies:
#
# - **Qiskit** and **Qiskit Machine Learning**: Quantum computing framework for VQE simulation
# - **PyTorch** and **torchvision**: Deep learning framework for GAN implementation
# - **torch-fidelity**: Library for computing FID and Inception Score metrics
#
# > **Note:** The quantum simulation runs on a noiseless `StatevectorEstimator` backend. No real quantum hardware is used.

# %%
#@title Installation of Required Libraries

# !pip install --upgrade pip -q
# !pip install \
    qiskit \
    qiskit-aer \
    torch \
    torch-fidelity \
    scikit-image \
    ipywidgets \
    pylatexenc \
    -q

# !pip install \
  git+https://github.com/qiskit-community/qiskit-machine-learning.git@main#egg=qiskit-machine-learning \
  -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 78.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   DEPRECATION: Building 'pylatexenc' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pylatexenc'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pylatexenc (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for qiskit-machine-learning (pyproject.toml) ... done

# %% [markdown]
# ## 2. Theoretical Foundations
#
# ### Generative Adversarial Networks (GANs)
# GANs consist of two neural networks—a Generator $G$ and a Discriminator $D$—trained in an adversarial minimax game. Training can suffer from instability and mode collapse.
#
# ### Auxiliary Classifier GAN (ACGAN)
# ACGAN extends GANs by having the discriminator predict both image authenticity (real/fake) and class labels. The generator $G(z, c)$ produces class-conditional images, leading to more stable training and improved sample quality.
#
# ### Variational Quantum Eigensolver (VQE)
# VQE is a hybrid quantum-classical algorithm that minimizes the expectation value of a Hamiltonian $\mathcal{H}$ using a parameterized quantum circuit (ansatz) and classical optimization:
# $$E(\vec{\theta}) = \langle \psi(\vec{\theta}) | \mathcal{H} | \psi(\vec{\theta}) \rangle$$
#
# ### Ising Hamiltonian for Class-Specific Regularization
# In QACGAN, each class $c$ is associated with an Ising Hamiltonian:
# $$H_c = -J \sum_{\langle i,j \rangle} \sigma_z^i \sigma_z^j - \sum_{i=1}^{N} h_{c,i} \sigma_z^i$$
#
# The VQE energy $E_c$ acts as a physics-inspired regularization term in the generator objective.

# %%
#@title Verification of Required Libraries Installation

import torch, qiskit, qiskit_machine_learning, torch_fidelity

"""
<summary>
This script prints the versions of the main libraries (PyTorch, Qiskit, Qiskit Machine Learning, Torch-Fidelity)
and verifies the availability of key modules for quantum-classical machine learning.
</summary>
"""

print("PyTorch version:      ", torch.__version__)
print("Qiskit version:       ", qiskit.__version__)
print("Qiskit-ML version:    ", qiskit_machine_learning.__version__)
print("Torch-Fidelity ver.:  ", torch_fidelity.__version__)

from qiskit.primitives import StatevectorEstimator
from qiskit_aer import AerSimulator
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector

print("✅ All key modules imported successfully!")
# Out:
# PyTorch version:       2.8.0+cu126
# Qiskit version:        1.4.4
# Qiskit-ML version:     0.9.0
# Torch-Fidelity ver.:   0.3.0
# ✅ All key modules imported successfully!

# %%
#@title 1. Imports
"""
<summary>
Installation and import of required libraries for PyTorch, Qiskit, and other utilities used in the project.
</summary>
<remarks>
This script contains imports for working with neural networks in PyTorch, image processing with torchvision and skimage,
evaluation with torch-fidelity, and quantum libraries Qiskit including Qiskit Machine Learning.
It also includes multiprocessing setup and version printing of key libraries.
</remarks>
"""

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets, transforms
from torchvision.utils import save_image, make_grid
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import time
import shutil
import tempfile
from skimage.transform import resize

from torch_fidelity import calculate_metrics

from qiskit import QuantumCircuit
from qiskit.circuit.library import EfficientSU2
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives import StatevectorEstimator
from qiskit_aer import AerSimulator
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector

from IPython.display import clear_output
import datetime
from google.colab import files

try:
    torch.multiprocessing.set_start_method('spawn', force=True)
    print("Multiprocessing start method set to 'spawn'.")
except RuntimeError:
    print("Multiprocessing start method was already set.")

print(f"PyTorch version: {torch.__version__}")
import qiskit
print(f"Qiskit version: {qiskit.__version__}")
import qiskit_machine_learning
print(f"Qiskit Machine Learning version: {qiskit_machine_learning.__version__}")
# Out:
# Multiprocessing start method set to 'spawn'.
# PyTorch version: 2.8.0+cu126
# Qiskit version: 1.4.4
# Qiskit Machine Learning version: 0.9.0

# %%
#@title 2. Device, Paths and Configuration Setup
"""
<summary>
Device setup (CPU/GPU), path configuration and check of required files in Google Colab environment for training and evaluation of the model.
</summary>
<remarks>
The script automatically detects GPU availability, sets the appropriate memory format, defines working and output paths, creates required directories, and verifies the presence of the MNIST classifier.
</remarks>
"""

if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
    MEMORY_FORMAT = torch.channels_last
else:
    device = torch.device("cpu")
    print("GPU not available, using CPU.")
    MEMORY_FORMAT = torch.contiguous_format
print(f"Device in use: {device}, Preferred memory format for models: {MEMORY_FORMAT}")

WORK_DIR = "/content/"
MNIST_DOWNLOAD_PATH = os.path.join(WORK_DIR, "MNIST_data")
MNIST_TRAIN_IMAGES_PATH = os.path.join(MNIST_DOWNLOAD_PATH, "MNIST_train_images_png")
OUTPUT_DIR_IMAGES = os.path.join(WORK_DIR, "hybrid_acgan_images_output")
OUTPUT_DIR_MODELS = os.path.join(WORK_DIR, "hybrid_acgan_models_output")
LOG_FILE = os.path.join(WORK_DIR, "hybrid_acgan_training_logs.pkl")
CLASSIFIER_PATH = os.path.join(WORK_DIR, "mnist_classifier.pth")

os.makedirs(MNIST_DOWNLOAD_PATH, exist_ok=True)
os.makedirs(OUTPUT_DIR_IMAGES, exist_ok=True)
os.makedirs(OUTPUT_DIR_MODELS, exist_ok=True)
print(f"Working directory: {WORK_DIR}")
print(f"Path for MNIST PNG (FID): {MNIST_TRAIN_IMAGES_PATH}")

if not os.path.exists(CLASSIFIER_PATH):
    print(f"\n!!! WARNING: Classifier file '{CLASSIFIER_PATH}' not found! !!!")
    print("Please upload 'mnist_classifier.pth' into Colab (e.g., drag & drop into Files).")
    print("Without it, classification accuracy of generated images cannot be computed.")
else:
    print(f"\nClassifier file '{CLASSIFIER_PATH}' found.")
# Out:
# GPU is available: NVIDIA A100-SXM4-40GB
# Device in use: cuda, Preferred memory format for models: torch.channels_last
# Working directory: /content/
# Path for MNIST PNG (FID): /content/MNIST_data/MNIST_train_images_png
#
# Classifier file '/content/mnist_classifier.pth' found.

# %%
#@title 3. Hyperparameters and Training Configuration
"""
<summary>
Setup of hyperparameters and training configuration for the hybrid quantum-classical model, including model parameters, quantum settings, training hyperparameters, logging and evaluation configuration, and seed initialization for reproducibility.
</summary>
"""

SEED = 42
Z_DIM = 100
NUM_CLASSES = 10
IMG_CHANNELS = 1
IMG_SIZE = 28

N_QUBITS = 4
ANSAETZ_REPS = 1
LAMBDA_VQER = 0.1
ISING_J = 1.0
ISING_H_GLOBAL = 0.1

NUM_EPOCHS = 10
EFFECTIVE_BATCH_SIZE = 64
MICRO_BATCH_SIZE = 32
ACCUMULATION_STEPS = EFFECTIVE_BATCH_SIZE // MICRO_BATCH_SIZE

LEARNING_RATE_G = 0.0002
LEARNING_RATE_D = 0.0002
BETA1 = 0.5
BETA2 = 0.999
LABEL_SMOOTHING = 0.9

LOG_INTERVAL = 50
EVAL_INTERVAL = 1
SAVE_SAMPLES_INTERVAL = 1

NUM_SAMPLES_FOR_METRICS = 1000
NUM_SAMPLES_FOR_ACCURACY = 500

FIDELITY_BATCH_SIZE = MICRO_BATCH_SIZE
FIDELITY_NUM_WORKERS = 2

USE_AMP = False

torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

print(f"Hyperparameters set. Effective batch size: {EFFECTIVE_BATCH_SIZE}")
print(f"Number of qubits for quantum part: {N_QUBITS}")
print(f"Lambda for VQE regularization: {LAMBDA_VQER}")
# Out:
# Hyperparameters set. Effective batch size: 64
# Number of qubits for quantum part: 4
# Lambda for VQE regularization: 0.1

# %% [markdown]
# ## 4. Quantum Components
#
# This section defines the quantum building blocks for VQE-based regularization:
#
# - **`build_ising_hamiltonian_op`** — Constructs a `SparsePauliOp` representation of the Ising Hamiltonian $H_c$ from the number of qubits, coupling coefficient $J$, and class-specific local fields $h_{c,i}$.
#
# - **EfficientSU2 Ansatz** — A hardware-efficient parameterized quantum circuit with circular entanglement, used to prepare quantum states $|\psi(\vec{\theta})\rangle$.
#
# - **StatevectorEstimator** — Qiskit's noiseless statevector simulator for computing expectation values $\langle H_c \rangle$.

# %%
#@title 4. Definition of Quantum Components
"""
<summary>
Definition of quantum components for the hybrid model:
- Creation of EfficientSU2 ansatz, calculation of the number of ansatz parameters
- Construction of Ising Hamiltonians for each class using SparsePauliOp
- Initialization of StatevectorEstimator for energy computations of quantum states
</summary>
"""

ansatz = EfficientSU2(num_qubits=N_QUBITS, reps=ANSAETZ_REPS, entanglement='circular', insert_barriers=True)
NUM_ANSATZ_PARAMS = ansatz.num_parameters
print(f"Quantum Ansatz: EfficientSU2 with {N_QUBITS} qubits and {ANSAETZ_REPS} reps.")
print(f"Number of ansatz parameters: {NUM_ANSATZ_PARAMS}")

def build_ising_hamiltonian_op(n_qubits, J_coeff=1.0, h_coeffs_list=None):
    """
    <summary>
    Creates an Ising Hamiltonian as SparsePauliOp.
    </summary>
    <param name="n_qubits">Number of qubits in the system.</param>
    <param name="J_coeff">Coefficient of ZZ interaction term.</param>
    <param name="h_coeffs_list">List of external field Z coefficients for each qubit.</param>
    <returns>SparsePauliOp representing the Ising Hamiltonian.</returns>
    """
    if h_coeffs_list is None:
        h_coeffs_list = [ISING_H_GLOBAL] * n_qubits
    if len(h_coeffs_list) != n_qubits:
        raise ValueError("Length of h_coeffs_list must equal n_qubits.")

    pauli_terms = []
    coeffs = []

    for i in range(n_qubits - 1):
        pauli_str = ['I'] * n_qubits
        pauli_str[i] = 'Z'
        pauli_str[i+1] = 'Z'
        pauli_terms.append("".join(pauli_str))
        coeffs.append(-J_coeff)

    for i in range(n_qubits):
        pauli_str = ['I'] * n_qubits
        pauli_str[i] = 'Z'
        pauli_terms.append("".join(pauli_str))
        coeffs.append(-h_coeffs_list[i])

    return SparsePauliOp(pauli_terms, coeffs=coeffs)

H_op_list = []
for i in range(NUM_CLASSES):
    h_coeffs_class = [ISING_H_GLOBAL + (i * 0.01) for _ in range(N_QUBITS)]
    H_op_list.append(build_ising_hamiltonian_op(N_QUBITS, J_coeff=ISING_J, h_coeffs_list=h_coeffs_class))

print(f"Created {len(H_op_list)} Hamiltonians (one per class).")
print(f"Example Hamiltonian for class 0: {H_op_list[0].paulis}")

aer_estimator = StatevectorEstimator()
print("StatevectorEstimator initialized.")
# Out:
# Quantum Ansatz: EfficientSU2 with 4 qubits and 1 reps.
# Number of ansatz parameters: 16
# Created 10 Hamiltonians (one per class).
# Example Hamiltonian for class 0: ['ZZII', 'IZZI', 'IIZZ', 'ZIII', 'IZII', 'IIZI', 'IIIZ']
# StatevectorEstimator initialized.

# %% [markdown]
# ## Model Architecture
#
# ### HybridGenerator
# - *Classical branch*: transposed convolutions ➜ 28×28 px image.
# - *VQE-energy branch* (active if `lambda_vqer > 0`):
#   1. `AngleProducer` → angles $\theta$
#   2. **EfficientSU2** ansatz on `N_QUBITS` qubits
#   3. **EstimatorQNN** + precomputed Ising $H_c$ ➜ class-specific energy $E_c$.
# The output of `forward` method is the pair *(fake_imgs, E_c)*.
#
# ### Discriminator (QACGAN-D)
# - Main convolution block ends with 4×4 feature map, which is flattened and leads to two branches:
#   * **adv_layer** – estimate of image authenticity
#   * **aux_layer** – class prediction (10 output neurons)
#
# This architecture proved to be more stable than the 1×1 convolution of the original ACGAN.

# %%
#@title 5. Definition of Models (Discriminator, Classifier, Hybrid Generator)
# --- 5.1 Classical MNIST Classifier (for evaluation) ---
class MnistClassifier(nn.Module):
    """
    <summary>
    Classical convolutional neural network classifier for the MNIST dataset.
    </summary>
    <param name="num_classes">Number of classes for classification (default 10).</param>
    <returns>Logits for each class.</returns>
    """
    def __init__(self, num_classes=10):
        super(MnistClassifier, self).__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.flatten_size = 64 * 7 * 7
        self.fc_block = nn.Sequential(
            nn.Linear(self.flatten_size, 1024),
            nn.ReLU(),
            nn.Linear(1024, num_classes))
    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = x.reshape(x.size(0), -1)
        logits = self.fc_block(x)
        return logits

# --- 5.2 Classical ACGAN Discriminator ---
class Discriminator(nn.Module):
    """
    <summary>
    Discriminator for the ACGAN architecture with recognition of both class and image authenticity.
    </summary>
    <param name="num_classes">Number of classes for the classification output.</param>
    <param name="img_channels">Number of channels of input images.</param>
    <returns>
        validity: Image authenticity score.
        class_logits: Logits for class prediction.
    </returns>
    """
    def __init__(self, num_classes=NUM_CLASSES, img_channels=IMG_CHANNELS):
        super(Discriminator, self).__init__()
        self.num_classes = num_classes
        self.img_channels = img_channels

        self.main_conv = nn.Sequential(
            nn.Conv2d(self.img_channels, 64, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
        )
        self.adv_layer = nn.Sequential(
            nn.Linear(256 * 4 * 4, 1),
            nn.Sigmoid()
        )
        self.aux_layer = nn.Sequential(
            nn.Linear(256 * 4 * 4, self.num_classes)
        )

    def forward(self, img):
        features = self.main_conv(img)
        flat_features = features.contiguous().view(features.size(0), -1)
        validity = self.adv_layer(flat_features)
        class_logits = self.aux_layer(flat_features)
        return validity, class_logits

# --- 5.3 Component for generating angles for the quantum ansatz ---
class AngleProducer(nn.Module):
    """
    <summary>
    Module producing angles for the parameterized quantum ansatz based on input noise and a conditional label.
    </summary>
    <param name="z_dim">Dimension of the latent vector.</param>
    <param name="num_classes">Number of classes for embedding.</param>
    <param name="num_ansatz_params">Number of parameters of the quantum ansatz.</param>
    <returns>Tensor of angles for the quantum ansatz in the range [-π, π].</returns>
    """
    def __init__(self, z_dim, num_classes, num_ansatz_params):
        super(AngleProducer, self).__init__()
        self.label_embedding = nn.Embedding(num_classes, z_dim)
        self.fc_net = nn.Sequential(
            nn.Linear(z_dim, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, num_ansatz_params),
            nn.Tanh()
        )
        self.num_ansatz_params = num_ansatz_params

    def forward(self, z, class_labels):
        embedded_labels = self.label_embedding(class_labels)
        conditioned_z = z * embedded_labels
        angles = self.fc_net(conditioned_z)
        return angles * torch.pi

# --- 5.4 Hybrid Generator (ACGAN + VQE regularization) ---
class HybridGenerator(nn.Module):
    """
    <summary>
    Hybrid generator combining the classical ACGAN architecture and quantum VQE regularization via an ansatz and Ising Hamiltonians.
    </summary>
    <param name="z_dim">Dimension of the input latent vector.</param>
    <param name="num_classes">Number of classes for conditional generation.</param>
    <param name="img_channels">Number of channels of the output image.</param>
    <param name="ansatz_instance">Instance of the parameterized quantum ansatz.</param>
    <param name="list_of_hamiltonians">List of SparsePauliOp Hamiltonians (one per class).</param>
    <param name="qiskit_estimator">Instance of Qiskit estimator for energy computations.</param>
    <param name="lambda_vqer_coeff">Weight of the VQE regularization term in the loss function.</param>
    <returns>
        img_classic: Generated image.
        E_c_batch: Energy for each sample in the batch.
    </returns>
    """
    def __init__(self, z_dim, num_classes, img_channels,
                 ansatz_instance,
                 list_of_hamiltonians,
                 qiskit_estimator,
                 lambda_vqer_coeff):
        super(HybridGenerator, self).__init__()

        self.z_dim = z_dim
        self.num_classes = num_classes
        self.img_channels = img_channels
        self.ansatz = ansatz_instance
        self.num_ansatz_params = ansatz_instance.num_parameters
        self.lambda_vqer = lambda_vqer_coeff

        self.classic_label_embedding = nn.Embedding(self.num_classes, self.num_classes)
        self.classic_input_layer = nn.Linear(self.z_dim + self.num_classes, 256 * 7 * 7)
        self.classic_main_generator_cnn = nn.Sequential(
            nn.BatchNorm2d(256),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(256, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128, momentum=0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64, momentum=0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, self.img_channels, kernel_size=3, stride=1, padding=1),
            nn.Tanh()
        )

        self.angle_producer = AngleProducer(self.z_dim, self.num_classes, self.num_ansatz_params)

        self.qnn_module_list = nn.ModuleList()
        for h_op in list_of_hamiltonians:
            qnn_c = EstimatorQNN(
                circuit=self.ansatz,
                observables=h_op,
                input_params=list(self.ansatz.parameters),
                input_gradients=True,
                estimator=qiskit_estimator
            )
            self.qnn_module_list.append(TorchConnector(qnn_c, initial_weights=None))

    def forward(self, z, class_labels):
        classic_embedded_lbls = self.classic_label_embedding(class_labels)
        classic_gen_in = torch.cat((z, classic_embedded_lbls), 1)
        classic_img_features_flat = self.classic_input_layer(classic_gen_in)
        classic_img_features_map = classic_img_features_flat.view(classic_img_features_flat.size(0), 256, 7, 7)
        img_classic = self.classic_main_generator_cnn(classic_img_features_map)

        angles_for_qnn = self.angle_producer(z, class_labels)

        batch_size = z.size(0)
        energies_for_batch = []
        for i in range(batch_size):
            label_index = class_labels[i].item()
            qnn_for_this_class = self.qnn_module_list[label_index]
            current_sample_angles = angles_for_qnn[i].unsqueeze(0)
            energy_tensor = qnn_for_this_class(current_sample_angles)
            energies_for_batch.append(energy_tensor.squeeze())

        E_c_batch = torch.stack(energies_for_batch)
        return img_classic, E_c_batch

# --- Weight initialization ---
def weights_init(m):
    """
    <summary>
    Initializes model weights depending on the layer type.
    </summary>
    <param name="m">Model layer.</param>
    """
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0)

print("Model definitions and weight initialization completed.")
# Out:
# Model definitions and weight initialization completed.

# %% [markdown]
# ## Data preparation
#
# Download, normalize, and split the **MNIST** dataset. Make sure to use deterministic seeds for reproducibility.

# %%
#@title 6. Dataset preparation and helper functions

def save_mnist_as_images(dataset_path_root, output_dir):
    """
    <summary>
    Save images from the MNIST training split as PNG files into the given folder.
    Checks whether the folder already contains a sufficient number of images; regenerates if needed.
    </summary>
    <param name="dataset_path_root">Path to the root folder for the MNIST dataset.</param>
    <param name="output_dir">Target directory to store the PNG images.</param>
    <returns>True if images were successfully written or already present; otherwise False.</returns>
    """
    num_mnist_train = 60000
    if os.path.exists(output_dir):
        try:
            num_files = len([f for f in os.listdir(output_dir) if f.endswith('.png')])
            if num_files >= num_mnist_train:
                print(f"Directory '{output_dir}' already exists and appears complete. Skipping PNG generation.")
                return True
            else:
                print(f"Directory '{output_dir}' exists but is incomplete. Removing and regenerating.")
                shutil.rmtree(output_dir)
        except OSError as e:
            print(f"Error while checking directory {output_dir}: {e}. Proceeding with generation...")

    os.makedirs(output_dir, exist_ok=True)
    print(f"Generating MNIST training images into '{output_dir}'...")
    transform_save = transforms.Compose([transforms.ToTensor()])
    try:
        mnist_dataset = datasets.MNIST(root=dataset_path_root, train=True, download=True, transform=transform_save)
    except Exception as e:
        print(f"FATAL: Failed to download/load the MNIST dataset from '{dataset_path_root}'. Error: {e}")
        return False

    for i, (image, label) in enumerate(mnist_dataset):
        save_image(image, os.path.join(output_dir, f"mnist_train_{i:05d}.png"), normalize=False)
        if (i + 1) % 5000 == 0:
            print(f"  Saved {i + 1}/{len(mnist_dataset)} images...")
    print(f"Successfully saved {len(mnist_dataset)} MNIST PNG images to '{output_dir}'.")
    return True

if not save_mnist_as_images(MNIST_DOWNLOAD_PATH, MNIST_TRAIN_IMAGES_PATH):
    print("Error while preparing MNIST PNG images. FID computation will not be possible.")

transform_train = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

try:
    train_dataset = datasets.MNIST(root=MNIST_DOWNLOAD_PATH, train=True, download=False, transform=transform_train)
    train_loader = DataLoader(train_dataset, batch_size=MICRO_BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)
    print(f"MNIST training dataset loaded: {len(train_dataset)} samples.")
except Exception as e:
    print(f"Failed to load MNIST dataset, error: {e}.")

def save_generated_samples(epoch, generator_model, fixed_z_noise, fixed_class_labels, output_path, num_samples_per_class=5):
    """
    <summary>
    Save generated sample images from the generator for a given epoch into a PNG file in the specified folder.
    </summary>
    <param name="epoch">Current epoch number.</param>
    <param name="generator_model">Generator instance.</param>
    <param name="fixed_z_noise">Fixed noise vector used for sample generation.</param>
    <param name="fixed_class_labels">Fixed labels used for sample generation.</param>
    <param name="output_path">Destination directory for the PNG file.</param>
    <param name="num_samples_per_class">Number of images per class in a single PNG row.</param>
    """
    generator_model.eval()
    with torch.no_grad():
        gen_imgs_classic, _ = generator_model(fixed_z_noise.to(device), fixed_class_labels.to(device))
        save_image(gen_imgs_classic.data,
                   os.path.join(output_path, f"hybrid_acgan_samples_epoch_{epoch:03d}.png"),
                   nrow=num_samples_per_class, normalize=True)
    generator_model.train()

def evaluate_hybrid_model(epoch, generator_model, ext_classifier,
                          num_metrics_samples, num_accuracy_samples,
                          ref_mnist_png_path, current_device):
    """
    <summary>
    Evaluate the hybrid generator using FID, IS, and classification accuracy.
    Generates samples, stores them temporarily for metric computation, and optionally computes accuracy using an external classifier.
    </summary>
    <param name="epoch">Epoch index (for logging).</param>
    <param name="generator_model">Generator instance.</param>
    <param name="ext_classifier">External classifier for accuracy evaluation (optional).</param>
    <param name="num_metrics_samples">Number of samples for FID/IS.</param>
    <param name="num_accuracy_samples">Number of samples for accuracy testing.</param>
    <param name="ref_mnist_png_path">Path to reference MNIST PNG images.</param>
    <param name="current_device">Device in use (CPU/GPU).</param>
    <returns>
        tuple(fid_score, is_score_mean, classification_accuracy)
        fid_score: Frechet Inception Distance value.
        is_score_mean: Mean Inception Score.
        classification_accuracy: Accuracy of the generated images.
    </returns>
    """
    generator_model.eval()
    if ext_classifier: ext_classifier.eval()

    fid_score, is_score_mean, classification_accuracy = float('nan'), float('nan'), float('nan')
    temp_gen_img_dir = tempfile.mkdtemp()

    try:
        print(f"  Generating {num_metrics_samples} samples for FID/IS into '{temp_gen_img_dir}'...")
        img_counter = 0
        with torch.no_grad():
            num_batches_needed = (num_metrics_samples + MICRO_BATCH_SIZE - 1) // MICRO_BATCH_SIZE
            for _ in range(num_batches_needed):
                if img_counter >= num_metrics_samples: break
                batch_z = torch.randn(MICRO_BATCH_SIZE, Z_DIM, device=current_device)
                batch_labels_fid = torch.randint(0, NUM_CLASSES, (MICRO_BATCH_SIZE,), device=current_device)
                gen_imgs_fid_classic, _ = generator_model(batch_z, batch_labels_fid)
                for img_tensor in gen_imgs_fid_classic.detach().cpu():
                    if img_counter >= num_metrics_samples: break
                    save_image(img_tensor,
                               os.path.join(temp_gen_img_dir, f"fid_img_{img_counter:05d}.png"),
                               normalize=True)
                    img_counter += 1

        if img_counter >= num_metrics_samples:
            print(f"  Saved {img_counter} images for metrics. Computing FID/IS via torch-fidelity...")
            metrics_dict = calculate_metrics(
                input1=temp_gen_img_dir,
                input2=ref_mnist_png_path,
                cuda=torch.cuda.is_available(),
                isc=True, fid=True,
                batch_size=FIDELITY_BATCH_SIZE,
                num_workers=FIDELITY_NUM_WORKERS,
                verbose=False
            )
            fid_score = metrics_dict.get('frechet_inception_distance', float('nan'))
            is_score_mean = metrics_dict.get('inception_score_mean', float('nan'))
            print(f"  FID: {fid_score:.4f}, IS (mean): {is_score_mean:.4f}")
        else:
            print(f"  Not enough generated samples ({img_counter}/{num_metrics_samples}) for FID/IS.")

    except Exception as e:
        print(f"  ERROR while computing FID/IS: {e}")
    finally:
        if os.path.exists(temp_gen_img_dir):
            shutil.rmtree(temp_gen_img_dir)

    if ext_classifier:
        try:
            print(f"  Generating {num_accuracy_samples} samples for classification test...")
            all_preds, all_targets = [], []
            num_samples_per_class_acc = num_accuracy_samples // NUM_CLASSES
            with torch.no_grad():
                for digit_class in range(NUM_CLASSES):
                    acc_z = torch.randn(num_samples_per_class_acc, Z_DIM, device=current_device)
                    acc_target_labels = torch.full((num_samples_per_class_acc,), digit_class, dtype=torch.long, device=current_device)
                    gen_imgs_acc_classic, _ = generator_model(acc_z, acc_target_labels)
                    outputs = ext_classifier(gen_imgs_acc_classic)
                    _, predicted = torch.max(outputs.data, 1)
                    all_preds.append(predicted.cpu())
                    all_targets.append(acc_target_labels.cpu())

            if all_preds:
                all_preds_tensor = torch.cat(all_preds)
                all_targets_tensor = torch.cat(all_targets)
                correct_predictions = (all_preds_tensor == all_targets_tensor).sum().item()
                total_for_accuracy = len(all_targets_tensor)
                if total_for_accuracy > 0:
                    classification_accuracy = 100. * correct_predictions / total_for_accuracy
                    print(f"  Classification accuracy on generated images: {classification_accuracy:.2f}%")
                else:
                    print("  No samples were generated for accuracy computation.")
            else:
                 print("  No predictions were generated for accuracy computation.")

        except Exception as e:
            print(f"  ERROR while computing classification accuracy: {e}")
    else:
        print("  External classifier not available; accuracy will not be computed.")

    generator_model.train()
    return fid_score, is_score_mean, classification_accuracy
# Out:
# Generating MNIST training images into '/content/MNIST_data/MNIST_train_images_png'...
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.52MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 130kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.24MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 11.3MB/s]
#   Saved 5000/60000 images...
#   Saved 10000/60000 images...
#   Saved 15000/60000 images...
#   Saved 20000/60000 images...
#   Saved 25000/60000 images...
#   Saved 30000/60000 images...
#   Saved 35000/60000 images...
#   Saved 40000/60000 images...
#   Saved 45000/60000 images...
#   Saved 50000/60000 images...
#   Saved 55000/60000 images...
#   Saved 60000/60000 images...
# Successfully saved 60000 MNIST PNG images to '/content/MNIST_data/MNIST_train_images_png'.
# MNIST training dataset loaded: 60000 samples.

# %%
#@title 7. Initialize models, losses, and optimizers

"""
<summary>
Initialize models (discriminator, hybrid generator, external MNIST classifier),
loss functions, optimizers, and logging/visualization variables for training the hybrid quantum–classical ACGAN architecture.
</summary>
"""

discriminator = Discriminator(num_classes=NUM_CLASSES, img_channels=IMG_CHANNELS).to(device, memory_format=MEMORY_FORMAT)
discriminator.apply(weights_init)

hybrid_generator = HybridGenerator(
    z_dim=Z_DIM,
    num_classes=NUM_CLASSES,
    img_channels=IMG_CHANNELS,
    ansatz_instance=ansatz,
    list_of_hamiltonians=H_op_list,
    qiskit_estimator=aer_estimator,
    lambda_vqer_coeff=LAMBDA_VQER
).to(device)
hybrid_generator.apply(weights_init)

mnist_classifier_eval = MnistClassifier().to(device)
if os.path.exists(CLASSIFIER_PATH):
    try:
        mnist_classifier_eval.load_state_dict(torch.load(CLASSIFIER_PATH, map_location=device))
        mnist_classifier_eval.eval()
        print(f"External MNIST classifier '{CLASSIFIER_PATH}' loaded successfully.")
    except Exception as e:
        print(f"ERROR while loading external classifier: {e}. Accuracy will not be computed.")
        mnist_classifier_eval = None
else:
    print(f"External MNIST classifier '{CLASSIFIER_PATH}' not found. Accuracy will not be computed.")
    mnist_classifier_eval = None

adversarial_loss_fn = nn.BCELoss().to(device)
auxiliary_loss_fn = nn.CrossEntropyLoss().to(device)

optimizer_G = optim.Adam(hybrid_generator.parameters(), lr=LEARNING_RATE_G, betas=(BETA1, BETA2))
optimizer_D = optim.Adam(discriminator.parameters(), lr=LEARNING_RATE_D, betas=(BETA1, BETA2))

num_fixed_samples_display = NUM_CLASSES * 5
fixed_z = torch.randn(num_fixed_samples_display, Z_DIM, device=device)
fixed_labels_list = []
for i in range(NUM_CLASSES):
    fixed_labels_list.extend([i] * 5)
fixed_labels = torch.LongTensor(fixed_labels_list).to(device)

training_logs = {
    'iterations': [], 'epochs': [],
    'g_loss': [], 'g_adv_loss': [], 'g_aux_loss': [], 'g_vqe_loss': [], 'avg_energy': [],
    'd_loss': [], 'd_real_adv_loss': [], 'd_fake_adv_loss': [], 'd_real_aux_loss': [], 'd_fake_aux_loss': [],
    'eval_epochs': [], 'fid_scores': [], 'is_scores': [], 'classification_accuracy': []
}
best_fid = float('inf')
best_epoch = -1

print("Initialization of models, losses, and optimizers completed.")

def count_parameters(model):
    """
    <summary>
    Count and return the number of trainable parameters in a given model.
    </summary>
    <param name="model">A PyTorch model.</param>
    <returns>Total number of trainable parameters.</returns>
    """
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Trainable parameters in Hybrid Generator: {count_parameters(hybrid_generator):,}")
print(f"Trainable parameters in Discriminator: {count_parameters(discriminator):,}")
if mnist_classifier_eval:
    print(f"Trainable parameters in Eval Classifier: {count_parameters(mnist_classifier_eval):,}")
# Out:
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# External MNIST classifier '/content/mnist_classifier.pth' loaded successfully.
# Initialization of models, losses, and optimizers completed.
# Trainable parameters in Hybrid Generator: 1,813,853
# Trainable parameters in Discriminator: 472,843
# Trainable parameters in Eval Classifier: 3,274,634

# %% [markdown]
# ## 8. Training Loop
#
# ### Training Hyperparameters
#
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | `NUM_EPOCHS` | 10 | Extended training run |
# | `EFFECTIVE_BATCH_SIZE` | 64 | Effective batch size (32 × 2 accumulation) |
# | `LEARNING_RATE` | 2 × 10⁻⁴ | Adam learning rate for G and D |
# | `BETA1`, `BETA2` | 0.5, 0.999 | Adam momentum parameters |
# | `LABEL_SMOOTHING` | 0.9 | Smoothed real labels for discriminator |
# | `λ_VQE` | 0.1 | Weight of VQE regularization term |
# | `N_QUBITS` | 4 | Number of qubits in quantum circuit |
# | `ANSATZ_REPS` | 1 | Repetitions in EfficientSU2 ansatz |
# | `ISING_J` | 1.0 | ZZ coupling coefficient |
# | `ISING_H_GLOBAL` | 0.1 | Base local field strength |
# | `SEED` | 42 | Same seed as exploratory run |
# | `EVAL_INTERVAL` | 1 | Evaluate every epoch |
#
# ### Generator Loss Function
# $$\mathcal{L}_G = \mathcal{L}_{\text{adv}} + \mathcal{L}_{\text{aux}} + \lambda_{\text{VQE}} \cdot E_c$$

# %%
#@title 8. Hybrid ACGAN Training Loop

"""
<summary>
Training loop for the hybrid ACGAN model with quantum VQE regularization.
Includes the main epoch/minibatch iterations, alternating training of discriminator and generator with gradient accumulation, logging of losses and metrics, saving samples and models, and periodic evaluation of FID/IS/classification accuracy.
</summary>
"""

print("Starting Hybrid ACGAN training...")
total_iterations = 0
start_time_total = time.time()

for epoch in range(NUM_EPOCHS):
    epoch_start_time = time.time()
    epoch_g_loss_sum, epoch_g_adv_sum, epoch_g_aux_sum, epoch_g_vqe_sum, epoch_e_c_sum = 0,0,0,0,0
    epoch_d_loss_sum, epoch_d_real_adv_sum, epoch_d_fake_adv_sum, epoch_d_real_aux_sum, epoch_d_fake_aux_sum = 0,0,0,0,0

    hybrid_generator.train()
    discriminator.train()

    optimizer_G.zero_grad()
    optimizer_D.zero_grad()

    for i, (real_imgs_batch, real_class_labels_batch) in enumerate(train_loader):
        current_batch_size = real_imgs_batch.size(0)
        real_imgs_batch = real_imgs_batch.to(device, memory_format=MEMORY_FORMAT if device.type == 'cuda' else torch.contiguous_format)
        real_class_labels_batch = real_class_labels_batch.to(device)

        real_targets_adv = torch.full((current_batch_size, 1), LABEL_SMOOTHING, device=device, dtype=torch.float32)
        fake_targets_adv = torch.full((current_batch_size, 1), 0.0, device=device, dtype=torch.float32)

        real_validity_D, real_class_logits_D = discriminator(real_imgs_batch)
        d_real_adv = adversarial_loss_fn(real_validity_D, real_targets_adv)
        d_real_aux = auxiliary_loss_fn(real_class_logits_D, real_class_labels_batch)

        z_noise_D = torch.randn(current_batch_size, Z_DIM, device=device)
        gen_class_labels_D = torch.randint(0, NUM_CLASSES, (current_batch_size,), device=device, dtype=torch.long)
        fake_imgs_classic_D, _ = hybrid_generator(z_noise_D, gen_class_labels_D)
        fake_validity_D, fake_class_logits_D = discriminator(fake_imgs_classic_D.detach())
        d_fake_adv = adversarial_loss_fn(fake_validity_D, fake_targets_adv)
        d_fake_aux = auxiliary_loss_fn(fake_class_logits_D, gen_class_labels_D)

        d_adv_combined = (d_real_adv + d_fake_adv) / 2
        d_aux_combined = (d_real_aux + d_fake_aux) / 2
        d_loss = (d_adv_combined + d_aux_combined) / ACCUMULATION_STEPS

        d_loss.backward()

        epoch_d_loss_sum += d_loss.item() * ACCUMULATION_STEPS
        epoch_d_real_adv_sum += d_real_adv.item()
        epoch_d_fake_adv_sum += d_fake_adv.item()
        epoch_d_real_aux_sum += d_real_aux.item()
        epoch_d_fake_aux_sum += d_fake_aux.item()

        z_noise_G = torch.randn(current_batch_size, Z_DIM, device=device)
        gen_class_labels_G = torch.randint(0, NUM_CLASSES, (current_batch_size,), device=device, dtype=torch.long)
        fake_imgs_classic_G, E_c_G = hybrid_generator(z_noise_G, gen_class_labels_G)
        fake_validity_G, fake_class_logits_G = discriminator(fake_imgs_classic_G)
        g_real_targets = torch.ones((current_batch_size, 1), device=device, dtype=torch.float32)
        g_adv = adversarial_loss_fn(fake_validity_G, g_real_targets)
        g_aux = auxiliary_loss_fn(fake_class_logits_G, gen_class_labels_G)
        g_vqe_regularizer = hybrid_generator.lambda_vqer * E_c_G.mean()
        g_loss_gan_part = g_adv + g_aux
        g_loss = (g_loss_gan_part + g_vqe_regularizer) / ACCUMULATION_STEPS

        g_loss.backward()

        epoch_g_loss_sum += g_loss.item() * ACCUMULATION_STEPS
        epoch_g_adv_sum += g_adv.item()
        epoch_g_aux_sum += g_aux.item()
        epoch_g_vqe_sum += g_vqe_regularizer.item()
        epoch_e_c_sum += E_c_G.mean().item()

        if (i + 1) % ACCUMULATION_STEPS == 0 or (i + 1) == len(train_loader):
            optimizer_D.step()
            optimizer_D.zero_grad()
            optimizer_G.step()
            optimizer_G.zero_grad()

        total_iterations += 1
        if total_iterations % LOG_INTERVAL == 0:
            print(f"[Epoch {epoch+1}/{NUM_EPOCHS}] [Batch {i+1}/{len(train_loader)}] [Iter {total_iterations}]")
            print(f"  G loss: {g_loss.item()*ACCUMULATION_STEPS:.4f} (Adv: {g_adv.item():.4f}, Aux: {g_aux.item():.4f}, VQE_reg: {g_vqe_regularizer.item():.4f}, E_c: {E_c_G.mean().item():.4f})")
            print(f"  D loss: {d_loss.item()*ACCUMULATION_STEPS:.4f} (RealAdv: {d_real_adv.item():.4f}, FakeAdv: {d_fake_adv.item():.4f}, RealAux: {d_real_aux.item():.4f}, FakeAux: {d_fake_aux.item():.4f})")
            training_logs['iterations'].append(total_iterations)
            training_logs['g_loss'].append(g_loss.item()*ACCUMULATION_STEPS)
            training_logs['g_adv_loss'].append(g_adv.item())
            training_logs['g_aux_loss'].append(g_aux.item())
            training_logs['g_vqe_loss'].append(g_vqe_regularizer.item())
            training_logs['avg_energy'].append(E_c_G.mean().item())
            training_logs['d_loss'].append(d_loss.item()*ACCUMULATION_STEPS)
            training_logs['d_real_adv_loss'].append(d_real_adv.item())
            training_logs['d_fake_adv_loss'].append(d_fake_adv.item())
            training_logs['d_real_aux_loss'].append(d_real_aux.item())
            training_logs['d_fake_aux_loss'].append(d_fake_aux.item())

    epoch_duration = time.time() - epoch_start_time
    num_batches_in_epoch = len(train_loader)
    avg_g_loss = epoch_g_loss_sum / num_batches_in_epoch
    avg_g_adv = epoch_g_adv_sum / num_batches_in_epoch
    avg_g_aux = epoch_g_aux_sum / num_batches_in_epoch
    avg_g_vqe = epoch_g_vqe_sum / num_batches_in_epoch
    avg_E_c = epoch_e_c_sum / num_batches_in_epoch

    avg_d_loss = epoch_d_loss_sum / num_batches_in_epoch
    avg_d_real_adv = epoch_d_real_adv_sum / num_batches_in_epoch
    avg_d_fake_adv = epoch_d_fake_adv_sum / num_batches_in_epoch
    avg_d_real_aux = epoch_d_real_aux_sum / num_batches_in_epoch
    avg_d_fake_aux = epoch_d_fake_aux_sum / num_batches_in_epoch

    print(f"\n--- End of Epoch {epoch+1}/{NUM_EPOCHS} (Duration: {epoch_duration:.2f}s) ---")
    print(f"  Avg G Loss: {avg_g_loss:.4f} (Adv: {avg_g_adv:.4f}, Aux: {avg_g_aux:.4f}, VQE_reg: {avg_g_vqe:.4f}, Avg E_c: {avg_E_c:.4f})")
    print(f"  Avg D Loss: {avg_d_loss:.4f} (R_Adv: {avg_d_real_adv:.4f}, F_Adv: {avg_d_fake_adv:.4f}, R_Aux: {avg_d_real_aux:.4f}, F_Aux: {avg_d_fake_aux:.4f})")

    training_logs['epochs'].append(epoch + 1)

    if (epoch + 1) % SAVE_SAMPLES_INTERVAL == 0 or (epoch + 1) == NUM_EPOCHS:
        save_generated_samples(epoch + 1, hybrid_generator, fixed_z, fixed_labels, OUTPUT_DIR_IMAGES)
        print(f"  Samples for epoch {epoch+1} saved.")

    if (epoch + 1) % EVAL_INTERVAL == 0 or (epoch + 1) == NUM_EPOCHS:
        print(f"  Running evaluation for epoch {epoch+1}...")
        fid, is_mean, acc = evaluate_hybrid_model(
            epoch + 1, hybrid_generator, mnist_classifier_eval,
            NUM_SAMPLES_FOR_METRICS, NUM_SAMPLES_FOR_ACCURACY,
            MNIST_TRAIN_IMAGES_PATH, device
        )
        training_logs['eval_epochs'].append(epoch + 1)
        training_logs['fid_scores'].append(fid)
        training_logs['is_scores'].append(is_mean)
        training_logs['classification_accuracy'].append(acc)

        if fid is not None and not np.isnan(fid) and fid < best_fid:
            best_fid = fid
            best_epoch = epoch + 1
            torch.save(hybrid_generator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_best.pth'))
            torch.save(discriminator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'discriminator_best.pth'))
            print(f"  *** New best FID: {best_fid:.4f} at epoch {best_epoch}. Models saved. ***")

    with open(LOG_FILE, 'wb') as f:
        pickle.dump(training_logs, f)
    print("-" * 60)

total_training_time = time.time() - start_time_total
print(f"\nTraining finished in {total_training_time // 3600:.0f}h {(total_training_time % 3600) // 60:.0f}m {total_training_time % 60:.0f}s")
print(f"Best FID achieved: {best_fid:.4f} at epoch {best_epoch}.")

torch.save(hybrid_generator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_final.pth'))
torch.save(discriminator.state_dict(), os.path.join(OUTPUT_DIR_MODELS, 'discriminator_final.pth'))
print(f"Final models saved to '{OUTPUT_DIR_MODELS}'.")
# Out:
# Starting Hybrid ACGAN training...
# [Epoch 1/10] [Batch 50/1875] [Iter 50]
#   G loss: 0.1533 (Adv: 0.4079, Aux: 0.1037, VQE_reg: -0.3583, E_c: -3.5830)
#   D loss: 1.1980 (RealAdv: 0.3377, FakeAdv: 1.3300, RealAux: 0.5952, FakeAux: 0.1330)
# [Epoch 1/10] [Batch 100/1875] [Iter 100]
#   G loss: 0.0732 (Adv: 0.3896, Aux: 0.0406, VQE_reg: -0.3569, E_c: -3.5694)
#   D loss: 1.0776 (RealAdv: 0.3604, FakeAdv: 1.2427, RealAux: 0.5176, FakeAux: 0.0345)
# [Epoch 1/10] [Batch 150/1875] [Iter 150]
#   G loss: -0.0543 (Adv: 0.2892, Aux: 0.0159, VQE_reg: -0.3595, E_c: -3.5947)
#   D loss: 1.1808 (RealAdv: 0.3461, FakeAdv: 1.5180, RealAux: 0.4626, FakeAux: 0.0348)
# [Epoch 1/10] [Batch 200/1875] [Iter 200]
#   G loss: 0.1248 (Adv: 0.4711, Aux: 0.0150, VQE_reg: -0.3613, E_c: -3.6130)
#   D loss: 1.1167 (RealAdv: 0.4442, FakeAdv: 1.0752, RealAux: 0.6888, FakeAux: 0.0251)
# [Epoch 1/10] [Batch 250/1875] [Iter 250]
#   G loss: -0.0005 (Adv: 0.3292, Aux: 0.0239, VQE_reg: -0.3536, E_c: -3.5356)
#   D loss: 0.9847 (RealAdv: 0.3801, FakeAdv: 1.2000, RealAux: 0.3668, FakeAux: 0.0225)
# [Epoch 1/10] [Batch 300/1875] [Iter 300]
#   G loss: -0.1749 (Adv: 0.1577, Aux: 0.0217, VQE_reg: -0.3543, E_c: -3.5430)
#   D loss: 1.4682 (RealAdv: 0.3375, FakeAdv: 2.0484, RealAux: 0.5357, FakeAux: 0.0147)
# [Epoch 1/10] [Batch 350/1875] [Iter 350]
#   G loss: 0.1052 (Adv: 0.4484, Aux: 0.0143, VQE_reg: -0.3575, E_c: -3.5746)
#   D loss: 0.8636 (RealAdv: 0.4224, FakeAdv: 1.0289, RealAux: 0.2604, FakeAux: 0.0155)
# [Epoch 1/10] [Batch 400/1875] [Iter 400]
#   G loss: 0.0608 (Adv: 0.4090, Aux: 0.0112, VQE_reg: -0.3594, E_c: -3.5936)
#   D loss: 0.9050 (RealAdv: 0.3860, FakeAdv: 1.2132, RealAux: 0.1942, FakeAux: 0.0167)
# [Epoch 1/10] [Batch 450/1875] [Iter 450]
#   G loss: 0.0911 (Adv: 0.4243, Aux: 0.0228, VQE_reg: -0.3561, E_c: -3.5606)
#   D loss: 0.8869 (RealAdv: 0.3801, FakeAdv: 1.1638, RealAux: 0.2166, FakeAux: 0.0133)
# [Epoch 1/10] [Batch 500/1875] [Iter 500]
#   G loss: 0.1319 (Adv: 0.4743, Aux: 0.0140, VQE_reg: -0.3563, E_c: -3.5633)
#   D loss: 0.8435 (RealAdv: 0.4095, FakeAdv: 1.0659, RealAux: 0.1914, FakeAux: 0.0201)
# [Epoch 1/10] [Batch 550/1875] [Iter 550]
#   G loss: -0.0230 (Adv: 0.3315, Aux: 0.0055, VQE_reg: -0.3600, E_c: -3.6000)
#   D loss: 0.9981 (RealAdv: 0.3857, FakeAdv: 1.3948, RealAux: 0.2028, FakeAux: 0.0129)
# [Epoch 1/10] [Batch 600/1875] [Iter 600]
#   G loss: 0.0237 (Adv: 0.3555, Aux: 0.0263, VQE_reg: -0.3582, E_c: -3.5817)
#   D loss: 0.8846 (RealAdv: 0.3807, FakeAdv: 1.1535, RealAux: 0.2120, FakeAux: 0.0231)
# [Epoch 1/10] [Batch 650/1875] [Iter 650]
#   G loss: 0.0404 (Adv: 0.3922, Aux: 0.0088, VQE_reg: -0.3606, E_c: -3.6062)
#   D loss: 0.9508 (RealAdv: 0.3883, FakeAdv: 1.1425, RealAux: 0.3602, FakeAux: 0.0106)
# [Epoch 1/10] [Batch 700/1875] [Iter 700]
#   G loss: -0.0915 (Adv: 0.2270, Aux: 0.0373, VQE_reg: -0.3558, E_c: -3.5577)
#   D loss: 1.0645 (RealAdv: 0.3363, FakeAdv: 1.6773, RealAux: 0.0936, FakeAux: 0.0218)
# [Epoch 1/10] [Batch 750/1875] [Iter 750]
#   G loss: -0.0466 (Adv: 0.3047, Aux: 0.0070, VQE_reg: -0.3583, E_c: -3.5825)
#   D loss: 0.9150 (RealAdv: 0.3711, FakeAdv: 1.2929, RealAux: 0.1540, FakeAux: 0.0120)
# [Epoch 1/10] [Batch 800/1875] [Iter 800]
#   G loss: 0.0124 (Adv: 0.3554, Aux: 0.0132, VQE_reg: -0.3562, E_c: -3.5619)
#   D loss: 0.9439 (RealAdv: 0.3691, FakeAdv: 1.2704, RealAux: 0.2368, FakeAux: 0.0116)
# [Epoch 1/10] [Batch 850/1875] [Iter 850]
#   G loss: -0.0698 (Adv: 0.2805, Aux: 0.0099, VQE_reg: -0.3602, E_c: -3.6015)
#   D loss: 0.9872 (RealAdv: 0.3521, FakeAdv: 1.3975, RealAux: 0.2170, FakeAux: 0.0078)
# [Epoch 1/10] [Batch 900/1875] [Iter 900]
#   G loss: 0.0057 (Adv: 0.3570, Aux: 0.0076, VQE_reg: -0.3588, E_c: -3.5885)
#   D loss: 0.8376 (RealAdv: 0.3881, FakeAdv: 1.1999, RealAux: 0.0811, FakeAux: 0.0062)
# [Epoch 1/10] [Batch 950/1875] [Iter 950]
#   G loss: 0.1459 (Adv: 0.4942, Aux: 0.0086, VQE_reg: -0.3569, E_c: -3.5685)
#   D loss: 0.7612 (RealAdv: 0.3910, FakeAdv: 1.0265, RealAux: 0.0952, FakeAux: 0.0098)
# [Epoch 1/10] [Batch 1000/1875] [Iter 1000]
#   G loss: -0.0009 (Adv: 0.3497, Aux: 0.0041, VQE_reg: -0.3547, E_c: -3.5470)
#   D loss: 0.8568 (RealAdv: 0.3681, FakeAdv: 1.2019, RealAux: 0.1322, FakeAux: 0.0113)
# [Epoch 1/10] [Batch 1050/1875] [Iter 1050]
#   G loss: 0.0107 (Adv: 0.3648, Aux: 0.0042, VQE_reg: -0.3583, E_c: -3.5831)
#   D loss: 0.8641 (RealAdv: 0.3718, FakeAdv: 1.2179, RealAux: 0.1343, FakeAux: 0.0041)
# [Epoch 1/10] [Batch 1100/1875] [Iter 1100]
#   G loss: 0.0299 (Adv: 0.3783, Aux: 0.0068, VQE_reg: -0.3551, E_c: -3.5514)
#   D loss: 0.8920 (RealAdv: 0.3748, FakeAdv: 1.3061, RealAux: 0.1002, FakeAux: 0.0028)
# [Epoch 1/10] [Batch 1150/1875] [Iter 1150]
#   G loss: -0.0188 (Adv: 0.3360, Aux: 0.0030, VQE_reg: -0.3579, E_c: -3.5788)
#   D loss: 1.0803 (RealAdv: 0.3664, FakeAdv: 1.2631, RealAux: 0.5290, FakeAux: 0.0020)
# [Epoch 1/10] [Batch 1200/1875] [Iter 1200]
#   G loss: 0.0522 (Adv: 0.3991, Aux: 0.0073, VQE_reg: -0.3542, E_c: -3.5424)
#   D loss: 0.7984 (RealAdv: 0.3921, FakeAdv: 1.1438, RealAux: 0.0553, FakeAux: 0.0058)
# [Epoch 1/10] [Batch 1250/1875] [Iter 1250]
#   G loss: 0.0441 (Adv: 0.3953, Aux: 0.0075, VQE_reg: -0.3588, E_c: -3.5881)
#   D loss: 0.8173 (RealAdv: 0.3873, FakeAdv: 1.1226, RealAux: 0.1185, FakeAux: 0.0063)
# [Epoch 1/10] [Batch 1300/1875] [Iter 1300]
#   G loss: -0.0505 (Adv: 0.2934, Aux: 0.0113, VQE_reg: -0.3552, E_c: -3.5516)
#   D loss: 0.8680 (RealAdv: 0.3624, FakeAdv: 1.2882, RealAux: 0.0738, FakeAux: 0.0117)
# [Epoch 1/10] [Batch 1350/1875] [Iter 1350]
#   G loss: 0.0026 (Adv: 0.3568, Aux: 0.0088, VQE_reg: -0.3631, E_c: -3.6305)
#   D loss: 0.8358 (RealAdv: 0.3968, FakeAdv: 1.0904, RealAux: 0.1796, FakeAux: 0.0047)
# [Epoch 1/10] [Batch 1400/1875] [Iter 1400]
#   G loss: -0.0010 (Adv: 0.3516, Aux: 0.0035, VQE_reg: -0.3562, E_c: -3.5622)
#   D loss: 1.0211 (RealAdv: 0.3634, FakeAdv: 1.2676, RealAux: 0.3986, FakeAux: 0.0126)
# [Epoch 1/10] [Batch 1450/1875] [Iter 1450]
#   G loss: -0.0585 (Adv: 0.2991, Aux: 0.0050, VQE_reg: -0.3626, E_c: -3.6261)
#   D loss: 0.9531 (RealAdv: 0.3522, FakeAdv: 1.5044, RealAux: 0.0443, FakeAux: 0.0054)
# [Epoch 1/10] [Batch 1500/1875] [Iter 1500]
#   G loss: 0.0634 (Adv: 0.4014, Aux: 0.0202, VQE_reg: -0.3581, E_c: -3.5814)
#   D loss: 0.8717 (RealAdv: 0.3822, FakeAdv: 1.3302, RealAux: 0.0274, FakeAux: 0.0036)
# [Epoch 1/10] [Batch 1550/1875] [Iter 1550]
#   G loss: 0.0963 (Adv: 0.4262, Aux: 0.0293, VQE_reg: -0.3592, E_c: -3.5922)
#   D loss: 0.9038 (RealAdv: 0.3996, FakeAdv: 1.1236, RealAux: 0.2774, FakeAux: 0.0069)
# [Epoch 1/10] [Batch 1600/1875] [Iter 1600]
#   G loss: -0.0717 (Adv: 0.2831, Aux: 0.0050, VQE_reg: -0.3599, E_c: -3.5993)
#   D loss: 0.9131 (RealAdv: 0.3500, FakeAdv: 1.3938, RealAux: 0.0792, FakeAux: 0.0032)
# [Epoch 1/10] [Batch 1650/1875] [Iter 1650]
#   G loss: 0.0269 (Adv: 0.3636, Aux: 0.0210, VQE_reg: -0.3577, E_c: -3.5765)
#   D loss: 0.9569 (RealAdv: 0.3865, FakeAdv: 1.2812, RealAux: 0.2393, FakeAux: 0.0068)
# [Epoch 1/10] [Batch 1700/1875] [Iter 1700]
#   G loss: 0.0121 (Adv: 0.3538, Aux: 0.0199, VQE_reg: -0.3616, E_c: -3.6164)
#   D loss: 0.8218 (RealAdv: 0.3712, FakeAdv: 1.2286, RealAux: 0.0411, FakeAux: 0.0027)
# [Epoch 1/10] [Batch 1750/1875] [Iter 1750]
#   G loss: 0.0810 (Adv: 0.4294, Aux: 0.0062, VQE_reg: -0.3546, E_c: -3.5460)
#   D loss: 0.7430 (RealAdv: 0.4024, FakeAdv: 1.0747, RealAux: 0.0052, FakeAux: 0.0038)
# [Epoch 1/10] [Batch 1800/1875] [Iter 1800]
#   G loss: -0.0081 (Adv: 0.3486, Aux: 0.0013, VQE_reg: -0.3580, E_c: -3.5803)
#   D loss: 0.8667 (RealAdv: 0.3778, FakeAdv: 1.1455, RealAux: 0.2088, FakeAux: 0.0013)
# [Epoch 1/10] [Batch 1850/1875] [Iter 1850]
#   G loss: 0.0112 (Adv: 0.3665, Aux: 0.0034, VQE_reg: -0.3587, E_c: -3.5865)
#   D loss: 0.9843 (RealAdv: 0.3665, FakeAdv: 1.3456, RealAux: 0.2537, FakeAux: 0.0028)
#
# --- End of Epoch 1/10 (Duration: 4975.53s) ---
#   Avg G Loss: 0.0388 (Adv: 0.3628, Aux: 0.0341, VQE_reg: -0.3580, Avg E_c: -3.5801)
#   Avg D Loss: 0.9658 (R_Adv: 0.3799, F_Adv: 1.2700, R_Aux: 0.2479, F_Aux: 0.0338)
#   Samples for epoch 1 saved.
#   Running evaluation for epoch 1...
#   Generating 1000 samples for FID/IS into '/tmp/tmpd1pef4pw'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:02<00:00, 31.9MB/s]
# /usr/local/lib/python3.12/dist-packages/torch_fidelity/datasets.py:16: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(img.tobytes())).view(height, width, 3)
#   FID: 122.1895, IS (mean): 2.0947
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 86.00%
#   *** New best FID: 122.1895 at epoch 1. Models saved. ***
# ------------------------------------------------------------
# [Epoch 2/10] [Batch 25/1875] [Iter 1900]
#   G loss: -0.0103 (Adv: 0.3479, Aux: 0.0022, VQE_reg: -0.3604, E_c: -3.6043)
#   D loss: 0.9026 (RealAdv: 0.3742, FakeAdv: 1.4099, RealAux: 0.0197, FakeAux: 0.0014)
# [Epoch 2/10] [Batch 75/1875] [Iter 1950]
#   G loss: 0.0893 (Adv: 0.4433, Aux: 0.0008, VQE_reg: -0.3549, E_c: -3.5486)
#   D loss: 0.7435 (RealAdv: 0.3852, FakeAdv: 1.0546, RealAux: 0.0461, FakeAux: 0.0010)
# [Epoch 2/10] [Batch 125/1875] [Iter 2000]
#   G loss: -0.0241 (Adv: 0.3318, Aux: 0.0016, VQE_reg: -0.3575, E_c: -3.5746)
#   D loss: 0.8713 (RealAdv: 0.3698, FakeAdv: 1.2879, RealAux: 0.0794, FakeAux: 0.0056)
# [Epoch 2/10] [Batch 175/1875] [Iter 2050]
#   G loss: -0.0873 (Adv: 0.2686, Aux: 0.0027, VQE_reg: -0.3586, E_c: -3.5864)
#   D loss: 0.9984 (RealAdv: 0.3731, FakeAdv: 1.4574, RealAux: 0.1575, FakeAux: 0.0087)
# [Epoch 2/10] [Batch 225/1875] [Iter 2100]
#   G loss: -0.0108 (Adv: 0.3421, Aux: 0.0036, VQE_reg: -0.3564, E_c: -3.5644)
#   D loss: 0.8539 (RealAdv: 0.3635, FakeAdv: 1.2350, RealAux: 0.1055, FakeAux: 0.0038)
# [Epoch 2/10] [Batch 275/1875] [Iter 2150]
#   G loss: 0.0073 (Adv: 0.3636, Aux: 0.0014, VQE_reg: -0.3576, E_c: -3.5764)
#   D loss: 0.8699 (RealAdv: 0.3708, FakeAdv: 1.3232, RealAux: 0.0420, FakeAux: 0.0039)
# [Epoch 2/10] [Batch 325/1875] [Iter 2200]
#   G loss: 0.0056 (Adv: 0.3266, Aux: 0.0363, VQE_reg: -0.3573, E_c: -3.5731)
#   D loss: 0.8886 (RealAdv: 0.3870, FakeAdv: 1.2852, RealAux: 0.1013, FakeAux: 0.0037)
# [Epoch 2/10] [Batch 375/1875] [Iter 2250]
#   G loss: 0.0530 (Adv: 0.3555, Aux: 0.0546, VQE_reg: -0.3572, E_c: -3.5716)
#   D loss: 0.8665 (RealAdv: 0.3780, FakeAdv: 1.2974, RealAux: 0.0558, FakeAux: 0.0018)
# [Epoch 2/10] [Batch 425/1875] [Iter 2300]
#   G loss: -0.0059 (Adv: 0.3516, Aux: 0.0024, VQE_reg: -0.3598, E_c: -3.5981)
#   D loss: 0.8730 (RealAdv: 0.3762, FakeAdv: 1.2259, RealAux: 0.1417, FakeAux: 0.0023)
# [Epoch 2/10] [Batch 475/1875] [Iter 2350]
#   G loss: -0.0009 (Adv: 0.3531, Aux: 0.0018, VQE_reg: -0.3558, E_c: -3.5582)
#   D loss: 0.9391 (RealAdv: 0.3709, FakeAdv: 1.2459, RealAux: 0.2507, FakeAux: 0.0107)
# [Epoch 2/10] [Batch 525/1875] [Iter 2400]
#   G loss: -0.0475 (Adv: 0.3039, Aux: 0.0035, VQE_reg: -0.3549, E_c: -3.5490)
#   D loss: 0.9374 (RealAdv: 0.3535, FakeAdv: 1.4567, RealAux: 0.0568, FakeAux: 0.0079)
# [Epoch 2/10] [Batch 575/1875] [Iter 2450]
#   G loss: -0.0338 (Adv: 0.3219, Aux: 0.0026, VQE_reg: -0.3583, E_c: -3.5826)
#   D loss: 0.9656 (RealAdv: 0.3621, FakeAdv: 1.3432, RealAux: 0.2245, FakeAux: 0.0014)
# [Epoch 2/10] [Batch 625/1875] [Iter 2500]
#   G loss: 0.0107 (Adv: 0.3638, Aux: 0.0037, VQE_reg: -0.3568, E_c: -3.5680)
#   D loss: 0.8120 (RealAdv: 0.3792, FakeAdv: 1.2224, RealAux: 0.0124, FakeAux: 0.0099)
# [Epoch 2/10] [Batch 675/1875] [Iter 2550]
#   G loss: 0.0496 (Adv: 0.4062, Aux: 0.0030, VQE_reg: -0.3595, E_c: -3.5955)
#   D loss: 0.7828 (RealAdv: 0.4129, FakeAdv: 1.1377, RealAux: 0.0095, FakeAux: 0.0056)
# [Epoch 2/10] [Batch 725/1875] [Iter 2600]
#   G loss: -0.0057 (Adv: 0.3519, Aux: 0.0013, VQE_reg: -0.3589, E_c: -3.5888)
#   D loss: 0.8850 (RealAdv: 0.3791, FakeAdv: 1.3713, RealAux: 0.0142, FakeAux: 0.0055)
# [Epoch 2/10] [Batch 775/1875] [Iter 2650]
#   G loss: -0.0061 (Adv: 0.3479, Aux: 0.0024, VQE_reg: -0.3564, E_c: -3.5636)
#   D loss: 0.8406 (RealAdv: 0.4195, FakeAdv: 1.2427, RealAux: 0.0145, FakeAux: 0.0045)
# [Epoch 2/10] [Batch 825/1875] [Iter 2700]
#   G loss: 0.0667 (Adv: 0.4189, Aux: 0.0048, VQE_reg: -0.3570, E_c: -3.5699)
#   D loss: 0.9035 (RealAdv: 0.3937, FakeAdv: 1.1261, RealAux: 0.2847, FakeAux: 0.0024)
# [Epoch 2/10] [Batch 875/1875] [Iter 2750]
#   G loss: -0.0249 (Adv: 0.3250, Aux: 0.0080, VQE_reg: -0.3579, E_c: -3.5786)
#   D loss: 0.8927 (RealAdv: 0.3956, FakeAdv: 1.3668, RealAux: 0.0211, FakeAux: 0.0019)
# [Epoch 2/10] [Batch 925/1875] [Iter 2800]
#   G loss: -0.0485 (Adv: 0.3107, Aux: 0.0018, VQE_reg: -0.3610, E_c: -3.6099)
#   D loss: 0.9992 (RealAdv: 0.3594, FakeAdv: 1.5544, RealAux: 0.0834, FakeAux: 0.0011)
# [Epoch 2/10] [Batch 975/1875] [Iter 2850]
#   G loss: -0.0546 (Adv: 0.3022, Aux: 0.0005, VQE_reg: -0.3573, E_c: -3.5726)
#   D loss: 0.8750 (RealAdv: 0.3565, FakeAdv: 1.3826, RealAux: 0.0092, FakeAux: 0.0016)
# [Epoch 2/10] [Batch 1025/1875] [Iter 2900]
#   G loss: -0.0032 (Adv: 0.3521, Aux: 0.0045, VQE_reg: -0.3598, E_c: -3.5981)
#   D loss: 0.9320 (RealAdv: 0.3731, FakeAdv: 1.2503, RealAux: 0.2395, FakeAux: 0.0011)
# [Epoch 2/10] [Batch 1075/1875] [Iter 2950]
#   G loss: -0.0026 (Adv: 0.3548, Aux: 0.0012, VQE_reg: -0.3586, E_c: -3.5858)
#   D loss: 0.8783 (RealAdv: 0.3942, FakeAdv: 1.2566, RealAux: 0.1049, FakeAux: 0.0010)
# [Epoch 2/10] [Batch 1125/1875] [Iter 3000]
#   G loss: 0.0335 (Adv: 0.2931, Aux: 0.0963, VQE_reg: -0.3560, E_c: -3.5596)
#   D loss: 0.9270 (RealAdv: 0.3988, FakeAdv: 1.3286, RealAux: 0.1174, FakeAux: 0.0091)
# [Epoch 2/10] [Batch 1175/1875] [Iter 3050]
#   G loss: -0.0661 (Adv: 0.2917, Aux: 0.0015, VQE_reg: -0.3592, E_c: -3.5925)
#   D loss: 0.8394 (RealAdv: 0.3832, FakeAdv: 1.2610, RealAux: 0.0325, FakeAux: 0.0022)
# [Epoch 2/10] [Batch 1225/1875] [Iter 3100]
#   G loss: -0.0430 (Adv: 0.3030, Aux: 0.0099, VQE_reg: -0.3559, E_c: -3.5593)
#   D loss: 0.9140 (RealAdv: 0.3661, FakeAdv: 1.3900, RealAux: 0.0676, FakeAux: 0.0042)
# [Epoch 2/10] [Batch 1275/1875] [Iter 3150]
#   G loss: 0.0471 (Adv: 0.4015, Aux: 0.0030, VQE_reg: -0.3574, E_c: -3.5741)
#   D loss: 0.8458 (RealAdv: 0.3989, FakeAdv: 1.1974, RealAux: 0.0938, FakeAux: 0.0015)
# [Epoch 2/10] [Batch 1325/1875] [Iter 3200]
#   G loss: 0.1091 (Adv: 0.4408, Aux: 0.0283, VQE_reg: -0.3599, E_c: -3.5993)
#   D loss: 0.8394 (RealAdv: 0.3790, FakeAdv: 1.2946, RealAux: 0.0029, FakeAux: 0.0024)
# [Epoch 2/10] [Batch 1375/1875] [Iter 3250]
#   G loss: 0.0225 (Adv: 0.3772, Aux: 0.0011, VQE_reg: -0.3558, E_c: -3.5577)
#   D loss: 0.7881 (RealAdv: 0.4427, FakeAdv: 1.1027, RealAux: 0.0198, FakeAux: 0.0111)
# [Epoch 2/10] [Batch 1425/1875] [Iter 3300]
#   G loss: 0.0247 (Adv: 0.3786, Aux: 0.0016, VQE_reg: -0.3555, E_c: -3.5552)
#   D loss: 0.8545 (RealAdv: 0.3732, FakeAdv: 1.1937, RealAux: 0.1408, FakeAux: 0.0013)
# [Epoch 2/10] [Batch 1475/1875] [Iter 3350]
#   G loss: -0.0131 (Adv: 0.3435, Aux: 0.0021, VQE_reg: -0.3587, E_c: -3.5867)
#   D loss: 0.9189 (RealAdv: 0.3835, FakeAdv: 1.3421, RealAux: 0.1068, FakeAux: 0.0054)
# [Epoch 2/10] [Batch 1525/1875] [Iter 3400]
#   G loss: 0.0248 (Adv: 0.3804, Aux: 0.0026, VQE_reg: -0.3583, E_c: -3.5828)
#   D loss: 0.8418 (RealAdv: 0.3841, FakeAdv: 1.2910, RealAux: 0.0073, FakeAux: 0.0012)
# [Epoch 2/10] [Batch 1575/1875] [Iter 3450]
#   G loss: -0.0283 (Adv: 0.3209, Aux: 0.0054, VQE_reg: -0.3547, E_c: -3.5466)
#   D loss: 0.9920 (RealAdv: 0.3734, FakeAdv: 1.3603, RealAux: 0.2412, FakeAux: 0.0091)
# [Epoch 2/10] [Batch 1625/1875] [Iter 3500]
#   G loss: 0.0150 (Adv: 0.3681, Aux: 0.0041, VQE_reg: -0.3571, E_c: -3.5714)
#   D loss: 0.9334 (RealAdv: 0.4215, FakeAdv: 1.2814, RealAux: 0.1523, FakeAux: 0.0117)
# [Epoch 2/10] [Batch 1675/1875] [Iter 3550]
#   G loss: 0.0249 (Adv: 0.3826, Aux: 0.0013, VQE_reg: -0.3590, E_c: -3.5904)
#   D loss: 0.8420 (RealAdv: 0.3988, FakeAdv: 1.2459, RealAux: 0.0344, FakeAux: 0.0048)
# [Epoch 2/10] [Batch 1725/1875] [Iter 3600]
#   G loss: -0.0327 (Adv: 0.3100, Aux: 0.0157, VQE_reg: -0.3584, E_c: -3.5837)
#   D loss: 0.8713 (RealAdv: 0.3744, FakeAdv: 1.3592, RealAux: 0.0072, FakeAux: 0.0019)
# [Epoch 2/10] [Batch 1775/1875] [Iter 3650]
#   G loss: -0.0070 (Adv: 0.3469, Aux: 0.0038, VQE_reg: -0.3578, E_c: -3.5776)
#   D loss: 1.0463 (RealAdv: 0.3946, FakeAdv: 1.2879, RealAux: 0.3967, FakeAux: 0.0134)
# [Epoch 2/10] [Batch 1825/1875] [Iter 3700]
#   G loss: -0.0339 (Adv: 0.3219, Aux: 0.0012, VQE_reg: -0.3570, E_c: -3.5704)
#   D loss: 0.9548 (RealAdv: 0.3840, FakeAdv: 1.4330, RealAux: 0.0869, FakeAux: 0.0057)
# [Epoch 2/10] [Batch 1875/1875] [Iter 3750]
#   G loss: 0.0119 (Adv: 0.3676, Aux: 0.0038, VQE_reg: -0.3595, E_c: -3.5950)
#   D loss: 0.9897 (RealAdv: 0.3883, FakeAdv: 1.4176, RealAux: 0.1699, FakeAux: 0.0037)
#
# --- End of Epoch 2/10 (Duration: 4983.01s) ---
#   Avg G Loss: 0.0006 (Adv: 0.3518, Aux: 0.0067, VQE_reg: -0.3580, Avg E_c: -3.5797)
#   Avg D Loss: 0.8758 (R_Adv: 0.3860, F_Adv: 1.2642, R_Aux: 0.0948, F_Aux: 0.0067)
#   Samples for epoch 2 saved.
#   Running evaluation for epoch 2...
#   Generating 1000 samples for FID/IS into '/tmp/tmphmjxqjop'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 61.7907, IS (mean): 2.2911
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 83.40%
#   *** New best FID: 61.7907 at epoch 2. Models saved. ***
# ------------------------------------------------------------
# [Epoch 3/10] [Batch 50/1875] [Iter 3800]
#   G loss: 0.0425 (Adv: 0.3973, Aux: 0.0032, VQE_reg: -0.3580, E_c: -3.5802)
#   D loss: 0.8173 (RealAdv: 0.3953, FakeAdv: 1.1850, RealAux: 0.0535, FakeAux: 0.0007)
# [Epoch 3/10] [Batch 100/1875] [Iter 3850]
#   G loss: -0.0011 (Adv: 0.3517, Aux: 0.0030, VQE_reg: -0.3558, E_c: -3.5584)
#   D loss: 0.7946 (RealAdv: 0.3996, FakeAdv: 1.1780, RealAux: 0.0109, FakeAux: 0.0007)
# [Epoch 3/10] [Batch 150/1875] [Iter 3900]
#   G loss: -0.0306 (Adv: 0.3200, Aux: 0.0059, VQE_reg: -0.3565, E_c: -3.5654)
#   D loss: 0.8245 (RealAdv: 0.3686, FakeAdv: 1.2615, RealAux: 0.0170, FakeAux: 0.0018)
# [Epoch 3/10] [Batch 200/1875] [Iter 3950]
#   G loss: -0.0081 (Adv: 0.3501, Aux: 0.0024, VQE_reg: -0.3605, E_c: -3.6055)
#   D loss: 0.7981 (RealAdv: 0.3914, FakeAdv: 1.1577, RealAux: 0.0463, FakeAux: 0.0008)
# [Epoch 3/10] [Batch 250/1875] [Iter 4000]
#   G loss: -0.0057 (Adv: 0.3480, Aux: 0.0048, VQE_reg: -0.3586, E_c: -3.5859)
#   D loss: 0.8892 (RealAdv: 0.3785, FakeAdv: 1.3820, RealAux: 0.0161, FakeAux: 0.0019)
# [Epoch 3/10] [Batch 300/1875] [Iter 4050]
#   G loss: 0.0074 (Adv: 0.3643, Aux: 0.0003, VQE_reg: -0.3572, E_c: -3.5718)
#   D loss: 0.8505 (RealAdv: 0.4042, FakeAdv: 1.2288, RealAux: 0.0621, FakeAux: 0.0060)
# [Epoch 3/10] [Batch 350/1875] [Iter 4100]
#   G loss: -0.0190 (Adv: 0.3409, Aux: 0.0011, VQE_reg: -0.3610, E_c: -3.6097)
#   D loss: 0.8579 (RealAdv: 0.4178, FakeAdv: 1.2890, RealAux: 0.0055, FakeAux: 0.0036)
# [Epoch 3/10] [Batch 400/1875] [Iter 4150]
#   G loss: 0.0365 (Adv: 0.3916, Aux: 0.0016, VQE_reg: -0.3567, E_c: -3.5668)
#   D loss: 0.7873 (RealAdv: 0.4128, FakeAdv: 1.1226, RealAux: 0.0364, FakeAux: 0.0028)
# [Epoch 3/10] [Batch 450/1875] [Iter 4200]
#   G loss: 0.0435 (Adv: 0.3923, Aux: 0.0116, VQE_reg: -0.3604, E_c: -3.6043)
#   D loss: 0.8578 (RealAdv: 0.3887, FakeAdv: 1.2296, RealAux: 0.0931, FakeAux: 0.0041)
# [Epoch 3/10] [Batch 500/1875] [Iter 4250]
#   G loss: -0.0815 (Adv: 0.2792, Aux: 0.0005, VQE_reg: -0.3612, E_c: -3.6120)
#   D loss: 0.9101 (RealAdv: 0.3722, FakeAdv: 1.4118, RealAux: 0.0345, FakeAux: 0.0018)
# [Epoch 3/10] [Batch 550/1875] [Iter 4300]
#   G loss: -0.0102 (Adv: 0.3468, Aux: 0.0003, VQE_reg: -0.3573, E_c: -3.5734)
#   D loss: 0.8169 (RealAdv: 0.3695, FakeAdv: 1.1872, RealAux: 0.0752, FakeAux: 0.0018)
# [Epoch 3/10] [Batch 600/1875] [Iter 4350]
#   G loss: 0.0621 (Adv: 0.3886, Aux: 0.0305, VQE_reg: -0.3569, E_c: -3.5690)
#   D loss: 0.9069 (RealAdv: 0.3981, FakeAdv: 1.3380, RealAux: 0.0702, FakeAux: 0.0076)
# [Epoch 3/10] [Batch 650/1875] [Iter 4400]
#   G loss: -0.0214 (Adv: 0.3318, Aux: 0.0058, VQE_reg: -0.3590, E_c: -3.5896)
#   D loss: 0.9670 (RealAdv: 0.3741, FakeAdv: 1.4294, RealAux: 0.1286, FakeAux: 0.0019)
# [Epoch 3/10] [Batch 700/1875] [Iter 4450]
#   G loss: -0.0190 (Adv: 0.3373, Aux: 0.0025, VQE_reg: -0.3588, E_c: -3.5880)
#   D loss: 0.9162 (RealAdv: 0.3846, FakeAdv: 1.2150, RealAux: 0.2310, FakeAux: 0.0018)
# [Epoch 3/10] [Batch 750/1875] [Iter 4500]
#   G loss: -0.0369 (Adv: 0.3198, Aux: 0.0011, VQE_reg: -0.3578, E_c: -3.5783)
#   D loss: 0.9633 (RealAdv: 0.3911, FakeAdv: 1.4216, RealAux: 0.1099, FakeAux: 0.0040)
# [Epoch 3/10] [Batch 800/1875] [Iter 4550]
#   G loss: -0.0216 (Adv: 0.3351, Aux: 0.0021, VQE_reg: -0.3588, E_c: -3.5879)
#   D loss: 0.8490 (RealAdv: 0.3710, FakeAdv: 1.2494, RealAux: 0.0320, FakeAux: 0.0456)
# [Epoch 3/10] [Batch 850/1875] [Iter 4600]
#   G loss: 0.0051 (Adv: 0.3640, Aux: 0.0005, VQE_reg: -0.3593, E_c: -3.5932)
#   D loss: 0.8261 (RealAdv: 0.3792, FakeAdv: 1.2646, RealAux: 0.0076, FakeAux: 0.0008)
# [Epoch 3/10] [Batch 900/1875] [Iter 4650]
#   G loss: -0.0183 (Adv: 0.3369, Aux: 0.0044, VQE_reg: -0.3596, E_c: -3.5964)
#   D loss: 0.8618 (RealAdv: 0.3855, FakeAdv: 1.3169, RealAux: 0.0137, FakeAux: 0.0075)
# [Epoch 3/10] [Batch 950/1875] [Iter 4700]
#   G loss: 0.0238 (Adv: 0.3799, Aux: 0.0030, VQE_reg: -0.3591, E_c: -3.5914)
#   D loss: 0.8282 (RealAdv: 0.4248, FakeAdv: 1.2188, RealAux: 0.0117, FakeAux: 0.0011)
# [Epoch 3/10] [Batch 1000/1875] [Iter 4750]
#   G loss: -0.0383 (Adv: 0.3208, Aux: 0.0005, VQE_reg: -0.3596, E_c: -3.5960)
#   D loss: 0.9504 (RealAdv: 0.4050, FakeAdv: 1.3569, RealAux: 0.1386, FakeAux: 0.0003)
# [Epoch 3/10] [Batch 1050/1875] [Iter 4800]
#   G loss: -0.0430 (Adv: 0.3012, Aux: 0.0124, VQE_reg: -0.3566, E_c: -3.5656)
#   D loss: 0.8278 (RealAdv: 0.3813, FakeAdv: 1.2514, RealAux: 0.0193, FakeAux: 0.0036)
# [Epoch 3/10] [Batch 1100/1875] [Iter 4850]
#   G loss: 0.0856 (Adv: 0.3713, Aux: 0.0731, VQE_reg: -0.3588, E_c: -3.5875)
#   D loss: 0.8111 (RealAdv: 0.4216, FakeAdv: 1.1980, RealAux: 0.0022, FakeAux: 0.0005)
# [Epoch 3/10] [Batch 1150/1875] [Iter 4900]
#   G loss: -0.0452 (Adv: 0.3162, Aux: 0.0005, VQE_reg: -0.3619, E_c: -3.6194)
#   D loss: 0.8471 (RealAdv: 0.3951, FakeAdv: 1.2547, RealAux: 0.0437, FakeAux: 0.0007)
# [Epoch 3/10] [Batch 1200/1875] [Iter 4950]
#   G loss: 0.0024 (Adv: 0.3587, Aux: 0.0027, VQE_reg: -0.3591, E_c: -3.5909)
#   D loss: 0.7870 (RealAdv: 0.4016, FakeAdv: 1.1645, RealAux: 0.0067, FakeAux: 0.0012)
# [Epoch 3/10] [Batch 1250/1875] [Iter 5000]
#   G loss: -0.0327 (Adv: 0.3237, Aux: 0.0023, VQE_reg: -0.3587, E_c: -3.5872)
#   D loss: 0.8787 (RealAdv: 0.3895, FakeAdv: 1.3454, RealAux: 0.0220, FakeAux: 0.0006)
# [Epoch 3/10] [Batch 1300/1875] [Iter 5050]
#   G loss: -0.0555 (Adv: 0.2991, Aux: 0.0016, VQE_reg: -0.3562, E_c: -3.5622)
#   D loss: 0.8604 (RealAdv: 0.3886, FakeAdv: 1.3123, RealAux: 0.0182, FakeAux: 0.0017)
# [Epoch 3/10] [Batch 1350/1875] [Iter 5100]
#   G loss: 0.0477 (Adv: 0.3950, Aux: 0.0098, VQE_reg: -0.3571, E_c: -3.5710)
#   D loss: 0.8103 (RealAdv: 0.4046, FakeAdv: 1.1917, RealAux: 0.0198, FakeAux: 0.0044)
# [Epoch 3/10] [Batch 1400/1875] [Iter 5150]
#   G loss: -0.0338 (Adv: 0.3260, Aux: 0.0003, VQE_reg: -0.3601, E_c: -3.6005)
#   D loss: 0.9457 (RealAdv: 0.3672, FakeAdv: 1.4076, RealAux: 0.1157, FakeAux: 0.0009)
# [Epoch 3/10] [Batch 1450/1875] [Iter 5200]
#   G loss: -0.0136 (Adv: 0.3433, Aux: 0.0007, VQE_reg: -0.3576, E_c: -3.5763)
#   D loss: 0.8171 (RealAdv: 0.3956, FakeAdv: 1.2208, RealAux: 0.0174, FakeAux: 0.0005)
# [Epoch 3/10] [Batch 1500/1875] [Iter 5250]
#   G loss: -0.0090 (Adv: 0.3488, Aux: 0.0019, VQE_reg: -0.3596, E_c: -3.5959)
#   D loss: 0.8646 (RealAdv: 0.4127, FakeAdv: 1.3041, RealAux: 0.0082, FakeAux: 0.0043)
# [Epoch 3/10] [Batch 1550/1875] [Iter 5300]
#   G loss: -0.0482 (Adv: 0.3068, Aux: 0.0023, VQE_reg: -0.3573, E_c: -3.5729)
#   D loss: 0.8435 (RealAdv: 0.3845, FakeAdv: 1.2630, RealAux: 0.0391, FakeAux: 0.0004)
# [Epoch 3/10] [Batch 1600/1875] [Iter 5350]
#   G loss: 0.0199 (Adv: 0.3797, Aux: 0.0003, VQE_reg: -0.3601, E_c: -3.6010)
#   D loss: 0.7928 (RealAdv: 0.4087, FakeAdv: 1.1557, RealAux: 0.0185, FakeAux: 0.0027)
# [Epoch 3/10] [Batch 1650/1875] [Iter 5400]
#   G loss: 0.0119 (Adv: 0.3642, Aux: 0.0062, VQE_reg: -0.3585, E_c: -3.5854)
#   D loss: 0.8397 (RealAdv: 0.4119, FakeAdv: 1.1342, RealAux: 0.1324, FakeAux: 0.0010)
# [Epoch 3/10] [Batch 1700/1875] [Iter 5450]
#   G loss: -0.0560 (Adv: 0.2970, Aux: 0.0061, VQE_reg: -0.3590, E_c: -3.5902)
#   D loss: 0.8541 (RealAdv: 0.3833, FakeAdv: 1.3014, RealAux: 0.0197, FakeAux: 0.0037)
# [Epoch 3/10] [Batch 1750/1875] [Iter 5500]
#   G loss: 0.0437 (Adv: 0.3994, Aux: 0.0005, VQE_reg: -0.3561, E_c: -3.5610)
#   D loss: 0.8660 (RealAdv: 0.4329, FakeAdv: 1.2058, RealAux: 0.0928, FakeAux: 0.0004)
# [Epoch 3/10] [Batch 1800/1875] [Iter 5550]
#   G loss: -0.0361 (Adv: 0.3151, Aux: 0.0025, VQE_reg: -0.3538, E_c: -3.5377)
#   D loss: 0.8891 (RealAdv: 0.4050, FakeAdv: 1.2783, RealAux: 0.0942, FakeAux: 0.0006)
# [Epoch 3/10] [Batch 1850/1875] [Iter 5600]
#   G loss: 0.0078 (Adv: 0.3563, Aux: 0.0106, VQE_reg: -0.3591, E_c: -3.5910)
#   D loss: 0.8623 (RealAdv: 0.4430, FakeAdv: 1.1644, RealAux: 0.1148, FakeAux: 0.0023)
#
# --- End of Epoch 3/10 (Duration: 4980.98s) ---
#   Avg G Loss: -0.0083 (Adv: 0.3442, Aux: 0.0055, VQE_reg: -0.3580, Avg E_c: -3.5801)
#   Avg D Loss: 0.8690 (R_Adv: 0.3935, F_Adv: 1.2710, R_Aux: 0.0679, F_Aux: 0.0056)
#   Samples for epoch 3 saved.
#   Running evaluation for epoch 3...
#   Generating 1000 samples for FID/IS into '/tmp/tmpl5x0df2y'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 54.5969, IS (mean): 2.0621
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 98.40%
#   *** New best FID: 54.5969 at epoch 3. Models saved. ***
# ------------------------------------------------------------
# [Epoch 4/10] [Batch 25/1875] [Iter 5650]
#   G loss: -0.0006 (Adv: 0.3544, Aux: 0.0014, VQE_reg: -0.3564, E_c: -3.5642)
#   D loss: 0.8168 (RealAdv: 0.4027, FakeAdv: 1.2236, RealAux: 0.0061, FakeAux: 0.0012)
# [Epoch 4/10] [Batch 75/1875] [Iter 5700]
#   G loss: -0.0349 (Adv: 0.3212, Aux: 0.0009, VQE_reg: -0.3570, E_c: -3.5705)
#   D loss: 0.8909 (RealAdv: 0.3950, FakeAdv: 1.3092, RealAux: 0.0730, FakeAux: 0.0047)
# [Epoch 4/10] [Batch 125/1875] [Iter 5750]
#   G loss: -0.0129 (Adv: 0.3469, Aux: 0.0002, VQE_reg: -0.3600, E_c: -3.6002)
#   D loss: 0.9245 (RealAdv: 0.3836, FakeAdv: 1.3732, RealAux: 0.0913, FakeAux: 0.0009)
# [Epoch 4/10] [Batch 175/1875] [Iter 5800]
#   G loss: -0.0219 (Adv: 0.3298, Aux: 0.0091, VQE_reg: -0.3609, E_c: -3.6085)
#   D loss: 0.8262 (RealAdv: 0.3945, FakeAdv: 1.2072, RealAux: 0.0505, FakeAux: 0.0001)
# [Epoch 4/10] [Batch 225/1875] [Iter 5850]
#   G loss: 0.0110 (Adv: 0.3680, Aux: 0.0003, VQE_reg: -0.3573, E_c: -3.5731)
#   D loss: 0.8595 (RealAdv: 0.4317, FakeAdv: 1.2705, RealAux: 0.0164, FakeAux: 0.0006)
# [Epoch 4/10] [Batch 275/1875] [Iter 5900]
#   G loss: -0.0125 (Adv: 0.3462, Aux: 0.0013, VQE_reg: -0.3600, E_c: -3.5995)
#   D loss: 0.8923 (RealAdv: 0.3882, FakeAdv: 1.2316, RealAux: 0.1621, FakeAux: 0.0027)
# [Epoch 4/10] [Batch 325/1875] [Iter 5950]
#   G loss: -0.0591 (Adv: 0.2912, Aux: 0.0036, VQE_reg: -0.3540, E_c: -3.5396)
#   D loss: 0.8940 (RealAdv: 0.3973, FakeAdv: 1.3776, RealAux: 0.0068, FakeAux: 0.0062)
# [Epoch 4/10] [Batch 375/1875] [Iter 6000]
#   G loss: -0.0420 (Adv: 0.3154, Aux: 0.0006, VQE_reg: -0.3580, E_c: -3.5796)
#   D loss: 0.8621 (RealAdv: 0.3806, FakeAdv: 1.3289, RealAux: 0.0047, FakeAux: 0.0100)
# [Epoch 4/10] [Batch 425/1875] [Iter 6050]
#   G loss: 0.0054 (Adv: 0.3655, Aux: 0.0002, VQE_reg: -0.3604, E_c: -3.6036)
#   D loss: 0.8116 (RealAdv: 0.4020, FakeAdv: 1.1747, RealAux: 0.0437, FakeAux: 0.0028)
# [Epoch 4/10] [Batch 475/1875] [Iter 6100]
#   G loss: -0.0114 (Adv: 0.3466, Aux: 0.0008, VQE_reg: -0.3588, E_c: -3.5884)
#   D loss: 0.9223 (RealAdv: 0.4083, FakeAdv: 1.2728, RealAux: 0.1622, FakeAux: 0.0012)
# [Epoch 4/10] [Batch 525/1875] [Iter 6150]
#   G loss: -0.0488 (Adv: 0.3094, Aux: 0.0018, VQE_reg: -0.3600, E_c: -3.6001)
#   D loss: 0.8627 (RealAdv: 0.3800, FakeAdv: 1.3410, RealAux: 0.0039, FakeAux: 0.0003)
# [Epoch 4/10] [Batch 575/1875] [Iter 6200]
#   G loss: -0.0589 (Adv: 0.2973, Aux: 0.0020, VQE_reg: -0.3581, E_c: -3.5814)
#   D loss: 0.8511 (RealAdv: 0.3831, FakeAdv: 1.3045, RealAux: 0.0138, FakeAux: 0.0009)
# [Epoch 4/10] [Batch 625/1875] [Iter 6250]
#   G loss: -0.0290 (Adv: 0.3319, Aux: 0.0002, VQE_reg: -0.3611, E_c: -3.6111)
#   D loss: 0.8339 (RealAdv: 0.4158, FakeAdv: 1.2472, RealAux: 0.0038, FakeAux: 0.0011)
# [Epoch 4/10] [Batch 675/1875] [Iter 6300]
#   G loss: -0.0328 (Adv: 0.3209, Aux: 0.0029, VQE_reg: -0.3567, E_c: -3.5666)
#   D loss: 0.8600 (RealAdv: 0.4079, FakeAdv: 1.3072, RealAux: 0.0042, FakeAux: 0.0007)
# [Epoch 4/10] [Batch 725/1875] [Iter 6350]
#   G loss: 0.0170 (Adv: 0.3738, Aux: 0.0013, VQE_reg: -0.3581, E_c: -3.5807)
#   D loss: 0.8233 (RealAdv: 0.4132, FakeAdv: 1.2260, RealAux: 0.0066, FakeAux: 0.0008)
# [Epoch 4/10] [Batch 775/1875] [Iter 6400]
#   G loss: -0.0249 (Adv: 0.3342, Aux: 0.0007, VQE_reg: -0.3598, E_c: -3.5978)
#   D loss: 0.8125 (RealAdv: 0.4048, FakeAdv: 1.2151, RealAux: 0.0049, FakeAux: 0.0001)
# [Epoch 4/10] [Batch 825/1875] [Iter 6450]
#   G loss: -0.0000 (Adv: 0.3609, Aux: 0.0011, VQE_reg: -0.3620, E_c: -3.6200)
#   D loss: 0.8515 (RealAdv: 0.3985, FakeAdv: 1.2645, RealAux: 0.0328, FakeAux: 0.0072)
# [Epoch 4/10] [Batch 875/1875] [Iter 6500]
#   G loss: 0.0076 (Adv: 0.3691, Aux: 0.0016, VQE_reg: -0.3631, E_c: -3.6311)
#   D loss: 0.9356 (RealAdv: 0.4351, FakeAdv: 1.2056, RealAux: 0.2290, FakeAux: 0.0013)
# [Epoch 4/10] [Batch 925/1875] [Iter 6550]
#   G loss: -0.0133 (Adv: 0.3258, Aux: 0.0175, VQE_reg: -0.3567, E_c: -3.5667)
#   D loss: 0.8231 (RealAdv: 0.3867, FakeAdv: 1.2468, RealAux: 0.0123, FakeAux: 0.0003)
# [Epoch 4/10] [Batch 975/1875] [Iter 6600]
#   G loss: -0.0372 (Adv: 0.3180, Aux: 0.0025, VQE_reg: -0.3577, E_c: -3.5770)
#   D loss: 0.8668 (RealAdv: 0.4135, FakeAdv: 1.2458, RealAux: 0.0671, FakeAux: 0.0072)
# [Epoch 4/10] [Batch 1025/1875] [Iter 6650]
#   G loss: 0.0372 (Adv: 0.3726, Aux: 0.0258, VQE_reg: -0.3613, E_c: -3.6127)
#   D loss: 0.8336 (RealAdv: 0.4099, FakeAdv: 1.2424, RealAux: 0.0138, FakeAux: 0.0011)
# [Epoch 4/10] [Batch 1075/1875] [Iter 6700]
#   G loss: 0.0178 (Adv: 0.3702, Aux: 0.0003, VQE_reg: -0.3527, E_c: -3.5272)
#   D loss: 0.8926 (RealAdv: 0.3980, FakeAdv: 1.2675, RealAux: 0.1193, FakeAux: 0.0004)
# [Epoch 4/10] [Batch 1125/1875] [Iter 6750]
#   G loss: -0.0218 (Adv: 0.3346, Aux: 0.0001, VQE_reg: -0.3565, E_c: -3.5651)
#   D loss: 0.8891 (RealAdv: 0.3952, FakeAdv: 1.3478, RealAux: 0.0317, FakeAux: 0.0036)
# [Epoch 4/10] [Batch 1175/1875] [Iter 6800]
#   G loss: -0.0377 (Adv: 0.3215, Aux: 0.0009, VQE_reg: -0.3601, E_c: -3.6009)
#   D loss: 0.8498 (RealAdv: 0.3975, FakeAdv: 1.2606, RealAux: 0.0405, FakeAux: 0.0009)
# [Epoch 4/10] [Batch 1225/1875] [Iter 6850]
#   G loss: -0.0096 (Adv: 0.3513, Aux: 0.0002, VQE_reg: -0.3611, E_c: -3.6113)
#   D loss: 0.8303 (RealAdv: 0.4077, FakeAdv: 1.2448, RealAux: 0.0070, FakeAux: 0.0012)
# [Epoch 4/10] [Batch 1275/1875] [Iter 6900]
#   G loss: -0.0175 (Adv: 0.3402, Aux: 0.0003, VQE_reg: -0.3581, E_c: -3.5814)
#   D loss: 0.9385 (RealAdv: 0.4046, FakeAdv: 1.2888, RealAux: 0.1814, FakeAux: 0.0022)
# [Epoch 4/10] [Batch 1325/1875] [Iter 6950]
#   G loss: -0.0263 (Adv: 0.3321, Aux: 0.0005, VQE_reg: -0.3589, E_c: -3.5889)
#   D loss: 0.9025 (RealAdv: 0.4192, FakeAdv: 1.2492, RealAux: 0.1360, FakeAux: 0.0006)
# [Epoch 4/10] [Batch 1375/1875] [Iter 7000]
#   G loss: -0.0531 (Adv: 0.3017, Aux: 0.0020, VQE_reg: -0.3569, E_c: -3.5685)
#   D loss: 0.9240 (RealAdv: 0.4138, FakeAdv: 1.2666, RealAux: 0.0359, FakeAux: 0.1317)
# [Epoch 4/10] [Batch 1425/1875] [Iter 7050]
#   G loss: -0.0279 (Adv: 0.3254, Aux: 0.0017, VQE_reg: -0.3550, E_c: -3.5503)
#   D loss: 0.9017 (RealAdv: 0.3894, FakeAdv: 1.3983, RealAux: 0.0106, FakeAux: 0.0050)
# [Epoch 4/10] [Batch 1475/1875] [Iter 7100]
#   G loss: -0.0496 (Adv: 0.3068, Aux: 0.0010, VQE_reg: -0.3574, E_c: -3.5742)
#   D loss: 0.8581 (RealAdv: 0.3972, FakeAdv: 1.3028, RealAux: 0.0109, FakeAux: 0.0054)
# [Epoch 4/10] [Batch 1525/1875] [Iter 7150]
#   G loss: 0.0293 (Adv: 0.3818, Aux: 0.0030, VQE_reg: -0.3555, E_c: -3.5553)
#   D loss: 0.8106 (RealAdv: 0.4316, FakeAdv: 1.1650, RealAux: 0.0242, FakeAux: 0.0003)
# [Epoch 4/10] [Batch 1575/1875] [Iter 7200]
#   G loss: 0.0239 (Adv: 0.3833, Aux: 0.0004, VQE_reg: -0.3599, E_c: -3.5987)
#   D loss: 0.8160 (RealAdv: 0.4148, FakeAdv: 1.1793, RealAux: 0.0354, FakeAux: 0.0024)
# [Epoch 4/10] [Batch 1625/1875] [Iter 7250]
#   G loss: -0.0147 (Adv: 0.3444, Aux: 0.0009, VQE_reg: -0.3600, E_c: -3.6003)
#   D loss: 0.8324 (RealAdv: 0.3965, FakeAdv: 1.2606, RealAux: 0.0051, FakeAux: 0.0025)
# [Epoch 4/10] [Batch 1675/1875] [Iter 7300]
#   G loss: -0.0300 (Adv: 0.3250, Aux: 0.0003, VQE_reg: -0.3553, E_c: -3.5530)
#   D loss: 0.8259 (RealAdv: 0.4035, FakeAdv: 1.2289, RealAux: 0.0185, FakeAux: 0.0008)
# [Epoch 4/10] [Batch 1725/1875] [Iter 7350]
#   G loss: -0.0198 (Adv: 0.3384, Aux: 0.0002, VQE_reg: -0.3584, E_c: -3.5841)
#   D loss: 0.9440 (RealAdv: 0.3856, FakeAdv: 1.3378, RealAux: 0.1615, FakeAux: 0.0032)
# [Epoch 4/10] [Batch 1775/1875] [Iter 7400]
#   G loss: -0.0345 (Adv: 0.3216, Aux: 0.0012, VQE_reg: -0.3572, E_c: -3.5724)
#   D loss: 0.8186 (RealAdv: 0.4090, FakeAdv: 1.2243, RealAux: 0.0022, FakeAux: 0.0016)
# [Epoch 4/10] [Batch 1825/1875] [Iter 7450]
#   G loss: -0.0474 (Adv: 0.3094, Aux: 0.0015, VQE_reg: -0.3583, E_c: -3.5834)
#   D loss: 0.8324 (RealAdv: 0.3937, FakeAdv: 1.2333, RealAux: 0.0346, FakeAux: 0.0034)
# [Epoch 4/10] [Batch 1875/1875] [Iter 7500]
#   G loss: -0.0437 (Adv: 0.3112, Aux: 0.0007, VQE_reg: -0.3556, E_c: -3.5557)
#   D loss: 0.9408 (RealAdv: 0.3783, FakeAdv: 1.3835, RealAux: 0.1176, FakeAux: 0.0021)
#
# --- End of Epoch 4/10 (Duration: 4969.68s) ---
#   Avg G Loss: -0.0168 (Adv: 0.3377, Aux: 0.0035, VQE_reg: -0.3580, Avg E_c: -3.5805)
#   Avg D Loss: 0.8692 (R_Adv: 0.4013, F_Adv: 1.2807, R_Aux: 0.0520, F_Aux: 0.0044)
#   Samples for epoch 4 saved.
#   Running evaluation for epoch 4...
#   Generating 1000 samples for FID/IS into '/tmp/tmp4u8f25wn'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 37.9757, IS (mean): 2.0831
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 97.00%
#   *** New best FID: 37.9757 at epoch 4. Models saved. ***
# ------------------------------------------------------------
# [Epoch 5/10] [Batch 50/1875] [Iter 7550]
#   G loss: -0.0141 (Adv: 0.3433, Aux: 0.0007, VQE_reg: -0.3582, E_c: -3.5817)
#   D loss: 0.8396 (RealAdv: 0.3993, FakeAdv: 1.2666, RealAux: 0.0128, FakeAux: 0.0005)
# [Epoch 5/10] [Batch 100/1875] [Iter 7600]
#   G loss: -0.0480 (Adv: 0.3089, Aux: 0.0002, VQE_reg: -0.3571, E_c: -3.5709)
#   D loss: 0.8704 (RealAdv: 0.4024, FakeAdv: 1.3348, RealAux: 0.0030, FakeAux: 0.0005)
# [Epoch 5/10] [Batch 150/1875] [Iter 7650]
#   G loss: -0.0115 (Adv: 0.3498, Aux: 0.0008, VQE_reg: -0.3621, E_c: -3.6210)
#   D loss: 0.8402 (RealAdv: 0.3948, FakeAdv: 1.2596, RealAux: 0.0251, FakeAux: 0.0008)
# [Epoch 5/10] [Batch 200/1875] [Iter 7700]
#   G loss: -0.0201 (Adv: 0.3367, Aux: 0.0010, VQE_reg: -0.3578, E_c: -3.5777)
#   D loss: 0.8440 (RealAdv: 0.4070, FakeAdv: 1.2774, RealAux: 0.0020, FakeAux: 0.0016)
# [Epoch 5/10] [Batch 250/1875] [Iter 7750]
#   G loss: -0.0479 (Adv: 0.3060, Aux: 0.0002, VQE_reg: -0.3541, E_c: -3.5414)
#   D loss: 0.8950 (RealAdv: 0.4116, FakeAdv: 1.3610, RealAux: 0.0158, FakeAux: 0.0017)
# [Epoch 5/10] [Batch 300/1875] [Iter 7800]
#   G loss: 0.0011 (Adv: 0.3567, Aux: 0.0004, VQE_reg: -0.3560, E_c: -3.5601)
#   D loss: 0.8699 (RealAdv: 0.4068, FakeAdv: 1.2258, RealAux: 0.0969, FakeAux: 0.0102)
# [Epoch 5/10] [Batch 350/1875] [Iter 7850]
#   G loss: -0.0155 (Adv: 0.3431, Aux: 0.0006, VQE_reg: -0.3592, E_c: -3.5920)
#   D loss: 0.8502 (RealAdv: 0.3712, FakeAdv: 1.2928, RealAux: 0.0357, FakeAux: 0.0007)
# [Epoch 5/10] [Batch 400/1875] [Iter 7900]
#   G loss: -0.0278 (Adv: 0.3279, Aux: 0.0008, VQE_reg: -0.3565, E_c: -3.5653)
#   D loss: 0.8353 (RealAdv: 0.3979, FakeAdv: 1.2509, RealAux: 0.0192, FakeAux: 0.0026)
# [Epoch 5/10] [Batch 450/1875] [Iter 7950]
#   G loss: -0.0503 (Adv: 0.3069, Aux: 0.0009, VQE_reg: -0.3581, E_c: -3.5810)
#   D loss: 0.8946 (RealAdv: 0.3811, FakeAdv: 1.3295, RealAux: 0.0782, FakeAux: 0.0004)
# [Epoch 5/10] [Batch 500/1875] [Iter 8000]
#   G loss: -0.0304 (Adv: 0.3237, Aux: 0.0015, VQE_reg: -0.3555, E_c: -3.5554)
#   D loss: 0.8713 (RealAdv: 0.4034, FakeAdv: 1.3118, RealAux: 0.0178, FakeAux: 0.0096)
# [Epoch 5/10] [Batch 550/1875] [Iter 8050]
#   G loss: -0.0051 (Adv: 0.3520, Aux: 0.0006, VQE_reg: -0.3577, E_c: -3.5771)
#   D loss: 0.8913 (RealAdv: 0.4160, FakeAdv: 1.3439, RealAux: 0.0225, FakeAux: 0.0002)
# [Epoch 5/10] [Batch 600/1875] [Iter 8100]
#   G loss: -0.0259 (Adv: 0.3124, Aux: 0.0183, VQE_reg: -0.3566, E_c: -3.5663)
#   D loss: 0.8879 (RealAdv: 0.3883, FakeAdv: 1.3748, RealAux: 0.0115, FakeAux: 0.0012)
# [Epoch 5/10] [Batch 650/1875] [Iter 8150]
#   G loss: -0.0535 (Adv: 0.2978, Aux: 0.0059, VQE_reg: -0.3573, E_c: -3.5725)
#   D loss: 0.8251 (RealAdv: 0.3765, FakeAdv: 1.2644, RealAux: 0.0091, FakeAux: 0.0002)
# [Epoch 5/10] [Batch 700/1875] [Iter 8200]
#   G loss: -0.0930 (Adv: 0.2647, Aux: 0.0002, VQE_reg: -0.3580, E_c: -3.5800)
#   D loss: 0.8996 (RealAdv: 0.3737, FakeAdv: 1.4244, RealAux: 0.0008, FakeAux: 0.0004)
# [Epoch 5/10] [Batch 750/1875] [Iter 8250]
#   G loss: 0.0066 (Adv: 0.3620, Aux: 0.0006, VQE_reg: -0.3560, E_c: -3.5600)
#   D loss: 0.8204 (RealAdv: 0.3913, FakeAdv: 1.2255, RealAux: 0.0108, FakeAux: 0.0132)
# [Epoch 5/10] [Batch 800/1875] [Iter 8300]
#   G loss: 0.0153 (Adv: 0.3662, Aux: 0.0027, VQE_reg: -0.3536, E_c: -3.5363)
#   D loss: 0.8042 (RealAdv: 0.4392, FakeAdv: 1.1604, RealAux: 0.0074, FakeAux: 0.0014)
# [Epoch 5/10] [Batch 850/1875] [Iter 8350]
#   G loss: -0.0118 (Adv: 0.3467, Aux: 0.0005, VQE_reg: -0.3590, E_c: -3.5902)
#   D loss: 0.8642 (RealAdv: 0.4106, FakeAdv: 1.3133, RealAux: 0.0037, FakeAux: 0.0007)
# [Epoch 5/10] [Batch 900/1875] [Iter 8400]
#   G loss: -0.0079 (Adv: 0.3527, Aux: 0.0003, VQE_reg: -0.3609, E_c: -3.6089)
#   D loss: 0.8141 (RealAdv: 0.4024, FakeAdv: 1.2187, RealAux: 0.0068, FakeAux: 0.0003)
# [Epoch 5/10] [Batch 950/1875] [Iter 8450]
#   G loss: 0.0140 (Adv: 0.3652, Aux: 0.0008, VQE_reg: -0.3520, E_c: -3.5203)
#   D loss: 0.8813 (RealAdv: 0.4053, FakeAdv: 1.3481, RealAux: 0.0084, FakeAux: 0.0008)
# [Epoch 5/10] [Batch 1000/1875] [Iter 8500]
#   G loss: -0.0114 (Adv: 0.3429, Aux: 0.0013, VQE_reg: -0.3556, E_c: -3.5556)
#   D loss: 0.8219 (RealAdv: 0.4166, FakeAdv: 1.2219, RealAux: 0.0046, FakeAux: 0.0007)
# [Epoch 5/10] [Batch 1050/1875] [Iter 8550]
#   G loss: 0.0003 (Adv: 0.3545, Aux: 0.0029, VQE_reg: -0.3571, E_c: -3.5715)
#   D loss: 0.8069 (RealAdv: 0.4315, FakeAdv: 1.1728, RealAux: 0.0094, FakeAux: 0.0002)
# [Epoch 5/10] [Batch 1100/1875] [Iter 8600]
#   G loss: -0.0334 (Adv: 0.3188, Aux: 0.0036, VQE_reg: -0.3558, E_c: -3.5576)
#   D loss: 0.8792 (RealAdv: 0.3989, FakeAdv: 1.3273, RealAux: 0.0285, FakeAux: 0.0037)
# [Epoch 5/10] [Batch 1150/1875] [Iter 8650]
#   G loss: -0.0124 (Adv: 0.3452, Aux: 0.0007, VQE_reg: -0.3583, E_c: -3.5825)
#   D loss: 0.8485 (RealAdv: 0.4002, FakeAdv: 1.2853, RealAux: 0.0111, FakeAux: 0.0003)
# [Epoch 5/10] [Batch 1200/1875] [Iter 8700]
#   G loss: -0.0213 (Adv: 0.3365, Aux: 0.0003, VQE_reg: -0.3581, E_c: -3.5810)
#   D loss: 0.8947 (RealAdv: 0.4057, FakeAdv: 1.3720, RealAux: 0.0080, FakeAux: 0.0036)
# [Epoch 5/10] [Batch 1250/1875] [Iter 8750]
#   G loss: -0.0336 (Adv: 0.3145, Aux: 0.0053, VQE_reg: -0.3534, E_c: -3.5344)
#   D loss: 0.8673 (RealAdv: 0.4269, FakeAdv: 1.3027, RealAux: 0.0039, FakeAux: 0.0011)
# [Epoch 5/10] [Batch 1300/1875] [Iter 8800]
#   G loss: 0.0197 (Adv: 0.3796, Aux: 0.0002, VQE_reg: -0.3600, E_c: -3.6002)
#   D loss: 0.7993 (RealAdv: 0.4121, FakeAdv: 1.1723, RealAux: 0.0137, FakeAux: 0.0006)
# [Epoch 5/10] [Batch 1350/1875] [Iter 8850]
#   G loss: -0.0386 (Adv: 0.3174, Aux: 0.0020, VQE_reg: -0.3580, E_c: -3.5801)
#   D loss: 0.8470 (RealAdv: 0.4034, FakeAdv: 1.2863, RealAux: 0.0038, FakeAux: 0.0005)
# [Epoch 5/10] [Batch 1400/1875] [Iter 8900]
#   G loss: -0.0072 (Adv: 0.3510, Aux: 0.0008, VQE_reg: -0.3589, E_c: -3.5894)
#   D loss: 0.7958 (RealAdv: 0.4202, FakeAdv: 1.1459, RealAux: 0.0248, FakeAux: 0.0006)
# [Epoch 5/10] [Batch 1450/1875] [Iter 8950]
#   G loss: -0.0597 (Adv: 0.2981, Aux: 0.0007, VQE_reg: -0.3585, E_c: -3.5847)
#   D loss: 0.9152 (RealAdv: 0.3982, FakeAdv: 1.3997, RealAux: 0.0313, FakeAux: 0.0012)
# [Epoch 5/10] [Batch 1500/1875] [Iter 9000]
#   G loss: -0.0289 (Adv: 0.3262, Aux: 0.0037, VQE_reg: -0.3588, E_c: -3.5882)
#   D loss: 0.8536 (RealAdv: 0.3986, FakeAdv: 1.2920, RealAux: 0.0161, FakeAux: 0.0004)
# [Epoch 5/10] [Batch 1550/1875] [Iter 9050]
#   G loss: -0.0632 (Adv: 0.2933, Aux: 0.0016, VQE_reg: -0.3581, E_c: -3.5809)
#   D loss: 0.8442 (RealAdv: 0.4132, FakeAdv: 1.2624, RealAux: 0.0120, FakeAux: 0.0009)
# [Epoch 5/10] [Batch 1600/1875] [Iter 9100]
#   G loss: 0.0072 (Adv: 0.3660, Aux: 0.0013, VQE_reg: -0.3600, E_c: -3.6005)
#   D loss: 0.8160 (RealAdv: 0.4125, FakeAdv: 1.2113, RealAux: 0.0077, FakeAux: 0.0005)
# [Epoch 5/10] [Batch 1650/1875] [Iter 9150]
#   G loss: -0.0290 (Adv: 0.3276, Aux: 0.0021, VQE_reg: -0.3587, E_c: -3.5870)
#   D loss: 0.8505 (RealAdv: 0.4191, FakeAdv: 1.2553, RealAux: 0.0264, FakeAux: 0.0001)
# [Epoch 5/10] [Batch 1700/1875] [Iter 9200]
#   G loss: 0.0440 (Adv: 0.3291, Aux: 0.0741, VQE_reg: -0.3592, E_c: -3.5922)
#   D loss: 0.8819 (RealAdv: 0.3949, FakeAdv: 1.3261, RealAux: 0.0388, FakeAux: 0.0039)
# [Epoch 5/10] [Batch 1750/1875] [Iter 9250]
#   G loss: -0.0195 (Adv: 0.3368, Aux: 0.0005, VQE_reg: -0.3568, E_c: -3.5676)
#   D loss: 0.8873 (RealAdv: 0.4167, FakeAdv: 1.2551, RealAux: 0.1018, FakeAux: 0.0009)
# [Epoch 5/10] [Batch 1800/1875] [Iter 9300]
#   G loss: -0.0257 (Adv: 0.3319, Aux: 0.0011, VQE_reg: -0.3588, E_c: -3.5881)
#   D loss: 0.8582 (RealAdv: 0.4163, FakeAdv: 1.2910, RealAux: 0.0085, FakeAux: 0.0005)
# [Epoch 5/10] [Batch 1850/1875] [Iter 9350]
#   G loss: -0.0078 (Adv: 0.3496, Aux: 0.0001, VQE_reg: -0.3575, E_c: -3.5748)
#   D loss: 0.8336 (RealAdv: 0.3780, FakeAdv: 1.2821, RealAux: 0.0069, FakeAux: 0.0003)
#
# --- End of Epoch 5/10 (Duration: 4973.80s) ---
#   Avg G Loss: -0.0178 (Adv: 0.3358, Aux: 0.0043, VQE_reg: -0.3580, Avg E_c: -3.5799)
#   Avg D Loss: 0.8657 (R_Adv: 0.4032, F_Adv: 1.2806, R_Aux: 0.0439, F_Aux: 0.0037)
#   Samples for epoch 5 saved.
#   Running evaluation for epoch 5...
#   Generating 1000 samples for FID/IS into '/tmp/tmp43lj9x00'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 35.9578, IS (mean): 2.0639
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 99.00%
#   *** New best FID: 35.9578 at epoch 5. Models saved. ***
# ------------------------------------------------------------
# [Epoch 6/10] [Batch 25/1875] [Iter 9400]
#   G loss: 0.0307 (Adv: 0.3916, Aux: 0.0013, VQE_reg: -0.3621, E_c: -3.6214)
#   D loss: 0.8767 (RealAdv: 0.3993, FakeAdv: 1.3241, RealAux: 0.0296, FakeAux: 0.0003)
# [Epoch 6/10] [Batch 75/1875] [Iter 9450]
#   G loss: -0.0008 (Adv: 0.3580, Aux: 0.0003, VQE_reg: -0.3591, E_c: -3.5906)
#   D loss: 0.9092 (RealAdv: 0.4118, FakeAdv: 1.3861, RealAux: 0.0161, FakeAux: 0.0044)
# [Epoch 6/10] [Batch 125/1875] [Iter 9500]
#   G loss: -0.0012 (Adv: 0.3598, Aux: 0.0005, VQE_reg: -0.3615, E_c: -3.6151)
#   D loss: 0.8433 (RealAdv: 0.3905, FakeAdv: 1.2954, RealAux: 0.0003, FakeAux: 0.0004)
# [Epoch 6/10] [Batch 175/1875] [Iter 9550]
#   G loss: 0.0120 (Adv: 0.3688, Aux: 0.0004, VQE_reg: -0.3572, E_c: -3.5720)
#   D loss: 0.8691 (RealAdv: 0.4077, FakeAdv: 1.2956, RealAux: 0.0347, FakeAux: 0.0002)
# [Epoch 6/10] [Batch 225/1875] [Iter 9600]
#   G loss: -0.0365 (Adv: 0.3192, Aux: 0.0003, VQE_reg: -0.3560, E_c: -3.5596)
#   D loss: 0.8824 (RealAdv: 0.4028, FakeAdv: 1.2954, RealAux: 0.0665, FakeAux: 0.0002)
# [Epoch 6/10] [Batch 275/1875] [Iter 9650]
#   G loss: -0.0213 (Adv: 0.3363, Aux: 0.0004, VQE_reg: -0.3580, E_c: -3.5803)
#   D loss: 0.8610 (RealAdv: 0.4137, FakeAdv: 1.2820, RealAux: 0.0254, FakeAux: 0.0008)
# [Epoch 6/10] [Batch 325/1875] [Iter 9700]
#   G loss: -0.0251 (Adv: 0.3303, Aux: 0.0020, VQE_reg: -0.3575, E_c: -3.5745)
#   D loss: 0.8519 (RealAdv: 0.4206, FakeAdv: 1.2717, RealAux: 0.0014, FakeAux: 0.0100)
# [Epoch 6/10] [Batch 375/1875] [Iter 9750]
#   G loss: -0.0643 (Adv: 0.2948, Aux: 0.0003, VQE_reg: -0.3594, E_c: -3.5943)
#   D loss: 0.7924 (RealAdv: 0.4092, FakeAdv: 1.1692, RealAux: 0.0040, FakeAux: 0.0024)
# [Epoch 6/10] [Batch 425/1875] [Iter 9800]
#   G loss: -0.0460 (Adv: 0.3094, Aux: 0.0033, VQE_reg: -0.3587, E_c: -3.5866)
#   D loss: 0.8499 (RealAdv: 0.4090, FakeAdv: 1.2710, RealAux: 0.0192, FakeAux: 0.0006)
# [Epoch 6/10] [Batch 475/1875] [Iter 9850]
#   G loss: 0.0260 (Adv: 0.3819, Aux: 0.0015, VQE_reg: -0.3575, E_c: -3.5748)
#   D loss: 0.8194 (RealAdv: 0.4496, FakeAdv: 1.1593, RealAux: 0.0294, FakeAux: 0.0004)
# [Epoch 6/10] [Batch 525/1875] [Iter 9900]
#   G loss: -0.0073 (Adv: 0.3509, Aux: 0.0017, VQE_reg: -0.3599, E_c: -3.5990)
#   D loss: 0.8336 (RealAdv: 0.4219, FakeAdv: 1.2434, RealAux: 0.0014, FakeAux: 0.0005)
# [Epoch 6/10] [Batch 575/1875] [Iter 9950]
#   G loss: -0.0230 (Adv: 0.3314, Aux: 0.0006, VQE_reg: -0.3550, E_c: -3.5496)
#   D loss: 0.9021 (RealAdv: 0.4015, FakeAdv: 1.3975, RealAux: 0.0019, FakeAux: 0.0033)
# [Epoch 6/10] [Batch 625/1875] [Iter 10000]
#   G loss: -0.0223 (Adv: 0.3365, Aux: 0.0002, VQE_reg: -0.3590, E_c: -3.5903)
#   D loss: 0.8998 (RealAdv: 0.3922, FakeAdv: 1.3707, RealAux: 0.0365, FakeAux: 0.0002)
# [Epoch 6/10] [Batch 675/1875] [Iter 10050]
#   G loss: -0.0392 (Adv: 0.3198, Aux: 0.0001, VQE_reg: -0.3592, E_c: -3.5917)
#   D loss: 0.8951 (RealAdv: 0.3948, FakeAdv: 1.3582, RealAux: 0.0369, FakeAux: 0.0003)
# [Epoch 6/10] [Batch 725/1875] [Iter 10100]
#   G loss: 0.0097 (Adv: 0.3708, Aux: 0.0003, VQE_reg: -0.3614, E_c: -3.6142)
#   D loss: 0.8439 (RealAdv: 0.4170, FakeAdv: 1.2679, RealAux: 0.0013, FakeAux: 0.0016)
# [Epoch 6/10] [Batch 775/1875] [Iter 10150]
#   G loss: -0.0108 (Adv: 0.3459, Aux: 0.0003, VQE_reg: -0.3570, E_c: -3.5699)
#   D loss: 0.8775 (RealAdv: 0.4085, FakeAdv: 1.2533, RealAux: 0.0930, FakeAux: 0.0002)
# [Epoch 6/10] [Batch 825/1875] [Iter 10200]
#   G loss: -0.0338 (Adv: 0.3238, Aux: 0.0004, VQE_reg: -0.3580, E_c: -3.5797)
#   D loss: 0.8443 (RealAdv: 0.4199, FakeAdv: 1.2351, RealAux: 0.0333, FakeAux: 0.0002)
# [Epoch 6/10] [Batch 875/1875] [Iter 10250]
#   G loss: -0.0076 (Adv: 0.3527, Aux: 0.0003, VQE_reg: -0.3606, E_c: -3.6064)
#   D loss: 0.8528 (RealAdv: 0.4168, FakeAdv: 1.2796, RealAux: 0.0018, FakeAux: 0.0073)
# [Epoch 6/10] [Batch 925/1875] [Iter 10300]
#   G loss: 0.0143 (Adv: 0.3677, Aux: 0.0038, VQE_reg: -0.3572, E_c: -3.5722)
#   D loss: 0.8422 (RealAdv: 0.4236, FakeAdv: 1.2566, RealAux: 0.0020, FakeAux: 0.0021)
# [Epoch 6/10] [Batch 975/1875] [Iter 10350]
#   G loss: -0.0701 (Adv: 0.2891, Aux: 0.0006, VQE_reg: -0.3598, E_c: -3.5980)
#   D loss: 0.8729 (RealAdv: 0.3851, FakeAdv: 1.3429, RealAux: 0.0171, FakeAux: 0.0007)
# [Epoch 6/10] [Batch 1025/1875] [Iter 10400]
#   G loss: -0.0657 (Adv: 0.2918, Aux: 0.0001, VQE_reg: -0.3576, E_c: -3.5762)
#   D loss: 1.0833 (RealAdv: 0.3761, FakeAdv: 1.3900, RealAux: 0.4000, FakeAux: 0.0005)
# [Epoch 6/10] [Batch 1075/1875] [Iter 10450]
#   G loss: -0.0551 (Adv: 0.3004, Aux: 0.0001, VQE_reg: -0.3557, E_c: -3.5567)
#   D loss: 0.8296 (RealAdv: 0.4028, FakeAdv: 1.2473, RealAux: 0.0086, FakeAux: 0.0004)
# [Epoch 6/10] [Batch 1125/1875] [Iter 10500]
#   G loss: -0.0296 (Adv: 0.3272, Aux: 0.0000, VQE_reg: -0.3568, E_c: -3.5680)
#   D loss: 0.8655 (RealAdv: 0.4042, FakeAdv: 1.2787, RealAux: 0.0480, FakeAux: 0.0001)
# [Epoch 6/10] [Batch 1175/1875] [Iter 10550]
#   G loss: 0.0131 (Adv: 0.3720, Aux: 0.0002, VQE_reg: -0.3590, E_c: -3.5902)
#   D loss: 0.8025 (RealAdv: 0.4271, FakeAdv: 1.1738, RealAux: 0.0037, FakeAux: 0.0004)
# [Epoch 6/10] [Batch 1225/1875] [Iter 10600]
#   G loss: -0.0226 (Adv: 0.3343, Aux: 0.0004, VQE_reg: -0.3573, E_c: -3.5725)
#   D loss: 0.8352 (RealAdv: 0.3896, FakeAdv: 1.2737, RealAux: 0.0062, FakeAux: 0.0009)
# [Epoch 6/10] [Batch 1275/1875] [Iter 10650]
#   G loss: -0.0460 (Adv: 0.3087, Aux: 0.0002, VQE_reg: -0.3549, E_c: -3.5489)
#   D loss: 0.8379 (RealAdv: 0.4038, FakeAdv: 1.2672, RealAux: 0.0035, FakeAux: 0.0013)
# [Epoch 6/10] [Batch 1325/1875] [Iter 10700]
#   G loss: -0.0057 (Adv: 0.3512, Aux: 0.0002, VQE_reg: -0.3571, E_c: -3.5711)
#   D loss: 0.8333 (RealAdv: 0.4045, FakeAdv: 1.2594, RealAux: 0.0021, FakeAux: 0.0007)
# ...
# [Epoch 9/10] [Batch 200/1875] [Iter 15200]
#   G loss: -0.0402 (Adv: 0.3149, Aux: 0.0001, VQE_reg: -0.3553, E_c: -3.5527)
#   D loss: 0.8259 (RealAdv: 0.3918, FakeAdv: 1.2569, RealAux: 0.0020, FakeAux: 0.0010)
# [Epoch 9/10] [Batch 250/1875] [Iter 15250]
#   G loss: -0.0681 (Adv: 0.2862, Aux: 0.0037, VQE_reg: -0.3581, E_c: -3.5806)
#   D loss: 0.9383 (RealAdv: 0.3852, FakeAdv: 1.4731, RealAux: 0.0174, FakeAux: 0.0009)
# [Epoch 9/10] [Batch 300/1875] [Iter 15300]
#   G loss: -0.0028 (Adv: 0.3536, Aux: 0.0002, VQE_reg: -0.3566, E_c: -3.5659)
#   D loss: 0.8329 (RealAdv: 0.4052, FakeAdv: 1.2531, RealAux: 0.0059, FakeAux: 0.0017)
# [Epoch 9/10] [Batch 350/1875] [Iter 15350]
#   G loss: -0.0223 (Adv: 0.3351, Aux: 0.0003, VQE_reg: -0.3577, E_c: -3.5772)
#   D loss: 0.8706 (RealAdv: 0.4047, FakeAdv: 1.2867, RealAux: 0.0496, FakeAux: 0.0003)
# [Epoch 9/10] [Batch 400/1875] [Iter 15400]
#   G loss: -0.0117 (Adv: 0.3455, Aux: 0.0003, VQE_reg: -0.3574, E_c: -3.5741)
#   D loss: 0.8628 (RealAdv: 0.4358, FakeAdv: 1.2849, RealAux: 0.0046, FakeAux: 0.0003)
# [Epoch 9/10] [Batch 450/1875] [Iter 15450]
#   G loss: -0.0404 (Adv: 0.3147, Aux: 0.0006, VQE_reg: -0.3556, E_c: -3.5565)
#   D loss: 0.8525 (RealAdv: 0.4153, FakeAdv: 1.2626, RealAux: 0.0230, FakeAux: 0.0041)
# [Epoch 9/10] [Batch 500/1875] [Iter 15500]
#   G loss: -0.0549 (Adv: 0.3026, Aux: 0.0006, VQE_reg: -0.3580, E_c: -3.5804)
#   D loss: 0.9622 (RealAdv: 0.3778, FakeAdv: 1.4517, RealAux: 0.0101, FakeAux: 0.0847)
# [Epoch 9/10] [Batch 550/1875] [Iter 15550]
#   G loss: -0.0527 (Adv: 0.3019, Aux: 0.0009, VQE_reg: -0.3555, E_c: -3.5547)
#   D loss: 0.8956 (RealAdv: 0.3953, FakeAdv: 1.3942, RealAux: 0.0011, FakeAux: 0.0007)
# [Epoch 9/10] [Batch 600/1875] [Iter 15600]
#   G loss: -0.0067 (Adv: 0.3512, Aux: 0.0001, VQE_reg: -0.3581, E_c: -3.5806)
#   D loss: 0.8685 (RealAdv: 0.4399, FakeAdv: 1.2420, RealAux: 0.0539, FakeAux: 0.0011)
# [Epoch 9/10] [Batch 650/1875] [Iter 15650]
#   G loss: 0.0409 (Adv: 0.3947, Aux: 0.0026, VQE_reg: -0.3565, E_c: -3.5648)
#   D loss: 0.7802 (RealAdv: 0.4462, FakeAdv: 1.0660, RealAux: 0.0481, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 700/1875] [Iter 15700]
#   G loss: 0.0100 (Adv: 0.3639, Aux: 0.0005, VQE_reg: -0.3544, E_c: -3.5441)
#   D loss: 0.8419 (RealAdv: 0.4053, FakeAdv: 1.2703, RealAux: 0.0081, FakeAux: 0.0002)
# [Epoch 9/10] [Batch 750/1875] [Iter 15750]
#   G loss: -0.0400 (Adv: 0.3152, Aux: 0.0019, VQE_reg: -0.3571, E_c: -3.5709)
#   D loss: 0.8725 (RealAdv: 0.4084, FakeAdv: 1.3347, RealAux: 0.0015, FakeAux: 0.0005)
# [Epoch 9/10] [Batch 800/1875] [Iter 15800]
#   G loss: -0.0111 (Adv: 0.3427, Aux: 0.0001, VQE_reg: -0.3538, E_c: -3.5379)
#   D loss: 0.9777 (RealAdv: 0.3978, FakeAdv: 1.2617, RealAux: 0.2957, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 850/1875] [Iter 15850]
#   G loss: -0.0503 (Adv: 0.3049, Aux: 0.0025, VQE_reg: -0.3576, E_c: -3.5763)
#   D loss: 0.8969 (RealAdv: 0.4166, FakeAdv: 1.3762, RealAux: 0.0007, FakeAux: 0.0002)
# [Epoch 9/10] [Batch 900/1875] [Iter 15900]
#   G loss: 0.0312 (Adv: 0.3885, Aux: 0.0009, VQE_reg: -0.3582, E_c: -3.5822)
#   D loss: 0.7820 (RealAdv: 0.4248, FakeAdv: 1.1136, RealAux: 0.0253, FakeAux: 0.0004)
# [Epoch 9/10] [Batch 950/1875] [Iter 15950]
#   G loss: 0.0206 (Adv: 0.3627, Aux: 0.0155, VQE_reg: -0.3576, E_c: -3.5762)
#   D loss: 0.8061 (RealAdv: 0.4105, FakeAdv: 1.1971, RealAux: 0.0045, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1000/1875] [Iter 16000]
#   G loss: -0.0093 (Adv: 0.3442, Aux: 0.0017, VQE_reg: -0.3552, E_c: -3.5522)
#   D loss: 0.8506 (RealAdv: 0.4277, FakeAdv: 1.2510, RealAux: 0.0218, FakeAux: 0.0006)
# [Epoch 9/10] [Batch 1050/1875] [Iter 16050]
#   G loss: -0.1030 (Adv: 0.2549, Aux: 0.0013, VQE_reg: -0.3592, E_c: -3.5921)
#   D loss: 0.9720 (RealAdv: 0.3943, FakeAdv: 1.3542, RealAux: 0.1892, FakeAux: 0.0063)
# [Epoch 9/10] [Batch 1100/1875] [Iter 16100]
#   G loss: -0.0570 (Adv: 0.3006, Aux: 0.0002, VQE_reg: -0.3577, E_c: -3.5773)
#   D loss: 0.9428 (RealAdv: 0.3869, FakeAdv: 1.4107, RealAux: 0.0879, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1150/1875] [Iter 16150]
#   G loss: -0.0343 (Adv: 0.3232, Aux: 0.0001, VQE_reg: -0.3576, E_c: -3.5757)
#   D loss: 0.8726 (RealAdv: 0.4123, FakeAdv: 1.3308, RealAux: 0.0017, FakeAux: 0.0004)
# [Epoch 9/10] [Batch 1200/1875] [Iter 16200]
#   G loss: 0.0108 (Adv: 0.3709, Aux: 0.0006, VQE_reg: -0.3607, E_c: -3.6065)
#   D loss: 0.7845 (RealAdv: 0.4345, FakeAdv: 1.1306, RealAux: 0.0033, FakeAux: 0.0006)
# [Epoch 9/10] [Batch 1250/1875] [Iter 16250]
#   G loss: -0.0613 (Adv: 0.2905, Aux: 0.0018, VQE_reg: -0.3536, E_c: -3.5362)
#   D loss: 0.9662 (RealAdv: 0.3890, FakeAdv: 1.4316, RealAux: 0.1108, FakeAux: 0.0009)
# [Epoch 9/10] [Batch 1300/1875] [Iter 16300]
#   G loss: -0.0702 (Adv: 0.2887, Aux: 0.0004, VQE_reg: -0.3593, E_c: -3.5934)
#   D loss: 0.8555 (RealAdv: 0.3776, FakeAdv: 1.3288, RealAux: 0.0045, FakeAux: 0.0002)
# [Epoch 9/10] [Batch 1350/1875] [Iter 16350]
#   G loss: -0.0220 (Adv: 0.3368, Aux: 0.0002, VQE_reg: -0.3590, E_c: -3.5905)
#   D loss: 0.8761 (RealAdv: 0.4459, FakeAdv: 1.2722, RealAux: 0.0336, FakeAux: 0.0005)
# [Epoch 9/10] [Batch 1400/1875] [Iter 16400]
#   G loss: -0.0304 (Adv: 0.3274, Aux: 0.0001, VQE_reg: -0.3579, E_c: -3.5789)
#   D loss: 0.8863 (RealAdv: 0.3968, FakeAdv: 1.3751, RealAux: 0.0005, FakeAux: 0.0003)
# [Epoch 9/10] [Batch 1450/1875] [Iter 16450]
#   G loss: -0.0317 (Adv: 0.3264, Aux: 0.0006, VQE_reg: -0.3587, E_c: -3.5870)
#   D loss: 0.8764 (RealAdv: 0.4147, FakeAdv: 1.3060, RealAux: 0.0320, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1500/1875] [Iter 16500]
#   G loss: -0.0549 (Adv: 0.3014, Aux: 0.0000, VQE_reg: -0.3563, E_c: -3.5635)
#   D loss: 0.8388 (RealAdv: 0.4059, FakeAdv: 1.2682, RealAux: 0.0010, FakeAux: 0.0025)
# [Epoch 9/10] [Batch 1550/1875] [Iter 16550]
#   G loss: -0.0683 (Adv: 0.2936, Aux: 0.0001, VQE_reg: -0.3621, E_c: -3.6207)
#   D loss: 0.9125 (RealAdv: 0.3877, FakeAdv: 1.3746, RealAux: 0.0627, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 1600/1875] [Iter 16600]
#   G loss: 0.0052 (Adv: 0.3626, Aux: 0.0001, VQE_reg: -0.3574, E_c: -3.5743)
#   D loss: 0.8405 (RealAdv: 0.4134, FakeAdv: 1.2623, RealAux: 0.0053, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 1650/1875] [Iter 16650]
#   G loss: -0.0285 (Adv: 0.3302, Aux: 0.0001, VQE_reg: -0.3588, E_c: -3.5884)
#   D loss: 0.7925 (RealAdv: 0.3872, FakeAdv: 1.1948, RealAux: 0.0031, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 1700/1875] [Iter 16700]
#   G loss: -0.0251 (Adv: 0.3343, Aux: 0.0001, VQE_reg: -0.3594, E_c: -3.5943)
#   D loss: 0.8232 (RealAdv: 0.4118, FakeAdv: 1.2241, RealAux: 0.0103, FakeAux: 0.0001)
# [Epoch 9/10] [Batch 1750/1875] [Iter 16750]
#   G loss: -0.0787 (Adv: 0.2777, Aux: 0.0002, VQE_reg: -0.3567, E_c: -3.5669)
#   D loss: 0.8416 (RealAdv: 0.4033, FakeAdv: 1.2765, RealAux: 0.0034, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 1800/1875] [Iter 16800]
#   G loss: 0.0009 (Adv: 0.3584, Aux: 0.0028, VQE_reg: -0.3603, E_c: -3.6026)
#   D loss: 0.8220 (RealAdv: 0.4152, FakeAdv: 1.2218, RealAux: 0.0069, FakeAux: 0.0000)
# [Epoch 9/10] [Batch 1850/1875] [Iter 16850]
#   G loss: 0.0020 (Adv: 0.3601, Aux: 0.0007, VQE_reg: -0.3588, E_c: -3.5881)
#   D loss: 0.8717 (RealAdv: 0.4050, FakeAdv: 1.3349, RealAux: 0.0006, FakeAux: 0.0029)
#
# --- End of Epoch 9/10 (Duration: 4989.05s) ---
#   Avg G Loss: -0.0247 (Adv: 0.3309, Aux: 0.0024, VQE_reg: -0.3580, Avg E_c: -3.5797)
#   Avg D Loss: 0.8592 (R_Adv: 0.4085, F_Adv: 1.2834, R_Aux: 0.0247, F_Aux: 0.0018)
#   Samples for epoch 9 saved.
#   Running evaluation for epoch 9...
#   Generating 1000 samples for FID/IS into '/tmp/tmpt_lc3zz0'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...
#   FID: 29.5406, IS (mean): 2.0835
#   Generating 500 samples for classification test...
#   Classification accuracy on generated images: 99.40%
# ------------------------------------------------------------
# [Epoch 10/10] [Batch 25/1875] [Iter 16900]
#   G loss: -0.0454 (Adv: 0.3184, Aux: 0.0001, VQE_reg: -0.3639, E_c: -3.6389)
#   D loss: 0.8825 (RealAdv: 0.4136, FakeAdv: 1.3392, RealAux: 0.0122, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 75/1875] [Iter 16950]
#   G loss: 0.0289 (Adv: 0.3848, Aux: 0.0003, VQE_reg: -0.3562, E_c: -3.5617)
#   D loss: 0.8342 (RealAdv: 0.4277, FakeAdv: 1.2386, RealAux: 0.0021, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 125/1875] [Iter 17000]
#   G loss: -0.0040 (Adv: 0.3484, Aux: 0.0056, VQE_reg: -0.3579, E_c: -3.5790)
#   D loss: 0.8400 (RealAdv: 0.4026, FakeAdv: 1.2280, RealAux: 0.0488, FakeAux: 0.0006)
# [Epoch 10/10] [Batch 175/1875] [Iter 17050]
#   G loss: -0.0246 (Adv: 0.3329, Aux: 0.0002, VQE_reg: -0.3576, E_c: -3.5762)
#   D loss: 0.8353 (RealAdv: 0.4000, FakeAdv: 1.2547, RealAux: 0.0155, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 225/1875] [Iter 17100]
#   G loss: 0.0169 (Adv: 0.3692, Aux: 0.0041, VQE_reg: -0.3564, E_c: -3.5641)
#   D loss: 0.8956 (RealAdv: 0.4296, FakeAdv: 1.2884, RealAux: 0.0728, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 275/1875] [Iter 17150]
#   G loss: 0.0064 (Adv: 0.3620, Aux: 0.0003, VQE_reg: -0.3559, E_c: -3.5589)
#   D loss: 0.9502 (RealAdv: 0.4216, FakeAdv: 1.3446, RealAux: 0.1337, FakeAux: 0.0005)
# [Epoch 10/10] [Batch 325/1875] [Iter 17200]
#   G loss: -0.0212 (Adv: 0.3371, Aux: 0.0002, VQE_reg: -0.3584, E_c: -3.5842)
#   D loss: 0.8436 (RealAdv: 0.4281, FakeAdv: 1.2574, RealAux: 0.0016, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 375/1875] [Iter 17250]
#   G loss: -0.0123 (Adv: 0.3455, Aux: 0.0001, VQE_reg: -0.3579, E_c: -3.5791)
#   D loss: 0.8545 (RealAdv: 0.4222, FakeAdv: 1.2432, RealAux: 0.0435, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 425/1875] [Iter 17300]
#   G loss: 0.0081 (Adv: 0.3654, Aux: 0.0002, VQE_reg: -0.3575, E_c: -3.5752)
#   D loss: 0.8756 (RealAdv: 0.4264, FakeAdv: 1.1866, RealAux: 0.1375, FakeAux: 0.0008)
# [Epoch 10/10] [Batch 475/1875] [Iter 17350]
#   G loss: -0.0335 (Adv: 0.3175, Aux: 0.0057, VQE_reg: -0.3567, E_c: -3.5666)
#   D loss: 0.8314 (RealAdv: 0.3987, FakeAdv: 1.2231, RealAux: 0.0078, FakeAux: 0.0331)
# [Epoch 10/10] [Batch 525/1875] [Iter 17400]
#   G loss: -0.0097 (Adv: 0.3487, Aux: 0.0002, VQE_reg: -0.3586, E_c: -3.5859)
#   D loss: 0.9296 (RealAdv: 0.4003, FakeAdv: 1.2994, RealAux: 0.1589, FakeAux: 0.0006)
# [Epoch 10/10] [Batch 575/1875] [Iter 17450]
#   G loss: 0.0011 (Adv: 0.3590, Aux: 0.0003, VQE_reg: -0.3582, E_c: -3.5824)
#   D loss: 0.8091 (RealAdv: 0.3979, FakeAdv: 1.2138, RealAux: 0.0064, FakeAux: 0.0002)
# [Epoch 10/10] [Batch 625/1875] [Iter 17500]
#   G loss: -0.0603 (Adv: 0.2955, Aux: 0.0001, VQE_reg: -0.3560, E_c: -3.5600)
#   D loss: 0.8752 (RealAdv: 0.4335, FakeAdv: 1.3135, RealAux: 0.0033, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 675/1875] [Iter 17550]
#   G loss: -0.0127 (Adv: 0.3454, Aux: 0.0007, VQE_reg: -0.3588, E_c: -3.5880)
#   D loss: 0.8522 (RealAdv: 0.4228, FakeAdv: 1.2803, RealAux: 0.0014, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 725/1875] [Iter 17600]
#   G loss: 0.0065 (Adv: 0.3581, Aux: 0.0070, VQE_reg: -0.3586, E_c: -3.5862)
#   D loss: 0.8344 (RealAdv: 0.4250, FakeAdv: 1.2431, RealAux: 0.0005, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 775/1875] [Iter 17650]
#   G loss: -0.0041 (Adv: 0.3542, Aux: 0.0002, VQE_reg: -0.3585, E_c: -3.5847)
#   D loss: 0.8545 (RealAdv: 0.4056, FakeAdv: 1.3006, RealAux: 0.0027, FakeAux: 0.0002)
# [Epoch 10/10] [Batch 825/1875] [Iter 17700]
#   G loss: -0.0001 (Adv: 0.3573, Aux: 0.0005, VQE_reg: -0.3579, E_c: -3.5789)
#   D loss: 0.8594 (RealAdv: 0.4227, FakeAdv: 1.2480, RealAux: 0.0480, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 875/1875] [Iter 17750]
#   G loss: -0.0372 (Adv: 0.3209, Aux: 0.0001, VQE_reg: -0.3582, E_c: -3.5821)
#   D loss: 0.8401 (RealAdv: 0.4077, FakeAdv: 1.2691, RealAux: 0.0034, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 925/1875] [Iter 17800]
#   G loss: -0.0177 (Adv: 0.3431, Aux: 0.0006, VQE_reg: -0.3614, E_c: -3.6137)
#   D loss: 0.7954 (RealAdv: 0.4236, FakeAdv: 1.1623, RealAux: 0.0049, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 975/1875] [Iter 17850]
#   G loss: -0.0237 (Adv: 0.3287, Aux: 0.0030, VQE_reg: -0.3554, E_c: -3.5545)
#   D loss: 0.8899 (RealAdv: 0.4362, FakeAdv: 1.3408, RealAux: 0.0018, FakeAux: 0.0010)
# [Epoch 10/10] [Batch 1025/1875] [Iter 17900]
#   G loss: -0.0355 (Adv: 0.3188, Aux: 0.0000, VQE_reg: -0.3544, E_c: -3.5438)
#   D loss: 0.8493 (RealAdv: 0.4184, FakeAdv: 1.2767, RealAux: 0.0031, FakeAux: 0.0005)
# [Epoch 10/10] [Batch 1075/1875] [Iter 17950]
#   G loss: -0.0501 (Adv: 0.3089, Aux: 0.0001, VQE_reg: -0.3591, E_c: -3.5914)
#   D loss: 0.8361 (RealAdv: 0.3898, FakeAdv: 1.2510, RealAux: 0.0314, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1125/1875] [Iter 18000]
#   G loss: -0.0386 (Adv: 0.3177, Aux: 0.0000, VQE_reg: -0.3563, E_c: -3.5632)
#   D loss: 0.8385 (RealAdv: 0.4057, FakeAdv: 1.2629, RealAux: 0.0084, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1175/1875] [Iter 18050]
#   G loss: -0.0399 (Adv: 0.3176, Aux: 0.0002, VQE_reg: -0.3576, E_c: -3.5762)
#   D loss: 0.8344 (RealAdv: 0.4114, FakeAdv: 1.2456, RealAux: 0.0113, FakeAux: 0.0005)
# [Epoch 10/10] [Batch 1225/1875] [Iter 18100]
#   G loss: -0.0455 (Adv: 0.3116, Aux: 0.0005, VQE_reg: -0.3576, E_c: -3.5759)
#   D loss: 0.9064 (RealAdv: 0.4220, FakeAdv: 1.2735, RealAux: 0.1167, FakeAux: 0.0005)
# [Epoch 10/10] [Batch 1275/1875] [Iter 18150]
#   G loss: -0.0871 (Adv: 0.2707, Aux: 0.0002, VQE_reg: -0.3581, E_c: -3.5805)
#   D loss: 0.9172 (RealAdv: 0.3704, FakeAdv: 1.4052, RealAux: 0.0524, FakeAux: 0.0064)
# [Epoch 10/10] [Batch 1325/1875] [Iter 18200]
#   G loss: 0.0035 (Adv: 0.3610, Aux: 0.0000, VQE_reg: -0.3575, E_c: -3.5748)
#   D loss: 0.8467 (RealAdv: 0.4021, FakeAdv: 1.1795, RealAux: 0.1114, FakeAux: 0.0004)
# [Epoch 10/10] [Batch 1375/1875] [Iter 18250]
#   G loss: -0.0120 (Adv: 0.3447, Aux: 0.0024, VQE_reg: -0.3591, E_c: -3.5911)
#   D loss: 0.8218 (RealAdv: 0.4167, FakeAdv: 1.1820, RealAux: 0.0444, FakeAux: 0.0005)
# [Epoch 10/10] [Batch 1425/1875] [Iter 18300]
#   G loss: -0.0374 (Adv: 0.3225, Aux: 0.0001, VQE_reg: -0.3600, E_c: -3.5997)
#   D loss: 0.8770 (RealAdv: 0.4343, FakeAdv: 1.3148, RealAux: 0.0046, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 1475/1875] [Iter 18350]
#   G loss: 0.0078 (Adv: 0.3642, Aux: 0.0001, VQE_reg: -0.3565, E_c: -3.5647)
#   D loss: 0.8279 (RealAdv: 0.4216, FakeAdv: 1.2308, RealAux: 0.0031, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 1525/1875] [Iter 18400]
#   G loss: -0.0859 (Adv: 0.2675, Aux: 0.0015, VQE_reg: -0.3549, E_c: -3.5491)
#   D loss: 0.9233 (RealAdv: 0.3702, FakeAdv: 1.4759, RealAux: 0.0003, FakeAux: 0.0002)
# [Epoch 10/10] [Batch 1575/1875] [Iter 18450]
#   G loss: -0.0159 (Adv: 0.3374, Aux: 0.0001, VQE_reg: -0.3534, E_c: -3.5341)
#   D loss: 0.8819 (RealAdv: 0.4179, FakeAdv: 1.3149, RealAux: 0.0019, FakeAux: 0.0290)
# [Epoch 10/10] [Batch 1625/1875] [Iter 18500]
#   G loss: -0.0396 (Adv: 0.3194, Aux: 0.0005, VQE_reg: -0.3595, E_c: -3.5953)
#   D loss: 0.8243 (RealAdv: 0.4040, FakeAdv: 1.2136, RealAux: 0.0309, FakeAux: 0.0000)
# [Epoch 10/10] [Batch 1675/1875] [Iter 18550]
#   G loss: -0.0679 (Adv: 0.2908, Aux: 0.0000, VQE_reg: -0.3588, E_c: -3.5878)
#   D loss: 0.8317 (RealAdv: 0.4028, FakeAdv: 1.2595, RealAux: 0.0010, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1725/1875] [Iter 18600]
#   G loss: -0.0144 (Adv: 0.3423, Aux: 0.0001, VQE_reg: -0.3568, E_c: -3.5684)
#   D loss: 0.8513 (RealAdv: 0.4019, FakeAdv: 1.2973, RealAux: 0.0033, FakeAux: 0.0001)
# [Epoch 10/10] [Batch 1775/1875] [Iter 18650]
#   G loss: -0.0115 (Adv: 0.3460, Aux: 0.0012, VQE_reg: -0.3587, E_c: -3.5868)
#   D loss: 0.8178 (RealAdv: 0.4138, FakeAdv: 1.2142, RealAux: 0.0073, FakeAux: 0.0004)
# [Epoch 10/10] [Batch 1825/1875] [Iter 18700]
#   G loss: -0.0076 (Adv: 0.3470, Aux: 0.0009, VQE_reg: -0.3555, E_c: -3.5548)
#   D loss: 0.8031 (RealAdv: 0.4222, FakeAdv: 1.1821, RealAux: 0.0015, FakeAux: 0.0003)
# [Epoch 10/10] [Batch 1875/1875] [Iter 18750]
#   G loss: -0.0123 (Adv: 0.3470, Aux: 0.0003, VQE_reg: -0.3596, E_c: -3.5962)
#   D loss: 0.8675 (RealAdv: 0.3858, FakeAdv: 1.3181, RealAux: 0.0309, FakeAux: 0.0002)
#
# --- End of Epoch 10/10 (Duration: 5023.93s) ---
#   Avg G Loss: -0.0261 (Adv: 0.3300, Aux: 0.0018, VQE_reg: -0.3580, Avg E_c: -3.5796)
#   Avg D Loss: 0.8596 (R_Adv: 0.4097, F_Adv: 1.2852, R_Aux: 0.0224, F_Aux: 0.0020)
#   Samples for epoch 10 saved.
#   Running evaluation for epoch 10...
#   Generating 1000 samples for FID/IS into '/tmp/tmp0paiu1cn'...
#   Saved 1000 images for metrics. Computing FID/IS via torch-fidelity...

# %% [markdown]
# ## 9. Evaluation and Visualization
#
# ### Results Summary (10 Epochs, Seed 42)
#
# | Epoch | FID ↓ | IS ↑ | Accuracy |
# |-------|-------|------|----------|
# | 1 | 122.19 | 2.09 | 86.0% |
# | 2 | 61.79 | **2.29** | 83.4% |
# | 5 | 35.96 | 2.06 | 99.0% |
# | 7 | 27.83 | 2.06 | **99.4%** |
# | 10 | **23.91** | 2.20 | 97.6% |
#
# ### Comparison with Other Runs
#
# | Run | Best FID | FID @ ep.5 | Best Accuracy | Training Time |
# |-----|----------|------------|---------------|---------------|
# | **This run (RUN1)** | 23.91 (ep.10) | 35.96 | 99.4% | ~14h 2min |
# | 5-Epoch Exploratory | 19.92 (ep.5) | 19.92 | 99.0% | ~7h 17min |
# | ACGAN Baseline | 24.02 (ep.20) | — | 100% (ep.35) | ~27min |
#
# ### Key Observation
# The high FID variance at epoch 5 (35.96 vs. 19.92 in exploratory run) demonstrates sensitivity to training dynamics, but extended training stabilizes FID to ~24, competitive with the ACGAN baseline.

# %%
#@title 9. Visualization of Training Logs

"""
<summary>
Loads the training logs from file and visualizes the training progress of the hybrid ACGAN model.
Plots losses, loss components, energy, FID/IS metrics, and classification accuracy over iterations/epochs.
</summary>
"""

if os.path.exists(LOG_FILE):
    with open(LOG_FILE, 'rb') as f:
        logs = pickle.load(f)

    plt.style.use('seaborn-v0_8-whitegrid')

    fig, axs = plt.subplots(4, 2, figsize=(18, 22))
    fig.suptitle('Hybrid ACGAN-VQER Training Analysis', fontsize=16)

    iters = logs.get('iterations', [])
    epochs_eval = logs.get('eval_epochs', [])

    if iters:
        axs[0, 0].plot(iters, logs.get('g_loss', []), label='G Loss (Total)', color='green', alpha=0.7)
        axs[0, 0].plot(iters, logs.get('d_loss', []), label='D Loss (Total)', color='red', alpha=0.7)
        axs[0, 0].set_xlabel('Iterations')
        axs[0, 0].set_ylabel('Loss')
        axs[0, 0].set_title('Total G and D Losses')
        axs[0, 0].legend()
        axs[0, 0].grid(True, linestyle='--', alpha=0.7)

    if iters:
        axs[0, 1].plot(iters, logs.get('g_adv_loss', []), label='G Adv Loss', color='lightgreen', linestyle='--')
        axs[0, 1].plot(iters, logs.get('g_aux_loss', []), label='G Aux Loss', color='darkgreen', linestyle='-.')
        axs[0, 1].plot(iters, logs.get('g_vqe_loss', []), label='G VQE Reg Loss', color='cyan', linestyle=':')
        axs[0, 1].set_xlabel('Iterations')
        axs[0, 1].set_ylabel('Loss')
        axs[0, 1].set_title('Generator Loss Components')
        axs[0, 1].legend()
        axs[0, 1].grid(True, linestyle='--', alpha=0.7)

    if iters:
        axs[1, 0].plot(iters, logs.get('avg_energy', []), label='Avg E_c (per batch)', color='magenta')
        axs[1, 0].set_xlabel('Iterations')
        axs[1, 0].set_ylabel('Average Energy E_c')
        axs[1, 0].set_title('E_c Energy from VQE Regularization')
        axs[1, 0].legend()
        axs[1, 0].grid(True, linestyle='--', alpha=0.7)

    if iters:
        axs[1, 1].plot(iters, logs.get('d_real_adv_loss', []), label='D Real Adv', color='salmon', linestyle='--')
        axs[1, 1].plot(iters, logs.get('d_fake_adv_loss', []), label='D Fake Adv', color='firebrick', linestyle='--')
        axs[1, 1].plot(iters, logs.get('d_real_aux_loss', []), label='D Real Aux', color='lightcoral', linestyle='-.')
        axs[1, 1].plot(iters, logs.get('d_fake_aux_loss', []), label='D Fake Aux', color='maroon', linestyle='-.')
        axs[1, 1].set_xlabel('Iterations')
        axs[1, 1].set_ylabel('Loss')
        axs[1, 1].set_title('Discriminator Loss Components')
        axs[1, 1].legend()
        axs[1, 1].grid(True, linestyle='--', alpha=0.7)

    if epochs_eval:
        axs[2, 0].plot(epochs_eval, logs.get('fid_scores', []), label='FID Score', marker='o', color='blue')
        axs[2, 0].set_xlabel('Epochs')
        axs[2, 0].set_ylabel('FID (lower is better)')
        axs[2, 0].set_title('Fréchet Inception Distance (FID)')
        axs[2, 0].legend()
        axs[2, 0].grid(True, linestyle='--', alpha=0.7)

    if epochs_eval:
        axs[2, 1].plot(epochs_eval, logs.get('is_scores', []), label='Inception Score (mean)', marker='s', color='purple')
        axs[2, 1].set_xlabel('Epochs')
        axs[2, 1].set_ylabel('IS (higher is better)')
        axs[2, 1].set_title('Inception Score (IS)')
        axs[2, 1].legend()
        axs[2, 1].grid(True, linestyle='--', alpha=0.7)

    if epochs_eval:
        axs[3, 0].plot(epochs_eval, logs.get('classification_accuracy', []), label='Classification Accuracy', marker='^', color='teal')
        axs[3, 0].set_xlabel('Epochs')
        axs[3, 0].set_ylabel('Accuracy (%)')
        axs[3, 0].set_title('External Classifier Accuracy')
        axs[3, 0].legend()
        axs[3, 0].grid(True, linestyle='--', alpha=0.7)

    axs[3, 1].axis('off')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()
else:
    print(f"Log file '{LOG_FILE}' not found. Cannot render plots.")

# %%
#@title 10. Final Sample Generation and Packaging of Results

if os.path.exists(os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_final.pth')):
    print("\nLoading final generator model for sample generation...")
    final_generator = HybridGenerator(
        z_dim=Z_DIM, num_classes=NUM_CLASSES, img_channels=IMG_CHANNELS,
        ansatz_instance=ansatz, list_of_hamiltonians=H_op_list,
        qiskit_estimator=aer_estimator, lambda_vqer_coeff=LAMBDA_VQER
    ).to(device)
    try:
        final_generator.load_state_dict(torch.load(os.path.join(OUTPUT_DIR_MODELS, 'hybrid_generator_final.pth'), map_location=device))
        final_generator.eval()

        samples_per_class_final = 10
        num_final_display_samples = NUM_CLASSES * samples_per_class_final

        final_z = torch.randn(num_final_display_samples, Z_DIM, device=device)
        final_labels_list = []
        for i in range(NUM_CLASSES):
            final_labels_list.extend([i] * samples_per_class_final)
        final_labels = torch.LongTensor(final_labels_list).to(device)

        with torch.no_grad():
            gen_imgs_final_classic, _ = final_generator(final_z, final_labels)

        save_image(gen_imgs_final_classic.data,
                   os.path.join(OUTPUT_DIR_IMAGES, "hybrid_acgan_final_grid_all_classes.png"),
                   nrow=samples_per_class_final, normalize=True)
        print(f"Final sample grid saved to '{OUTPUT_DIR_IMAGES}'.")

        for digit_class in range(NUM_CLASSES):
            class_z = torch.randn(samples_per_class_final, Z_DIM, device=device)
            class_labels = torch.full((samples_per_class_final,), digit_class, dtype=torch.long, device=device)
            with torch.no_grad():
                gen_imgs_class_specific, _ = final_generator(class_z, class_labels)
            save_image(gen_imgs_class_specific.data,
                       os.path.join(OUTPUT_DIR_IMAGES, f"hybrid_acgan_final_samples_class_{digit_class}.png"),
                       nrow=samples_per_class_final, normalize=True)
        print(f"Final samples for individual classes saved to '{OUTPUT_DIR_IMAGES}'.")

    except Exception as e:
        print(f"Error during final sample generation: {e}")
else:
    print("Final generator model not found, samples will not be generated.")

def zip_and_download_results_colab(folders_to_zip, files_to_zip, zip_filename_base="hybrid_acgan_results", work_dir="/content/"):
    """
    <summary>
    Packages selected folders and files into a ZIP archive, downloads it to the user, and deletes the temporary directory in the Google Colab environment.
    </summary>
    <param name="folders_to_zip">List of folder paths to include in the ZIP archive.</param>
    <param name="files_to_zip">List of file paths to include in the ZIP archive.</param>
    <param name="zip_filename_base">Base name of the resulting ZIP file.</param>
    <param name="work_dir">Working directory where the archive will be created.</param>
    """
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    zip_filename = f"{zip_filename_base}_{timestamp}.zip"
    zip_filepath = os.path.join(work_dir, zip_filename)

    temp_archive_dir_name = f"temp_archive_{timestamp}"
    temp_archive_dir_path = os.path.join(work_dir, temp_archive_dir_name)
    os.makedirs(temp_archive_dir_path, exist_ok=True)

    print(f"\nCopying files and folders to temporary directory '{temp_archive_dir_path}' for archiving...")
    for folder_path in folders_to_zip:
        if os.path.isdir(folder_path):
            dest_folder_name = os.path.basename(os.path.normpath(folder_path))
            shutil.copytree(folder_path, os.path.join(temp_archive_dir_path, dest_folder_name))
            print(f"  - Folder '{dest_folder_name}' copied.")
        else:
            print(f"  - Warning: Folder '{folder_path}' not found.")

    for file_item_path in files_to_zip:
        if os.path.isfile(file_item_path):
            shutil.copy(file_item_path, temp_archive_dir_path)
            print(f"  - File '{os.path.basename(file_item_path)}' copied.")
        else:
            print(f"  - Warning: File '{file_item_path}' not found.")

    print("Creating ZIP archive...")
    try:
        shutil.make_archive(os.path.join(work_dir, zip_filename_base + "_" + timestamp),
                            'zip',
                            root_dir=temp_archive_dir_path)
        print(f"ZIP archive '{zip_filepath}' successfully created.")

        shutil.rmtree(temp_archive_dir_path)
        print(f"Temporary directory '{temp_archive_dir_path}' deleted.")

        print(f"Starting download of file '{zip_filename}'...")
        files.download(zip_filepath)
        print("Download started. The file should appear in your browser.")

    except Exception as e:
        print(f"ERROR during creation or download of ZIP archive: {e}")
        if os.path.exists(temp_archive_dir_path):
            shutil.rmtree(temp_archive_dir_path)

folders_to_include = [OUTPUT_DIR_IMAGES, OUTPUT_DIR_MODELS]
files_to_include = [LOG_FILE]
if os.path.exists(CLASSIFIER_PATH):
    files_to_include.append(CLASSIFIER_PATH)

zip_and_download_results_colab(folders_to_include, files_to_include)
# Out:
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# Loading final generator model for sample generation...
# Final sample grid saved to '/content/hybrid_acgan_images_output'.
# Final samples for individual classes saved to '/content/hybrid_acgan_images_output'.
#
# Copying files and folders to temporary directory '/content/temp_archive_20250927_090623' for archiving...
#   - Folder 'hybrid_acgan_images_output' copied.
#   - Folder 'hybrid_acgan_models_output' copied.
#   - File 'hybrid_acgan_training_logs.pkl' copied.
#   - File 'mnist_classifier.pth' copied.
# Creating ZIP archive...
# ZIP archive '/content/hybrid_acgan_results_20250927_090623.zip' successfully created.
# Temporary directory '/content/temp_archive_20250927_090623' deleted.
# Starting download of file 'hybrid_acgan_results_20250927_090623.zip'...
# Download started. The file should appear in your browser.

# %% [markdown]
# ## Discussion and Conclusion
#
# This extended 10-epoch run provides insights into QACGAN training dynamics:
#
# ### Key Findings
# - **FID converges to ~24**: Despite high early variance (FID 35.96 at epoch 5), the model stabilizes to 23.91 by epoch 10
# - **Best IS of 2.29** achieved early (epoch 2), comparable to ACGAN's best IS of 2.23
# - **High classification accuracy** (99.4%) maintained, confirming consistent class conditioning
# - **Training time**: ~14h 2min (10 epochs × ~1.4 h/epoch)
#
# ### Variance Analysis
# The discrepancy between this run's epoch-5 FID (35.96) and the exploratory run (19.92) with the same seed highlights:
# - Early-epoch GAN metrics are highly sensitive to minor training differences
# - Extended training reduces variance and leads to stable final metrics
# - Multiple runs are essential for reliable evaluation
#
# ### Implications
# - VQE regularization consistently improves class accuracy (99%+) across runs
# - FID improvements are less consistent in early epochs but stabilize with longer training
# - The ~14h training time remains a significant barrier for practical applications
#
# ### Future Work
# - Systematic ablation of $\lambda_{\text{VQE}}$ coefficient
# - Adaptive scheduling strategies for the quantum penalty term
# - Evaluation on larger datasets and noise-aware quantum backends
